# %%
# taken from this repo: https://github.com/arup-group/suffolk_network/blob/main/scenarios/scenario_market_towns/Scenario_Market_Towns.ipynb

# also chucking the genet documentation in here: https://arup-group.github.io/genet/latest/reference/genet/utils/spatial/#genet.utils.spatial.distance_between_s2cellids 

import genet as gn
import pandas as pd
import os

# path_to_matsim_network = "/mnt/c/_BERTIE_data/2_2040_do_minimum_40WFH/"
path_to_matsim_network = "/mnt/c/_BERTIE_data/2_2040_do_minimum_40WFH/"
output_path = "/mnt/c/_BERTIE_data/market_buses_2040_test"
# Out:
# /home/siskiyoucedar/micromamba/envs/genet/lib/python3.12/site-packages/keplergl/keplergl.py:2: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_string

# %%
network = os.path.join(path_to_matsim_network, "output_network.xml")
schedule = os.path.join(path_to_matsim_network, "output_transitSchedule.xml") 
vehicles = os.path.join(path_to_matsim_network, 'output_transitVehicles.xml')
n = gn.read_matsim(
    path_to_network=network, epsg="epsg:27700", path_to_schedule=schedule, path_to_vehicles=vehicles
)

# %%
n

# %%
# actual list

market_towns = {
    'Aldeburgh',
    'Bury St Edmunds',
    'Capel St Mary',
    'Clare',
    'East Bergholt',
    'Eye',
    'Ipswich',
    'Lowestoft',
    'Red Lodge',
    'Beck Row',
    'Brandon',
    'Elmswell',
    'Haverhill',
    'Ixworth',
    'Long Melford',
    'Mildenhall',
    'Newmarket',
    'Stowmarket',
    'Sudbury',
    'Thurston',
    'Hadleigh',
    'Haverhill',
    'Felixstowe',
    'Framlingham',
    'Leiston',
    'Needham Market',
    'Rendlesham',
    'Saxmundham',
    'Shotley',
    'Beccles',
    'Bungay',
    'Halesworth',
    'Reydon',
    'Woodbridge',
    'Downham Market',  
    'Kings_Lynn', 
    'Swaffham', 
    'Wroxham', 
    'Stalham', 
    'Aylsham', 
    'Holt',
    'Fakenham', 
    'Hunstanton', 
    'Brandon',
    'Great_Yarmouth', 
    'Caister-on-Sea', 
    'Norwich',
    'Watton', 
    'Attleborough', 
    'Reepham', 
    'Cromer', 
    'Wells Next The Sea', 
    'Thetford',
    'Tiptree', 
    'Halstead', 
    'Great Dunmow', 
    'Brightlingsea',
    'West Mersea', 
    'Maldon', 
    'Saffron Walden', 
    'Braintree', 
    'Epping', 
    'Harlow',
    'Colchester',
    'Chelmsford',
    'Sudbury',
    'South Woodham Ferrers',
    'Bishops Stortford',
    'Braintree'
}
market_towns = sorted(list([t.replace(' ', '_') for t in market_towns]))
market_towns
# Out:
# ['Aldeburgh',
#  'Attleborough',
#  'Aylsham',
#  'Beccles',
#  'Beck_Row',
#  'Bishops_Stortford',
#  'Braintree',
#  'Brandon',
#  'Brightlingsea',
#  'Bungay',
#  'Bury_St_Edmunds',
#  'Caister-on-Sea',
#  'Capel_St_Mary',
#  'Chelmsford',
#  'Clare',
#  'Colchester',
#  'Cromer',
#  'Downham_Market',
#  'East_Bergholt',
#  'Elmswell',
#  'Epping',
#  'Eye',
#  'Fakenham',
#  'Felixstowe',
#  'Framlingham',
#  'Great_Dunmow',
#  'Great_Yarmouth',
#  'Hadleigh',
#  'Halesworth',
#  'Halstead',
#  'Harlow',
#  'Haverhill',
#  'Holt',
#  'Hunstanton',
#  'Ipswich',
#  'Ixworth',
#  'Kings_Lynn',
#  'Leiston',
#  'Long_Melford',
#  'Lowestoft',
#  'Maldon',
#  'Mildenhall',
#  'Needham_Market',
#  'Newmarket',
#  'Norwich',
#  'Red_Lodge',
#  'Reepham',
#  'Rendlesham',
#  'Reydon',
#  'Saffron_Walden',
#  'Saxmundham',
#  'Shotley',
#  'South_Woodham_Ferrers',
#  'Stalham',
#  'Stowmarket',
#  'Sudbury',
#  'Swaffham',
#  'Thetford',
#  'Thurston',
#  'Tiptree',
#  'Watton',
#  'Wells_Next_The_Sea',
#  'West_Mersea',
#  'Woodbridge',
#  'Wroxham']

# %%
# this throws an error - why?

# fixed it. was 5177495089997857897; dug out relevant stop id from schedule xml
# appears stop ids have changed in the newer versions of BERTIE

n.schedule.stop('390060143').print()
# Out:
# Stop ID: 390060143
# Projection: epsg:27700
# Lat, Lon: 52.150799, 1.60107101
# linkRefId: 5177495089997857897_5177495089997857897

# %%
# optional write to geojson - I will use this to get the right stop ids for market_town_stops below:

# n.write_spatial("C:/_BERTIE_data/market_buses_2040", filetype="geojson")
# Out:
# 2025-12-09 15:35:28,767 - Saving Network in C:/_BERTIE_data/market_buses_2040
# 2025-12-09 15:35:33,973 - Created 447,655 records
# 2025-12-09 15:36:09,095 - Created 985,382 records
# 2025-12-09 15:36:11,825 - Created 447,655 records
# 2025-12-09 15:36:27,250 - Created 985,382 records
# 2025-12-09 15:36:29,886 - Saving Schedule in C:/_BERTIE_data/market_buses_2040
# 2025-12-09 15:36:30,331 - Created 20,219 records
# 2025-12-09 15:36:30,667 - Created 26,444 records
# 2025-12-09 15:36:30,783 - Created 20,219 records
# 2025-12-09 15:36:30,983 - Created 26,444 records

# %%
# relevant stops found using QGIS

# I changed all of these for the new ids; will need to pull back from the url noted above if needed

market_town_stops = {
    'Aldeburgh': '390060144',
    'Beccles': '390071010',
    'Beck_Row': '390020120',
    'Brandon': '390020066',
    'Bungay': '390070047',
    'Bury_St_Edmunds': '390050878',
    'Capel_St_Mary': '390010551',
    'Clare': '390050196',
    'East_Bergholt': '390010838',
    'Elmswell': '390040425',
    'Eye': '390040134',
    'Felixstowe': '390060767',
    'Framlingham': '390060370',
    'Hadleigh': '390010387',
    'Halesworth': '390070274',
    'Haverhill': '390050277',
    'Ipswich': '390030007',
    'Ixworth': '390050564',
    'Leiston': '390060208',
    'Long_Melford': '390010149',
    'Lowestoft': '390071022',
    'Mildenhall': '390020289',
    'Needham_Market': '390040505',
    'Newmarket': '390020187',
    'Red_Lodge': '390020148',
    'Rendlesham': '390061134',
    'Reydon': '390070335',
    'Saxmundham': '390060201',
    'Shotley': '390010018',
    'Stowmarket': '390040596',
    'Sudbury': '390010689',
    'Thurston': '390040539',
    'Woodbridge': '390060607',
    # norwich ones:
    'Downham_Market': '290G8',  # king's lynn
    'Kings_Lynn': '290G15', # hunstanton, swaffham
    'Swaffham': '2900S7122', # king's lynn, norwich
    'Wroxham': '2900W554', # norwich
    'Stalham': '2900S3919', # norwich 
    'Aylsham': '2900A219', # norwich, cromer
    'Holt': '2900H394', # cromer
    'Fakenham': '2900F0118', # wells
    'Hunstanton': '290G14', # king's lynn
    'Brandon': '390020066', # thetford 
    'Great_Yarmouth': '2900Y0386', # lowestoft
    'Caister-on-Sea': '2900C0117', # yarmouth
    'Norwich': '290G65', # beccles, bungay
    'Watton': '2900W1219', # dereham, thetford
    'Attleborough': '2900A181', # norwich
    'Reepham': '2900R053', # norwich
    'Cromer': '2900C3811', # aylsham, holt
    'Wells_Next_The_Sea': '2900W5712', # fakenham
    'Thetford': '290G29', # brandon
    # essex ones: 
    'Tiptree': '150014006006', # colchester
    'Halstead': '1500IM101', # braintree
    'Great_Dunmow': '150018016003', # braintree, bishops stortford
    'Brightlingsea': '150032004031', # colchester
    'West_Mersea': '150014013023', # colchester
    'Maldon': '1500IM597', # chelmsford, south woodham ferrers
    'Saffron_Walden': '1500IM154', # bishops stortford
    'Braintree': '150G00003242', # sudbury
    'Epping': '1500IM353', # harlow
    'Harlow': '150G00000876', # and chelmsford here because why not
    'Colchester': '1500IM77A',
    'Chelmsford': '150G00003237',
    'South_Woodham_Ferrers': '1500IM2261B',
    'Bishops_Stortford': '210G224'
}

# %%
# as yet unchanged - to add norfolk and essex ones

market_town_links = [
    ('Aldeburgh','Woodbridge'),
    ('Bury_St_Edmunds', 'Beck_Row'),
    ('Bury_St_Edmunds', 'Brandon'),
    ('Bury_St_Edmunds', 'Elmswell'),
    ('Bury_St_Edmunds', 'Haverhill'),
    ('Bury_St_Edmunds', 'Ixworth'),
    ('Bury_St_Edmunds', 'Long_Melford'),
    ('Bury_St_Edmunds', 'Mildenhall'),
    ('Bury_St_Edmunds', 'Newmarket'),
    ('Bury_St_Edmunds', 'Stowmarket'),
    ('Bury_St_Edmunds', 'Sudbury'),
    ('Bury_St_Edmunds', 'Thurston'),
    ('Capel_St_Mary', 'Hadleigh'),
    ('Clare', 'Haverhill'),
    ('East_Bergholt', 'Hadleigh'),
    ('Eye', 'Stowmarket'),
    ('Ipswich', 'Felixstowe'),
    ('Ipswich', 'Framlingham'),
    ('Ipswich', 'Hadleigh'),
    ('Ipswich', 'Leiston'),
    ('Ipswich', 'Needham_Market'),
    ('Ipswich', 'Rendlesham'),
    ('Ipswich', 'Saxmundham'),
    ('Ipswich', 'Shotley'),
    ('Ipswich', 'Stowmarket'),
    ('Ipswich', 'Woodbridge'),
    ('Lowestoft', 'Beccles'),
    ('Lowestoft', 'Bungay'),
    ('Lowestoft', 'Halesworth'),
    ('Lowestoft', 'Leiston'),
    ('Lowestoft', 'Saxmundham'),
    ('Red_Lodge', 'Mildenhall'),
    ('Reydon', 'Halesworth'),
    # norwich:
    ('Downham_Market', 'Kings_Lynn'),
    ('Swaffham', 'Kings_Lynn'),
    ('Swaffham', 'Norwich'),
    ('Wroxham', 'Norwich'),
    ('Stalham', 'Norwich'),
    ('Aylsham', 'Norwich'),
    ('Holt', 'Cromer'),
    ('Fakenham', 'Wells_Next_The_Sea'),
    ('Hunstanton', 'Kings_Lynn'),
    ('Brandon', 'Thetford'),
    ('Great_Yarmouth', 'Caister-on-Sea'),
    ('Great_Yarmouth', 'Lowestoft'),
    ('Norwich', 'Beccles'),
    ('Norwich', 'Bungay'),
    ('Watton', 'Thetford'),
    ('Attleborough', 'Norwich'),
    ('Reepham', 'Norwich'),
    ('Cromer', 'Aylsham'),
    # essex:
    ('Tiptree', 'Colchester'),
    ('Halstead', 'Braintree'),
    ('Great_Dunmow', 'Braintree'),
    ('Great_Dunmow', 'Bishops_Stortford'),
    ('Brightlingsea', 'Colchester'),
    ('West_Mersea', 'Colchester'),
    ('Maldon', 'Chelmsford'),
    ('Maldon', 'South_Woodham_Ferrers'),
    ('Saffron_Walden', 'Bishops_Stortford'),
    ('Braintree', 'Sudbury'),
    ('Epping', 'Harlow'),
    ('Harlow', 'Chelmsford'),
]

# %%
# function that gets all the bus routes
# I bet this will spring an error but let's see how we roll...

def get_trips(n):
    trips = n.schedule.route_trips_to_dataframe().sort_values(['route_id', 'trip_departure_time']).reset_index(drop=True)
    trips['mode'] = trips['route_id'].apply(lambda x: n.schedule.graph().graph['routes'][x]['mode'])
    trips = trips[trips['mode'] == 'bus']
    return trips

# %%
trips = get_trips(n)
trips.head()

# that looks right!
# Out:
# 2025-12-09 15:36:33,284 - `route_trips_to_dataframe` method is deprecated and will be replaced by `trips_to_dataframe`in later versions.
#   service_id route_id mode                                     trip_id  \
# 0      10073  10073_0  bus  VJ578e53fa77a4da4b91eaba1d29ea42619687e1bf
# 1      10073  10073_0  bus  VJ28a063c007ab312989e2796dac4d7ea6c33757e4
# 2      10073  10073_0  bus  VJ12d2cf0235fb7fe5692ca330c2c2ff3a18e01ad9
# 3      10073  10073_0  bus  VJd546855afffba33bc947b26c547b9e073fef5d27
# 4      10073  10073_0  bus  VJ852d78aa1252a2da6b5803fac389c660b39d3b47
#
#   trip_departure_time     vehicle_id
# 0 1970-01-01 07:22:00  veh_14970_bus
# 1 1970-01-01 07:52:00  veh_14965_bus
# 2 1970-01-01 08:22:00  veh_14964_bus
# 3 1970-01-01 08:52:00  veh_14979_bus
# 4 1970-01-01 09:22:00  veh_14974_bus

# %%
trips_with_stops = n.schedule.route_trips_with_stops_to_dataframe()
trips_with_stops.head()
# Out:
# 2025-12-09 15:36:33,635 - `route_trips_with_stops_to_dataframe` method is deprecated and will be replaced by `trips_to_dataframe` in later versions.
#   route_name        arrival_time     to_stop      departure_time mode  \
# 0         44 1970-01-01 17:24:00  1590012401 1970-01-01 17:22:00  bus
# 1         44 1970-01-01 17:27:36  1590703601 1970-01-01 17:24:00  bus
# 2         44 1970-01-01 17:29:00  1590048301 1970-01-01 17:27:36  bus
# 3         44 1970-01-01 17:34:41  1590002001 1970-01-01 17:29:00  bus
# 4         44 1970-01-01 17:36:00  1590002101 1970-01-01 17:34:41  bus
#
#   route_id    from_stop  from_stop_name service_id service_name  \
# 0  10073_0  159G0060101        Lakeside      10073           44
# 1  10073_0   1590012401           Tesco      10073           44
# 2  10073_0   1590703601     Armour Road      10073           44
# 3  10073_0   1590048301  Watts Crescent      10073           44
# 4  10073_0   1590002001   Marlow Avenue      10073           44
#
#      to_stop_name                                     trip_id     vehicle_id
# 0           Tesco  VJ0095e1ed14f6ca86df9c9defe42d349438f26b5e  veh_14960_bus
# 1     Armour Road  VJ0095e1ed14f6ca86df9c9defe42d349438f26b5e  veh_14960_bus
# 2  Watts Crescent  VJ0095e1ed14f6ca86df9c9defe42d349438f26b5e  veh_14960_bus
# 3   Marlow Avenue  VJ0095e1ed14f6ca86df9c9defe42d349438f26b5e  veh_14960_bus
# 4   Saladin Drive  VJ0095e1ed14f6ca86df9c9defe42d349438f26b5e  veh_14960_bus

# %% [markdown]
# We will compute typical bus speeds and use it to inform arrival and departure offsets for the new services
# $$
# speed = \frac{distance}{time}
# $$
# for all existing services and then
# $$
# time = \frac{distance}{speed}
# $$

# %%
from genet.utils import spatial

# %%
# ok so we're getting an error where the from_ or to_ stop is not an integer

# the best solution would be to get rid of any entry that doesn't qualify as an integer, and just use the remainder of the dataset

# the only way to tell that's the case is to pick up on the ones that contain *only numbers*:

# the below code fixes the problem, but cuts out a lot of data - I've killed it for now

# trips_with_stops = trips_with_stops[
#     trips_with_stops['from_stop'].apply(lambda x: str(x).isdigit()) &
#     trips_with_stops['to_stop'].apply(lambda x: str(x).isdigit())
# ]

# %%
# test that we can pull out lat and long

n.schedule.stop_attribute_data(keys=["lat","lon","id"]).head()
# Out:
#                    lat       lon           id
# 910GPBRO     52.574993 -0.249823     910GPBRO
# 910GTHETFD   52.419144  0.745098   910GTHETFD
# 910GATTLBON  52.514568  1.022371  910GATTLBON
# 910GWYMNDHM  52.565434  1.118048  910GWYMNDHM
# 910GNRCH     52.627178  1.306844     910GNRCH

# %%
# again, but bigger this time

lat_lon = n.schedule.stop_attribute_data(keys=["lat","lon","id"])

# %%
# then, merge that into the trips_with_stops df using id:

# first to_stop

lat_lon_to = lat_lon.rename(columns={'id':'to_stop', 'lat':'to_lat', 'lon':'to_lon'})

# then, merge that into the trips_with_stops df using id
trips_with_stops = trips_with_stops.merge(
    lat_lon_to[['to_stop', 'to_lat', 'to_lon']],
    on='to_stop',
    how='left'
)

# then, from_stop

lat_lon_from = lat_lon.rename(columns={'id':'from_stop', 'lat':'from_lat', 'lon':'from_lon'})

# then, merge that into the trips_with_stops df using id
trips_with_stops = trips_with_stops.merge(
    lat_lon_from[['from_stop', 'from_lat', 'from_lon']],
    on='from_stop',
    how='left'
)

# %%
# original code threw errors because some ids aren't just integers so can't be called

# trips_with_stops['distance'] = trips_with_stops.apply(
    # lambda x: spatial.distance_between_s2cellids(int(x['from_stop']), int(x['to_stop'])),
    # axis=1
# )

# new code uses a haversine function instead 

import numpy as np

APPROX_EARTH_RADIUS = 6371008.8

def haversine(lat1, lon1, lat2, lon2, R=APPROX_EARTH_RADIUS):
    # expects degrees
    lat1, lon1, lat2, lon2 = map(np.radians, (lat1, lon1, lat2, lon2))
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = np.sin(dlat / 2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2.0)**2
    return 2 * R * np.arcsin(np.sqrt(a))

# ensure numeric and drop rows with missing coords
coords = ['from_lat','from_lon','to_lat','to_lon']
trips_with_stops[coords] = trips_with_stops[coords].apply(pd.to_numeric, errors='coerce')
trips_with_stops = trips_with_stops.dropna(subset=coords)

trips_with_stops['distance'] = trips_with_stops.apply(
    lambda x: haversine(x['from_lat'], x['from_lon'], x['to_lat'], x['to_lon']),
    axis=1
)

# %%
# horrible but necessary code to convert bng to lat, long:

# Converts eastings and northings (British national grid coordinates) to Lat/Long


from math import sqrt, pi, sin, cos, tan, atan2 as arctan2
import csv

def OSGB36toWGS84(E, N):
    # E, N are the British national grid coordinates - eastings and northings
    # The Airy 180 semi-major and semi-minor axes used for OSGB36 (m)
    a, b = 6377563.396, 6356256.909
    F0 = 0.9996012717  # scale factor on the central meridian
    lat0 = 49 * pi / 180  # Latitude of true origin (radians)
    # Longtitude of true origin and central meridian (radians)
    lon0 = -2 * pi / 180
    N0, E0 = -100000, 400000  # Northing & easting of true origin (m)
    e2 = 1 - (b * b) / (a * a)  # eccentricity squared
    n = (a - b) / (a + b)

    # Initialise the iterative variables
    lat, M = lat0, 0

    while N - N0 - M >= 0.00001:  # Accurate to 0.01mm
        lat = (N - N0 - M) / (a * F0) + lat
        M1 = (1 + n + (5. / 4) * n**2 + (5. / 4) * n**3) * (lat - lat0)
        M2 = (3 * n + 3 * n**2 + (21. / 8) * n**3) * \
            sin(lat - lat0) * cos(lat + lat0)
        M3 = ((15. / 8) * n**2 + (15. / 8) * n**3) * \
            sin(2 * (lat - lat0)) * cos(2 * (lat + lat0))
        M4 = (35. / 24) * n**3 * sin(3 * (lat - lat0)) * cos(3 * (lat + lat0))
        # meridional arc
        M = b * F0 * (M1 - M2 + M3 - M4)

    # transverse radius of curvature
    nu = a * F0 / sqrt(1 - e2 * sin(lat)**2)

    # meridional radius of curvature
    rho = a * F0 * (1 - e2) * (1 - e2 * sin(lat)**2)**(-1.5)
    eta2 = nu / rho - 1

    secLat = 1. / cos(lat)
    VII = tan(lat) / (2 * rho * nu)
    VIII = tan(lat) / (24 * rho * nu**3) * \
        (5 + 3 * tan(lat)**2 + eta2 - 9 * tan(lat)**2 * eta2)
    IX = tan(lat) / (720 * rho * nu**5) * \
        (61 + 90 * tan(lat)**2 + 45 * tan(lat)**4)
    X = secLat / nu
    XI = secLat / (6 * nu**3) * (nu / rho + 2 * tan(lat)**2)
    XII = secLat / (120 * nu**5) * (5 + 28 * tan(lat)**2 + 24 * tan(lat)**4)
    XIIA = secLat / (5040 * nu**7) * (61 + 662 * tan(lat) **
                                      2 + 1320 * tan(lat)**4 + 720 * tan(lat)**6)
    dE = E - E0

    # These are on the wrong ellipsoid currently: Airy1830. (Denoted by _1)
    lat_1 = lat - VII * dE**2 + VIII * dE**4 - IX * dE**6
    lon_1 = lon0 + X * dE - XI * dE**3 + XII * dE**5 - XIIA * dE**7

    # Want to convert to the GRS80 ellipsoid.
    # First convert to cartesian from spherical polar coordinates
    H = 0  # Third spherical coord.
    x_1 = (nu / F0 + H) * cos(lat_1) * cos(lon_1)
    y_1 = (nu / F0 + H) * cos(lat_1) * sin(lon_1)
    z_1 = ((1 - e2) * nu / F0 + H) * sin(lat_1)

    # Perform Helmut transform (to go between Airy 1830 (_1) and GRS80 (_2))
    s = -20.4894 * 10**-6  # The scale factor -1
    # The translations along x,y,z axes respectively
    tx, ty, tz = 446.448, -125.157, + 542.060
    # The rotations along x,y,z respectively, in seconds
    rxs, rys, rzs = 0.1502,  0.2470,  0.8421
    rx, ry, rz = rxs * pi / (180 * 3600.), rys * pi / \
        (180 * 3600.), rzs * pi / (180 * 3600.)  # In radians
    x_2 = tx + (1 + s) * x_1 + (-rz) * y_1 + (ry) * z_1
    y_2 = ty + (rz) * x_1 + (1 + s) * y_1 + (-rx) * z_1
    z_2 = tz + (-ry) * x_1 + (rx) * y_1 + (1 + s) * z_1

    # Back to spherical polar coordinates from cartesian
    # Need some of the characteristics of the new ellipsoid
    # The GSR80 semi-major and semi-minor axes used for WGS84(m)
    a_2, b_2 = 6378137.000, 6356752.3141
    # The eccentricity of the GRS80 ellipsoid
    e2_2 = 1 - (b_2 * b_2) / (a_2 * a_2)
    p = sqrt(x_2**2 + y_2**2)

    # Lat is obtained by an iterative proceedure:
    lat = arctan2(z_2, (p * (1 - e2_2)))  # Initial value
    latold = 2 * pi
    while abs(lat - latold) > 10**-16:
        lat, latold = latold, lat
        nu_2 = a_2 / sqrt(1 - e2_2 * sin(latold)**2)
        lat = arctan2(z_2 + e2_2 * nu_2 * sin(latold), p)

    # Lon and height are then pretty easy
    lon = arctan2(y_2, x_2)
    H = p / cos(lat) - nu_2

    # Uncomment this line if you want to print the results
    # print([(lat-lat_1)*180/pi, (lon - lon_1)*180/pi])

    # Convert to degrees
    lat = lat * 180 / pi
    lon = lon * 180 / pi

    # Job's a good'n.
    return lat, lon

# %%
trips_with_stops['time_delta'] = trips_with_stops['arrival_time'] - trips_with_stops['departure_time']
trips_with_stops['time_delta'] = trips_with_stops['time_delta'].dt.total_seconds()

# %%
trips_with_stops = trips_with_stops[trips_with_stops['time_delta'] != 0]

# %%
trips_with_stops['speed'] = trips_with_stops['distance'] / trips_with_stops['time_delta']

# %%
trips_with_stops.head()
# Out:
#   route_name        arrival_time     to_stop      departure_time mode  \
# 0         44 1970-01-01 17:24:00  1590012401 1970-01-01 17:22:00  bus
# 1         44 1970-01-01 17:27:36  1590703601 1970-01-01 17:24:00  bus
# 2         44 1970-01-01 17:29:00  1590048301 1970-01-01 17:27:36  bus
# 3         44 1970-01-01 17:34:41  1590002001 1970-01-01 17:29:00  bus
# 4         44 1970-01-01 17:36:00  1590002101 1970-01-01 17:34:41  bus
#
#   route_id    from_stop  from_stop_name service_id service_name  \
# 0  10073_0  159G0060101        Lakeside      10073           44
# 1  10073_0   1590012401           Tesco      10073           44
# 2  10073_0   1590703601     Armour Road      10073           44
# 3  10073_0   1590048301  Watts Crescent      10073           44
# 4  10073_0   1590002001   Marlow Avenue      10073           44
#
#      to_stop_name                                     trip_id     vehicle_id  \
# 0           Tesco  VJ0095e1ed14f6ca86df9c9defe42d349438f26b5e  veh_14960_bus
# 1     Armour Road  VJ0095e1ed14f6ca86df9c9defe42d349438f26b5e  veh_14960_bus
# 2  Watts Crescent  VJ0095e1ed14f6ca86df9c9defe42d349438f26b5e  veh_14960_bus
# 3   Marlow Avenue  VJ0095e1ed14f6ca86df9c9defe42d349438f26b5e  veh_14960_bus
# 4   Saladin Drive  VJ0095e1ed14f6ca86df9c9defe42d349438f26b5e  veh_14960_bus
#
#       to_lat    to_lon   from_lat  from_lon     distance  time_delta     speed
# 0  51.488010  0.274086  51.490292  0.283074   672.047665       120.0  5.600397
# 1  51.486172  0.256709  51.488010  0.274086  1220.420974       216.0  5.650097
# 2  51.485840  0.249938  51.486172  0.256709   470.287536        84.0  5.598661
# 3  51.488251  0.233635  51.485840  0.249938  1160.222268       341.0  3.402411
# 4  51.486038  0.232072  51.488251  0.233635   268.821170        79.0  3.402800

# %%
trips_with_stops['speed'].describe()

# max speed is clearly an error, but I'm prepared to broadly credit this dataset.
# Out:
# count    868075.000000
# mean          6.265960
# std           3.623215
# min           0.005612
# 25%           4.119974
# 50%           5.507079
# 75%           7.478403
# max         249.643455
# Name: speed, dtype: float64

# %%
import time
speed = 6.265
from_stop = market_town_links[0][0]
to_stop = market_town_links[0][1]

import xml.etree.ElementTree as ET

# Get the config:

sched_raw = ET.parse("/mnt/c/_BERTIE_data/2_2040_do_minimum_40WFH/output_transitSchedule.xml")

sched_root = sched_raw.getroot()

# new and exciting distance calculator:

for transitstops in sched_root.findall("transitStops"):
    # then drill to stopFacility
    for stopFacility in transitstops.findall("stopFacility"):
        # find the exact one we want
        if stopFacility.get("id") == market_town_stops[from_stop]:
            # then get x, y
            x_val = float(stopFacility.get("x"))
            y_val = float(stopFacility.get("y"))

latlon = OSGB36toWGS84(x_val, y_val)            

for transitstops in sched_root.findall("transitStops"):
    # then drill to stopFacility
    for stopFacility in transitstops.findall("stopFacility"):
        # find the exact one we want
        if stopFacility.get("id") == market_town_stops[to_stop]:
            # then get x, y
            x_val2 = float(stopFacility.get("x"))
            y_val2 = float(stopFacility.get("y"))
 
latlon2 = OSGB36toWGS84(x_val2, y_val2)

# get the number

distance = haversine(latlon[0], latlon[1], latlon2[0], latlon2[1])

# canned this one for obvious reasons:
# distance = spatial.distance_between_s2cellids(int(market_town_stops[from_stop]), int(market_town_stops[to_stop]))

time_s = distance/speed

print(distance)

from_stop, to_stop, time.strftime('%H:%M:%S', time.gmtime(time_s))
# Out:
# ('Aldeburgh', 'Woodbridge', '00:00:00')

# %%
trip_departures = list(pd.date_range(start='00:00:00', end='23:59:59', freq='15min'))

# %%
from genet import Route, Service

def add_service(from_stop, to_stop, stop_dict):
    speed = 6.265
    
    # had to amend this line, because of the earlier issues with non-integer stop ids:

    # ok, so I've finally found a workaround after encountering a mass of non-integer stop ids. 

    # it involves manually using elementtree to extract the x and y of each stop and then haversine-ing the distance.

    # I'd just like Arup to know, whoever constructed distance_between_s2cellids is now my biggest enemy.

    for transitstops in sched_root.findall("transitStops"):
        # then drill to stopFacility
        for stopFacility in transitstops.findall("stopFacility"):
            # find the exact one we want
            if stopFacility.get("id") == stop_dict[from_stop]:
                # then get x, y
                x_val = float(stopFacility.get("x"))
                y_val = float(stopFacility.get("y"))

    latlon = OSGB36toWGS84(x_val, y_val)            

    for transitstops in sched_root.findall("transitStops"):
        # then drill to stopFacility
        for stopFacility in transitstops.findall("stopFacility"):
            # find the exact one we want
            if stopFacility.get("id") == stop_dict[to_stop]:
                # then get x, y
                x_val2 = float(stopFacility.get("x"))
                y_val2 = float(stopFacility.get("y"))
 
    latlon2 = OSGB36toWGS84(x_val2, y_val2)

    # get the number

    distance = haversine(latlon[0], latlon[1], latlon2[0], latlon2[1])

    # now it is working, so the old method is out:

    # distance = spatial.distance_between_s2cellids(int(stop_dict[from_stop]), int(stop_dict[to_stop]))

    # now back to pre-existing code:

    time_offset =  time.strftime('%H:%M:%S', time.gmtime(distance/speed))
    print(type(time_offset))
    trip_departures = list(pd.date_range(start='00:00:00', end='23:59:59', freq='15min'))
    
    service_id = f'service_{from_stop}_{to_stop}'
    
    route_id = f'route_{from_stop}_{to_stop}'
    route_from = Route(
        route_short_name=route_id,
        mode='bus',
        trips={
            'trip_id': [f'{route_id}_{t.hour:02}-{t.minute:02}-{t.second:02}' for t in trip_departures],
            'trip_departure_time': [t.strftime('%H:%M:%S') for t in trip_departures],
            'vehicle_id': [f'veh_scenario_bus_{route_id}_{i}' for i in range(len(trip_departures))]
        },
        arrival_offsets=['00:00:00', time_offset],
        departure_offsets=['00:00:00', time_offset],
        id=route_id,
        await_departure= [True, True],
        stops=[n.schedule.stop(stop_dict[from_stop]), n.schedule.stop(stop_dict[to_stop])]
    )

    route_id = f'route_{to_stop}_{from_stop}'
    route_to = Route(
        route_short_name=route_id,
        mode='bus',
        trips={
            'trip_id': [f'{route_id}_{t.hour:02}-{t.minute:02}-{t.second:02}' for t in trip_departures],
            'trip_departure_time': [t.strftime('%H:%M:%S') for t in trip_departures],
            # this bit should be adding the vehicle id!
            'vehicle_id': [f'veh_scenario_bus_{route_id}_{i}' for i in range(len(trip_departures))]
        },
        arrival_offsets=['00:00:00', time_offset],
        departure_offsets=['00:00:00', time_offset],
        id=route_id,
        await_departure= [True, True],
        stops=[n.schedule.stop(stop_dict[to_stop]), n.schedule.stop(stop_dict[from_stop])]
    )

    print(f'Adding {service_id}. Time offset: {time_offset}')
    n.schedule.add_service(Service(id=service_id, routes=[route_from, route_to]))
    print(f'Routing {service_id}.')
    n.reroute(service_id)
    n.schedule.generate_vehicles()
    return service_id

# %%
# new veh related code

len(n.schedule.vehicles)
# Out:
# 52124

# %%
# realise the new services!!!!

services = []
for market_town_connection in market_town_links:
    s = add_service(
        market_town_connection[0], 
        market_town_connection[1], 
        market_town_stops)
    services.append(s)
# Out:
# <class 'str'>
# Adding service_Aldeburgh_Woodbridge. Time offset: 00:53:47
# 2025-12-09 15:37:01,486 - Added Services with IDs `['service_Aldeburgh_Woodbridge']` and Routes: [['route_Aldeburgh_Woodbridge', 'route_Woodbridge_Aldeburgh']]
# 2025-12-09 15:37:07,153 - Rerouting Service `service_Aldeburgh_Woodbridge`
# 2025-12-09 15:37:07,166 - Checking `linkRefId`s of the Route: `route_Aldeburgh_Woodbridge` are present in the graph
# 2025-12-09 15:37:07,252 - Rerouting Route `route_Aldeburgh_Woodbridge`
# Routing service_Aldeburgh_Woodbridge.
# 2025-12-09 15:37:11,964 - Changed Route attributes for 1 routes
# 2025-12-09 15:37:12,106 - Checking `linkRefId`s of the Route: `route_Woodbridge_Aldeburgh` are present in the graph
# 2025-12-09 15:37:12,179 - Rerouting Route `route_Woodbridge_Aldeburgh`
# 2025-12-09 15:37:16,999 - Changed Route attributes for 1 routes
# 2025-12-09 15:37:22,490 - Added Services with IDs `['service_Bury_St_Edmunds_Beck_Row']` and Routes: [['route_Bury_St_Edmunds_Beck_Row', 'route_Beck_Row_Bury_St_Edmunds']]
# <class 'str'>
# Adding service_Bury_St_Edmunds_Beck_Row. Time offset: 00:55:00
# 2025-12-09 15:37:25,307 - Rerouting Service `service_Bury_St_Edmunds_Beck_Row`
# 2025-12-09 15:37:25,320 - Checking `linkRefId`s of the Route: `route_Bury_St_Edmunds_Beck_Row` are present in the graph
# 2025-12-09 15:37:25,417 - Rerouting Route `route_Bury_St_Edmunds_Beck_Row`
# Routing service_Bury_St_Edmunds_Beck_Row.
# 2025-12-09 15:37:30,182 - Changed Route attributes for 1 routes
# 2025-12-09 15:37:30,350 - Checking `linkRefId`s of the Route: `route_Beck_Row_Bury_St_Edmunds` are present in the graph
# 2025-12-09 15:37:30,436 - Rerouting Route `route_Beck_Row_Bury_St_Edmunds`
# 2025-12-09 15:37:38,264 - Changed Route attributes for 1 routes
# 2025-12-09 15:37:41,340 - Added Services with IDs `['service_Bury_St_Edmunds_Brandon']` and Routes: [['route_Bury_St_Edmunds_Brandon', 'route_Brandon_Bury_St_Edmunds']]
# <class 'str'>
# Adding service_Bury_St_Edmunds_Brandon. Time offset: 01:01:47
# 2025-12-09 15:37:44,113 - Rerouting Service `service_Bury_St_Edmunds_Brandon`
# 2025-12-09 15:37:44,129 - Checking `linkRefId`s of the Route: `route_Bury_St_Edmunds_Brandon` are present in the graph
# 2025-12-09 15:37:44,233 - Rerouting Route `route_Bury_St_Edmunds_Brandon`
# Routing service_Bury_St_Edmunds_Brandon.
# 2025-12-09 15:37:51,808 - Changed Route attributes for 1 routes
# 2025-12-09 15:37:51,965 - Checking `linkRefId`s of the Route: `route_Brandon_Bury_St_Edmunds` are present in the graph
# 2025-12-09 15:37:52,043 - Rerouting Route `route_Brandon_Bury_St_Edmunds`
# 2025-12-09 15:37:57,159 - Changed Route attributes for 1 routes
# 2025-12-09 15:38:00,283 - Added Services with IDs `['service_Bury_St_Edmunds_Elmswell']` and Routes: [['route_Bury_St_Edmunds_Elmswell', 'route_Elmswell_Bury_St_Edmunds']]
# <class 'str'>
# Adding service_Bury_St_Edmunds_Elmswell. Time offset: 00:35:38
# 2025-12-09 15:38:06,179 - Rerouting Service `service_Bury_St_Edmunds_Elmswell`
# 2025-12-09 15:38:06,199 - Checking `linkRefId`s of the Route: `route_Bury_St_Edmunds_Elmswell` are present in the graph
# 2025-12-09 15:38:06,286 - Rerouting Route `route_Bury_St_Edmunds_Elmswell`
# Routing service_Bury_St_Edmunds_Elmswell.
# 2025-12-09 15:38:11,525 - Changed Route attributes for 1 routes
# 2025-12-09 15:38:11,687 - Checking `linkRefId`s of the Route: `route_Elmswell_Bury_St_Edmunds` are present in the graph
# 2025-12-09 15:38:11,772 - Rerouting Route `route_Elmswell_Bury_St_Edmunds`
# 2025-12-09 15:38:16,866 - Changed Route attributes for 1 routes
# 2025-12-09 15:38:22,406 - Added Services with IDs `['service_Bury_St_Edmunds_Haverhill']` and Routes: [['route_Bury_St_Edmunds_Haverhill', 'route_Haverhill_Bury_St_Edmunds']]
# <class 'str'>
# Adding service_Bury_St_Edmunds_Haverhill. Time offset: 01:09:58
# 2025-12-09 15:38:25,362 - Rerouting Service `service_Bury_St_Edmunds_Haverhill`
# 2025-12-09 15:38:25,373 - Checking `linkRefId`s of the Route: `route_Bury_St_Edmunds_Haverhill` are present in the graph
# 2025-12-09 15:38:25,465 - Rerouting Route `route_Bury_St_Edmunds_Haverhill`
# Routing service_Bury_St_Edmunds_Haverhill.
# 2025-12-09 15:38:30,491 - Changed Route attributes for 1 routes
# 2025-12-09 15:38:30,639 - Checking `linkRefId`s of the Route: `route_Haverhill_Bury_St_Edmunds` are present in the graph
# 2025-12-09 15:38:30,716 - Rerouting Route `route_Haverhill_Bury_St_Edmunds`
# 2025-12-09 15:38:35,392 - Changed Route attributes for 1 routes
# 2025-12-09 15:38:41,091 - Added Services with IDs `['service_Bury_St_Edmunds_Ixworth']` and Routes: [['route_Bury_St_Edmunds_Ixworth', 'route_Ixworth_Bury_St_Edmunds']]
# <class 'str'>
# Adding service_Bury_St_Edmunds_Ixworth. Time offset: 00:26:36
# 2025-12-09 15:38:43,868 - Rerouting Service `service_Bury_St_Edmunds_Ixworth`
# 2025-12-09 15:38:43,882 - Checking `linkRefId`s of the Route: `route_Bury_St_Edmunds_Ixworth` are present in the graph
# 2025-12-09 15:38:43,966 - Rerouting Route `route_Bury_St_Edmunds_Ixworth`
# Routing service_Bury_St_Edmunds_Ixworth.
# 2025-12-09 15:38:48,865 - Changed Route attributes for 1 routes
# 2025-12-09 15:38:49,032 - Checking `linkRefId`s of the Route: `route_Ixworth_Bury_St_Edmunds` are present in the graph
# 2025-12-09 15:38:49,113 - Rerouting Route `route_Ixworth_Bury_St_Edmunds`
# 2025-12-09 15:38:56,632 - Changed Route attributes for 1 routes
# 2025-12-09 15:38:59,651 - Added Services with IDs `['service_Bury_St_Edmunds_Long_Melford']` and Routes: [['route_Bury_St_Edmunds_Long_Melford', 'route_Long_Melford_Bury_St_Edmunds']]
# <class 'str'>
# Adding service_Bury_St_Edmunds_Long_Melford. Time offset: 00:50:26
# 2025-12-09 15:39:02,461 - Rerouting Service `service_Bury_St_Edmunds_Long_Melford`
# 2025-12-09 15:39:02,475 - Checking `linkRefId`s of the Route: `route_Bury_St_Edmunds_Long_Melford` are present in the graph
# 2025-12-09 15:39:02,557 - Rerouting Route `route_Bury_St_Edmunds_Long_Melford`
# Routing service_Bury_St_Edmunds_Long_Melford.
# 2025-12-09 15:39:10,252 - Changed Route attributes for 1 routes
# 2025-12-09 15:39:10,409 - Checking `linkRefId`s of the Route: `route_Long_Melford_Bury_St_Edmunds` are present in the graph
# 2025-12-09 15:39:10,485 - Rerouting Route `route_Long_Melford_Bury_St_Edmunds`
# 2025-12-09 15:39:15,460 - Changed Route attributes for 1 routes
# 2025-12-09 15:39:18,985 - Added Services with IDs `['service_Bury_St_Edmunds_Mildenhall']` and Routes: [['route_Bury_St_Edmunds_Mildenhall', 'route_Mildenhall_Bury_St_Edmunds']]
# <class 'str'>
# Adding service_Bury_St_Edmunds_Mildenhall. Time offset: 00:47:00
# 2025-12-09 15:39:24,340 - Rerouting Service `service_Bury_St_Edmunds_Mildenhall`
# 2025-12-09 15:39:24,355 - Checking `linkRefId`s of the Route: `route_Bury_St_Edmunds_Mildenhall` are present in the graph
# 2025-12-09 15:39:24,440 - Rerouting Route `route_Bury_St_Edmunds_Mildenhall`
# Routing service_Bury_St_Edmunds_Mildenhall.
# 2025-12-09 15:39:29,530 - Changed Route attributes for 1 routes
# 2025-12-09 15:39:29,689 - Checking `linkRefId`s of the Route: `route_Mildenhall_Bury_St_Edmunds` are present in the graph
# 2025-12-09 15:39:29,765 - Rerouting Route `route_Mildenhall_Bury_St_Edmunds`
# 2025-12-09 15:39:35,007 - Changed Route attributes for 1 routes
# 2025-12-09 15:39:38,359 - Added Services with IDs `['service_Bury_St_Edmunds_Newmarket']` and Routes: [['route_Bury_St_Edmunds_Newmarket', 'route_Newmarket_Bury_St_Edmunds']]
# <class 'str'>
# Adding service_Bury_St_Edmunds_Newmarket. Time offset: 00:56:19
# 2025-12-09 15:39:44,714 - Rerouting Service `service_Bury_St_Edmunds_Newmarket`
# 2025-12-09 15:39:44,724 - Checking `linkRefId`s of the Route: `route_Bury_St_Edmunds_Newmarket` are present in the graph
# 2025-12-09 15:39:44,807 - Rerouting Route `route_Bury_St_Edmunds_Newmarket`
# Routing service_Bury_St_Edmunds_Newmarket.
# 2025-12-09 15:39:49,769 - Changed Route attributes for 1 routes
# 2025-12-09 15:39:49,920 - Checking `linkRefId`s of the Route: `route_Newmarket_Bury_St_Edmunds` are present in the graph
# 2025-12-09 15:39:50,000 - Rerouting Route `route_Newmarket_Bury_St_Edmunds`
# 2025-12-09 15:39:55,061 - Changed Route attributes for 1 routes
# 2025-12-09 15:40:00,700 - Added Services with IDs `['service_Bury_St_Edmunds_Stowmarket']` and Routes: [['route_Bury_St_Edmunds_Stowmarket', 'route_Stowmarket_Bury_St_Edmunds']]
# <class 'str'>
# Adding service_Bury_St_Edmunds_Stowmarket. Time offset: 00:53:35
# 2025-12-09 15:40:03,552 - Rerouting Service `service_Bury_St_Edmunds_Stowmarket`
# 2025-12-09 15:40:03,562 - Checking `linkRefId`s of the Route: `route_Bury_St_Edmunds_Stowmarket` are present in the graph
# 2025-12-09 15:40:03,659 - Rerouting Route `route_Bury_St_Edmunds_Stowmarket`
# Routing service_Bury_St_Edmunds_Stowmarket.
# 2025-12-09 15:40:08,487 - Changed Route attributes for 1 routes
# 2025-12-09 15:40:08,689 - Checking `linkRefId`s of the Route: `route_Stowmarket_Bury_St_Edmunds` are present in the graph
# 2025-12-09 15:40:08,771 - Rerouting Route `route_Stowmarket_Bury_St_Edmunds`
# 2025-12-09 15:40:17,004 - Changed Route attributes for 1 routes
# 2025-12-09 15:40:20,259 - Added Services with IDs `['service_Bury_St_Edmunds_Sudbury']` and Routes: [['route_Bury_St_Edmunds_Sudbury', 'route_Sudbury_Bury_St_Edmunds']]
# <class 'str'>
# Adding service_Bury_St_Edmunds_Sudbury. Time offset: 01:01:05
# 2025-12-09 15:40:23,141 - Rerouting Service `service_Bury_St_Edmunds_Sudbury`
# 2025-12-09 15:40:23,157 - Checking `linkRefId`s of the Route: `route_Bury_St_Edmunds_Sudbury` are present in the graph
# 2025-12-09 15:40:23,250 - Rerouting Route `route_Bury_St_Edmunds_Sudbury`
# Routing service_Bury_St_Edmunds_Sudbury.
# 2025-12-09 15:40:30,881 - Changed Route attributes for 1 routes
# 2025-12-09 15:40:31,065 - Checking `linkRefId`s of the Route: `route_Sudbury_Bury_St_Edmunds` are present in the graph
# 2025-12-09 15:40:31,156 - Rerouting Route `route_Sudbury_Bury_St_Edmunds`
# 2025-12-09 15:40:36,591 - Changed Route attributes for 1 routes
# 2025-12-09 15:40:39,703 - Added Services with IDs `['service_Bury_St_Edmunds_Thurston']` and Routes: [['route_Bury_St_Edmunds_Thurston', 'route_Thurston_Bury_St_Edmunds']]
# <class 'str'>
# Adding service_Bury_St_Edmunds_Thurston. Time offset: 00:16:38
# 2025-12-09 15:40:45,198 - Rerouting Service `service_Bury_St_Edmunds_Thurston`
# 2025-12-09 15:40:45,210 - Checking `linkRefId`s of the Route: `route_Bury_St_Edmunds_Thurston` are present in the graph
# 2025-12-09 15:40:45,293 - Rerouting Route `route_Bury_St_Edmunds_Thurston`
# Routing service_Bury_St_Edmunds_Thurston.
# 2025-12-09 15:40:50,354 - Changed Route attributes for 1 routes
# 2025-12-09 15:40:50,527 - Checking `linkRefId`s of the Route: `route_Thurston_Bury_St_Edmunds` are present in the graph
# 2025-12-09 15:40:50,608 - Rerouting Route `route_Thurston_Bury_St_Edmunds`
# 2025-12-09 15:40:55,493 - Changed Route attributes for 1 routes
# 2025-12-09 15:41:00,975 - Added Services with IDs `['service_Capel_St_Mary_Hadleigh']` and Routes: [['route_Capel_St_Mary_Hadleigh', 'route_Hadleigh_Capel_St_Mary']]
# <class 'str'>
# Adding service_Capel_St_Mary_Hadleigh. Time offset: 00:22:16
# 2025-12-09 15:41:03,733 - Rerouting Service `service_Capel_St_Mary_Hadleigh`
# 2025-12-09 15:41:03,743 - Checking `linkRefId`s of the Route: `route_Capel_St_Mary_Hadleigh` are present in the graph
# 2025-12-09 15:41:03,826 - Rerouting Route `route_Capel_St_Mary_Hadleigh`
# Routing service_Capel_St_Mary_Hadleigh.
# 2025-12-09 15:41:08,694 - Changed Route attributes for 1 routes
# 2025-12-09 15:41:08,867 - Checking `linkRefId`s of the Route: `route_Hadleigh_Capel_St_Mary` are present in the graph
# 2025-12-09 15:41:08,949 - Rerouting Route `route_Hadleigh_Capel_St_Mary`
# 2025-12-09 15:41:13,990 - Changed Route attributes for 1 routes
# 2025-12-09 15:41:19,912 - Added Services with IDs `['service_Clare_Haverhill']` and Routes: [['route_Clare_Haverhill', 'route_Haverhill_Clare']]
# <class 'str'>
# Adding service_Clare_Haverhill. Time offset: 00:25:33
# 2025-12-09 15:41:22,760 - Rerouting Service `service_Clare_Haverhill`
# 2025-12-09 15:41:22,773 - Checking `linkRefId`s of the Route: `route_Clare_Haverhill` are present in the graph
# 2025-12-09 15:41:22,859 - Rerouting Route `route_Clare_Haverhill`
# Routing service_Clare_Haverhill.
# 2025-12-09 15:41:31,139 - Changed Route attributes for 1 routes
# 2025-12-09 15:41:31,308 - Checking `linkRefId`s of the Route: `route_Haverhill_Clare` are present in the graph
# 2025-12-09 15:41:31,388 - Rerouting Route `route_Haverhill_Clare`
# 2025-12-09 15:41:36,298 - Changed Route attributes for 1 routes
# 2025-12-09 15:41:39,290 - Added Services with IDs `['service_East_Bergholt_Hadleigh']` and Routes: [['route_East_Bergholt_Hadleigh', 'route_Hadleigh_East_Bergholt']]
# <class 'str'>
# Adding service_East_Bergholt_Hadleigh. Time offset: 00:22:51
# 2025-12-09 15:41:45,219 - Rerouting Service `service_East_Bergholt_Hadleigh`
# 2025-12-09 15:41:45,231 - Checking `linkRefId`s of the Route: `route_East_Bergholt_Hadleigh` are present in the graph
# 2025-12-09 15:41:45,314 - Rerouting Route `route_East_Bergholt_Hadleigh`
# Routing service_East_Bergholt_Hadleigh.
# 2025-12-09 15:41:50,389 - Changed Route attributes for 1 routes
# 2025-12-09 15:41:50,561 - Checking `linkRefId`s of the Route: `route_Hadleigh_East_Bergholt` are present in the graph
# 2025-12-09 15:41:50,637 - Rerouting Route `route_Hadleigh_East_Bergholt`
# 2025-12-09 15:41:55,415 - Changed Route attributes for 1 routes
# 2025-12-09 15:41:58,648 - Added Services with IDs `['service_Eye_Stowmarket']` and Routes: [['route_Eye_Stowmarket', 'route_Stowmarket_Eye']]
# <class 'str'>
# Adding service_Eye_Stowmarket. Time offset: 00:48:11
# 2025-12-09 15:42:03,885 - Rerouting Service `service_Eye_Stowmarket`
# 2025-12-09 15:42:03,897 - Checking `linkRefId`s of the Route: `route_Eye_Stowmarket` are present in the graph
# 2025-12-09 15:42:03,985 - Rerouting Route `route_Eye_Stowmarket`
# Routing service_Eye_Stowmarket.
# 2025-12-09 15:42:09,288 - Changed Route attributes for 1 routes
# 2025-12-09 15:42:09,470 - Checking `linkRefId`s of the Route: `route_Stowmarket_Eye` are present in the graph
# 2025-12-09 15:42:09,562 - Rerouting Route `route_Stowmarket_Eye`
# 2025-12-09 15:42:14,643 - Changed Route attributes for 1 routes
# 2025-12-09 15:42:20,770 - Added Services with IDs `['service_Ipswich_Felixstowe']` and Routes: [['route_Ipswich_Felixstowe', 'route_Felixstowe_Ipswich']]
# <class 'str'>
# Adding service_Ipswich_Felixstowe. Time offset: 00:44:49
# 2025-12-09 15:42:23,714 - Rerouting Service `service_Ipswich_Felixstowe`
# 2025-12-09 15:42:23,726 - Checking `linkRefId`s of the Route: `route_Ipswich_Felixstowe` are present in the graph
# 2025-12-09 15:42:23,810 - Rerouting Route `route_Ipswich_Felixstowe`
# Routing service_Ipswich_Felixstowe.
# 2025-12-09 15:42:28,786 - Changed Route attributes for 1 routes
# 2025-12-09 15:42:28,947 - Checking `linkRefId`s of the Route: `route_Felixstowe_Ipswich` are present in the graph
# 2025-12-09 15:42:29,036 - Rerouting Route `route_Felixstowe_Ipswich`
# 2025-12-09 15:42:36,092 - Changed Route attributes for 1 routes
# 2025-12-09 15:42:39,183 - Added Services with IDs `['service_Ipswich_Framlingham']` and Routes: [['route_Ipswich_Framlingham', 'route_Framlingham_Ipswich']]
# <class 'str'>
# Adding service_Ipswich_Framlingham. Time offset: 00:59:16
# 2025-12-09 15:42:41,988 - Rerouting Service `service_Ipswich_Framlingham`
# 2025-12-09 15:42:41,997 - Checking `linkRefId`s of the Route: `route_Ipswich_Framlingham` are present in the graph
# 2025-12-09 15:42:42,078 - Rerouting Route `route_Ipswich_Framlingham`
# Routing service_Ipswich_Framlingham.
# 2025-12-09 15:42:49,914 - Changed Route attributes for 1 routes
# 2025-12-09 15:42:50,078 - Checking `linkRefId`s of the Route: `route_Framlingham_Ipswich` are present in the graph
# 2025-12-09 15:42:50,157 - Rerouting Route `route_Framlingham_Ipswich`
# 2025-12-09 15:42:55,063 - Changed Route attributes for 1 routes
# 2025-12-09 15:42:58,260 - Added Services with IDs `['service_Ipswich_Hadleigh']` and Routes: [['route_Ipswich_Hadleigh', 'route_Hadleigh_Ipswich']]
# <class 'str'>
# Adding service_Ipswich_Hadleigh. Time offset: 00:37:03
# 2025-12-09 15:43:04,309 - Rerouting Service `service_Ipswich_Hadleigh`
# 2025-12-09 15:43:04,323 - Checking `linkRefId`s of the Route: `route_Ipswich_Hadleigh` are present in the graph
# 2025-12-09 15:43:04,413 - Rerouting Route `route_Ipswich_Hadleigh`
# Routing service_Ipswich_Hadleigh.
# 2025-12-09 15:43:09,230 - Changed Route attributes for 1 routes
# 2025-12-09 15:43:09,385 - Checking `linkRefId`s of the Route: `route_Hadleigh_Ipswich` are present in the graph
# 2025-12-09 15:43:09,466 - Rerouting Route `route_Hadleigh_Ipswich`
# 2025-12-09 15:43:14,255 - Changed Route attributes for 1 routes
# 2025-12-09 15:43:20,348 - Added Services with IDs `['service_Ipswich_Leiston']` and Routes: [['route_Ipswich_Leiston', 'route_Leiston_Ipswich']]
# <class 'str'>
# Adding service_Ipswich_Leiston. Time offset: 01:28:18
# 2025-12-09 15:43:23,418 - Rerouting Service `service_Ipswich_Leiston`
# 2025-12-09 15:43:23,430 - Checking `linkRefId`s of the Route: `route_Ipswich_Leiston` are present in the graph
# 2025-12-09 15:43:23,522 - Rerouting Route `route_Ipswich_Leiston`
# Routing service_Ipswich_Leiston.
# 2025-12-09 15:43:28,753 - Changed Route attributes for 1 routes
# 2025-12-09 15:43:28,924 - Checking `linkRefId`s of the Route: `route_Leiston_Ipswich` are present in the graph
# 2025-12-09 15:43:29,004 - Rerouting Route `route_Leiston_Ipswich`
# 2025-12-09 15:43:33,950 - Changed Route attributes for 1 routes
# 2025-12-09 15:43:39,545 - Added Services with IDs `['service_Ipswich_Needham_Market']` and Routes: [['route_Ipswich_Needham_Market', 'route_Needham_Market_Ipswich']]
# <class 'str'>
# Adding service_Ipswich_Needham_Market. Time offset: 00:34:06
# 2025-12-09 15:43:42,701 - Rerouting Service `service_Ipswich_Needham_Market`
# 2025-12-09 15:43:42,712 - Checking `linkRefId`s of the Route: `route_Ipswich_Needham_Market` are present in the graph
# 2025-12-09 15:43:42,805 - Rerouting Route `route_Ipswich_Needham_Market`
# Routing service_Ipswich_Needham_Market.
# 2025-12-09 15:43:47,928 - Changed Route attributes for 1 routes
# 2025-12-09 15:43:48,093 - Checking `linkRefId`s of the Route: `route_Needham_Market_Ipswich` are present in the graph
# 2025-12-09 15:43:48,173 - Rerouting Route `route_Needham_Market_Ipswich`
# 2025-12-09 15:43:55,807 - Changed Route attributes for 1 routes
# 2025-12-09 15:43:58,870 - Added Services with IDs `['service_Ipswich_Rendlesham']` and Routes: [['route_Ipswich_Rendlesham', 'route_Rendlesham_Ipswich']]
# <class 'str'>
# Adding service_Ipswich_Rendlesham. Time offset: 00:51:11
# 2025-12-09 15:44:01,892 - Rerouting Service `service_Ipswich_Rendlesham`
# 2025-12-09 15:44:01,903 - Checking `linkRefId`s of the Route: `route_Ipswich_Rendlesham` are present in the graph
# 2025-12-09 15:44:02,006 - Rerouting Route `route_Ipswich_Rendlesham`
# Routing service_Ipswich_Rendlesham.
# 2025-12-09 15:44:09,560 - Changed Route attributes for 1 routes
# 2025-12-09 15:44:09,757 - Checking `linkRefId`s of the Route: `route_Rendlesham_Ipswich` are present in the graph
# 2025-12-09 15:44:09,838 - Rerouting Route `route_Rendlesham_Ipswich`
# 2025-12-09 15:44:14,759 - Changed Route attributes for 1 routes
# 2025-12-09 15:44:18,158 - Added Services with IDs `['service_Ipswich_Saxmundham']` and Routes: [['route_Ipswich_Saxmundham', 'route_Saxmundham_Ipswich']]
# <class 'str'>
# Adding service_Ipswich_Saxmundham. Time offset: 01:16:33
# 2025-12-09 15:44:24,439 - Rerouting Service `service_Ipswich_Saxmundham`
# 2025-12-09 15:44:24,451 - Checking `linkRefId`s of the Route: `route_Ipswich_Saxmundham` are present in the graph
# 2025-12-09 15:44:24,536 - Rerouting Route `route_Ipswich_Saxmundham`
# Routing service_Ipswich_Saxmundham.
# 2025-12-09 15:44:29,420 - Changed Route attributes for 1 routes
# 2025-12-09 15:44:29,578 - Checking `linkRefId`s of the Route: `route_Saxmundham_Ipswich` are present in the graph
# 2025-12-09 15:44:29,670 - Rerouting Route `route_Saxmundham_Ipswich`
# 2025-12-09 15:44:34,568 - Changed Route attributes for 1 routes
# 2025-12-09 15:44:40,594 - Added Services with IDs `['service_Ipswich_Shotley']` and Routes: [['route_Ipswich_Shotley', 'route_Shotley_Ipswich']]
# <class 'str'>
# Adding service_Ipswich_Shotley. Time offset: 00:30:50
# 2025-12-09 15:44:43,016 - Rerouting Service `service_Ipswich_Shotley`
# 2025-12-09 15:44:43,028 - Checking `linkRefId`s of the Route: `route_Ipswich_Shotley` are present in the graph
# 2025-12-09 15:44:43,121 - Rerouting Route `route_Ipswich_Shotley`
# Routing service_Ipswich_Shotley.
# 2025-12-09 15:44:47,874 - Changed Route attributes for 1 routes
# 2025-12-09 15:44:48,028 - Checking `linkRefId`s of the Route: `route_Shotley_Ipswich` are present in the graph
# 2025-12-09 15:44:48,105 - Rerouting Route `route_Shotley_Ipswich`
# 2025-12-09 15:44:55,893 - Changed Route attributes for 1 routes
# 2025-12-09 15:44:59,183 - Added Services with IDs `['service_Ipswich_Stowmarket']` and Routes: [['route_Ipswich_Stowmarket', 'route_Stowmarket_Ipswich']]
# <class 'str'>
# Adding service_Ipswich_Stowmarket. Time offset: 00:48:44
# 2025-12-09 15:45:02,233 - Rerouting Service `service_Ipswich_Stowmarket`
# 2025-12-09 15:45:02,245 - Checking `linkRefId`s of the Route: `route_Ipswich_Stowmarket` are present in the graph
# 2025-12-09 15:45:02,347 - Rerouting Route `route_Ipswich_Stowmarket`
# Routing service_Ipswich_Stowmarket.
# 2025-12-09 15:45:10,200 - Changed Route attributes for 1 routes
# 2025-12-09 15:45:10,352 - Checking `linkRefId`s of the Route: `route_Stowmarket_Ipswich` are present in the graph
# 2025-12-09 15:45:10,433 - Rerouting Route `route_Stowmarket_Ipswich`
# 2025-12-09 15:45:14,840 - Changed Route attributes for 1 routes
# 2025-12-09 15:45:18,547 - Added Services with IDs `['service_Ipswich_Woodbridge']` and Routes: [['route_Ipswich_Woodbridge', 'route_Woodbridge_Ipswich']]
# <class 'str'>
# Adding service_Ipswich_Woodbridge. Time offset: 00:31:35
# 2025-12-09 15:45:25,010 - Rerouting Service `service_Ipswich_Woodbridge`
# 2025-12-09 15:45:25,022 - Checking `linkRefId`s of the Route: `route_Ipswich_Woodbridge` are present in the graph
# 2025-12-09 15:45:25,110 - Rerouting Route `route_Ipswich_Woodbridge`
# Routing service_Ipswich_Woodbridge.
# 2025-12-09 15:45:30,373 - Changed Route attributes for 1 routes
# 2025-12-09 15:45:30,532 - Checking `linkRefId`s of the Route: `route_Woodbridge_Ipswich` are present in the graph
# 2025-12-09 15:45:30,617 - Rerouting Route `route_Woodbridge_Ipswich`
# 2025-12-09 15:45:35,619 - Changed Route attributes for 1 routes
# 2025-12-09 15:45:41,685 - Added Services with IDs `['service_Lowestoft_Beccles']` and Routes: [['route_Lowestoft_Beccles', 'route_Beccles_Lowestoft']]
# <class 'str'>
# Adding service_Lowestoft_Beccles. Time offset: 00:33:57
# 2025-12-09 15:45:44,266 - Rerouting Service `service_Lowestoft_Beccles`
# 2025-12-09 15:45:44,279 - Checking `linkRefId`s of the Route: `route_Lowestoft_Beccles` are present in the graph
# 2025-12-09 15:45:44,375 - Rerouting Route `route_Lowestoft_Beccles`
# Routing service_Lowestoft_Beccles.
# 2025-12-09 15:45:49,411 - Changed Route attributes for 1 routes
# 2025-12-09 15:45:49,570 - Checking `linkRefId`s of the Route: `route_Beccles_Lowestoft` are present in the graph
# 2025-12-09 15:45:49,649 - Rerouting Route `route_Beccles_Lowestoft`
# 2025-12-09 15:45:54,522 - Changed Route attributes for 1 routes
# 2025-12-09 15:46:00,633 - Added Services with IDs `['service_Lowestoft_Bungay']` and Routes: [['route_Lowestoft_Bungay', 'route_Bungay_Lowestoft']]
# <class 'str'>
# Adding service_Lowestoft_Bungay. Time offset: 00:56:40
# 2025-12-09 15:46:03,699 - Rerouting Service `service_Lowestoft_Bungay`
# 2025-12-09 15:46:03,710 - Checking `linkRefId`s of the Route: `route_Lowestoft_Bungay` are present in the graph
# 2025-12-09 15:46:03,791 - Rerouting Route `route_Lowestoft_Bungay`
# Routing service_Lowestoft_Bungay.
# 2025-12-09 15:46:11,651 - Changed Route attributes for 1 routes
# 2025-12-09 15:46:11,813 - Checking `linkRefId`s of the Route: `route_Bungay_Lowestoft` are present in the graph
# 2025-12-09 15:46:11,898 - Rerouting Route `route_Bungay_Lowestoft`
# 2025-12-09 15:46:16,477 - Changed Route attributes for 1 routes
# 2025-12-09 15:46:19,834 - Added Services with IDs `['service_Lowestoft_Halesworth']` and Routes: [['route_Lowestoft_Halesworth', 'route_Halesworth_Lowestoft']]
# <class 'str'>
# Adding service_Lowestoft_Halesworth. Time offset: 00:59:27
# 2025-12-09 15:46:25,744 - Rerouting Service `service_Lowestoft_Halesworth`
# 2025-12-09 15:46:25,757 - Checking `linkRefId`s of the Route: `route_Lowestoft_Halesworth` are present in the graph
# 2025-12-09 15:46:25,858 - Rerouting Route `route_Lowestoft_Halesworth`
# Routing service_Lowestoft_Halesworth.
# 2025-12-09 15:46:31,079 - Changed Route attributes for 1 routes
# 2025-12-09 15:46:31,256 - Checking `linkRefId`s of the Route: `route_Halesworth_Lowestoft` are present in the graph
# 2025-12-09 15:46:31,347 - Rerouting Route `route_Halesworth_Lowestoft`
# 2025-12-09 15:46:36,460 - Changed Route attributes for 1 routes
# 2025-12-09 15:46:39,875 - Added Services with IDs `['service_Lowestoft_Leiston']` and Routes: [['route_Lowestoft_Leiston', 'route_Leiston_Lowestoft']]
# <class 'str'>
# Adding service_Lowestoft_Leiston. Time offset: 01:24:57
# 2025-12-09 15:46:46,037 - Rerouting Service `service_Lowestoft_Leiston`
# 2025-12-09 15:46:46,048 - Checking `linkRefId`s of the Route: `route_Lowestoft_Leiston` are present in the graph
# 2025-12-09 15:46:46,133 - Rerouting Route `route_Lowestoft_Leiston`
# Routing service_Lowestoft_Leiston.
# 2025-12-09 15:46:50,560 - Changed Route attributes for 1 routes
# 2025-12-09 15:46:50,720 - Checking `linkRefId`s of the Route: `route_Leiston_Lowestoft` are present in the graph
# 2025-12-09 15:46:50,801 - Rerouting Route `route_Leiston_Lowestoft`
# 2025-12-09 15:46:55,733 - Changed Route attributes for 1 routes
# 2025-12-09 15:47:01,867 - Added Services with IDs `['service_Lowestoft_Saxmundham']` and Routes: [['route_Lowestoft_Saxmundham', 'route_Saxmundham_Lowestoft']]
# <class 'str'>
# Adding service_Lowestoft_Saxmundham. Time offset: 01:30:03
# 2025-12-09 15:47:05,064 - Rerouting Service `service_Lowestoft_Saxmundham`
# 2025-12-09 15:47:05,075 - Checking `linkRefId`s of the Route: `route_Lowestoft_Saxmundham` are present in the graph
# 2025-12-09 15:47:05,165 - Rerouting Route `route_Lowestoft_Saxmundham`
# Routing service_Lowestoft_Saxmundham.
# 2025-12-09 15:47:10,190 - Changed Route attributes for 1 routes
# 2025-12-09 15:47:10,356 - Checking `linkRefId`s of the Route: `route_Saxmundham_Lowestoft` are present in the graph
# 2025-12-09 15:47:10,438 - Rerouting Route `route_Saxmundham_Lowestoft`
# 2025-12-09 15:47:18,205 - Changed Route attributes for 1 routes
# 2025-12-09 15:47:21,153 - Added Services with IDs `['service_Red_Lodge_Mildenhall']` and Routes: [['route_Red_Lodge_Mildenhall', 'route_Mildenhall_Red_Lodge']]
# <class 'str'>
# Adding service_Red_Lodge_Mildenhall. Time offset: 00:11:41
# 2025-12-09 15:47:24,504 - Rerouting Service `service_Red_Lodge_Mildenhall`
# 2025-12-09 15:47:24,517 - Checking `linkRefId`s of the Route: `route_Red_Lodge_Mildenhall` are present in the graph
# 2025-12-09 15:47:24,614 - Rerouting Route `route_Red_Lodge_Mildenhall`
# Routing service_Red_Lodge_Mildenhall.
# 2025-12-09 15:47:32,678 - Changed Route attributes for 1 routes
# 2025-12-09 15:47:32,824 - Checking `linkRefId`s of the Route: `route_Mildenhall_Red_Lodge` are present in the graph
# 2025-12-09 15:47:32,906 - Rerouting Route `route_Mildenhall_Red_Lodge`
# 2025-12-09 15:47:37,600 - Changed Route attributes for 1 routes
# 2025-12-09 15:47:40,967 - Added Services with IDs `['service_Reydon_Halesworth']` and Routes: [['route_Reydon_Halesworth', 'route_Halesworth_Reydon']]
# <class 'str'>
# Adding service_Reydon_Halesworth. Time offset: 00:31:04
# 2025-12-09 15:47:46,691 - Rerouting Service `service_Reydon_Halesworth`
# 2025-12-09 15:47:46,701 - Checking `linkRefId`s of the Route: `route_Reydon_Halesworth` are present in the graph
# 2025-12-09 15:47:46,779 - Rerouting Route `route_Reydon_Halesworth`
# Routing service_Reydon_Halesworth.
# 2025-12-09 15:47:50,778 - Changed Route attributes for 1 routes
# 2025-12-09 15:47:50,924 - Checking `linkRefId`s of the Route: `route_Halesworth_Reydon` are present in the graph
# 2025-12-09 15:47:51,005 - Rerouting Route `route_Halesworth_Reydon`
# 2025-12-09 15:47:55,753 - Changed Route attributes for 1 routes
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 5
#       3 services = []
#       4 for market_town_connection in market_town_links:
# ----> 5     s = add_service(
#       6         market_town_connection[0],
#       7         market_town_connection[1],
#       8         market_town_stops)
#       9     services.append(s)
#
# Cell In[26], line 26, in add_service(from_stop, to_stop, stop_dict)
#      22 for transitstops in sched_root.findall("transitStops"):
#      23     # then drill to stopFacility
#      24     for stopFacility in transitstops.findall("stopFacility"):
#      25         # find the exact one we want
# ---> 26         if stopFacility.get("id") == stop_dict[from_stop]:
#      27             # then get x, y
#      28             x_val = float(stopFacility.get("x"))
#      29             y_val = float(stopFacility.get("y"))
#
# KeyError: 'Downham_Market'

# %%
# from genet reference docs        

n.schedule.validate_vehicle_definitions()

# %%
len(n.schedule.vehicles)

# a higher number! it works!!!

# %%
vehs = n.schedule.vehicles

# %%
n.schedule.change_log().tail()

# ok, it's in the frame, just have to hope it runs properly in the model...

# %%
# below doesn't work, I don't know why, so it's commented out - I will be shocked if this is the problem.

# n.schedule.vehicle_types = {k:v for k,v in n.schedule.vehicle_types.items() if k in {'Bus', 'Rail'}}
# n.schedule.vehicle_types['ScenarioBus'] = n.schedule.vehicle_types['Bus']

# %%
# not sure why this is here, it always yields an empty list
# ok, great, fixed it

n.schedule.vehicle_types

# %%
n.schedule.validate_vehicle_definitions()

# %%
rep = n.generate_validation_report()

# %%
n.write_to_matsim(output_path)
