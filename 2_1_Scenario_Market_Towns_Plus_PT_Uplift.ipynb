# %%
# taken from this repo: https://github.com/arup-group/suffolk_network/blob/main/scenarios/scenario_market_towns/Scenario_Market_Towns.ipynb

# also chucking the genet documentation in here: https://arup-group.github.io/genet/latest/reference/genet/utils/spatial/#genet.utils.spatial.distance_between_s2cellids 

import genet as gn
import pandas as pd
import os

path_to_matsim_network = "/mnt/c/_BERTIE_data/pt_uplift_2040/"
output_path = "/mnt/c/_BERTIE_data/market_buses_PT_uplift_2040"
# Out:
# /home/siskiyoucedar/micromamba/envs/genet/lib/python3.12/site-packages/keplergl/keplergl.py:2: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_string

# %%
network = os.path.join(path_to_matsim_network, "output_network.xml")
schedule = os.path.join(path_to_matsim_network, "output_transitSchedule.xml") 
vehicles = os.path.join(path_to_matsim_network, 'output_transitVehicles.xml')
n = gn.read_matsim(
    path_to_network=network, epsg="epsg:27700", path_to_schedule=schedule, path_to_vehicles=vehicles
)

# %%
n
# Out:
# <Network instance at 133269176473872: with
# graph: MultiDiGraph with 447655 nodes and 985382 edges and
# schedule Schedule:
# Number of services: 1351
# Number of routes: 4687
# Number of stops: 20219

# %%
# first, validate the schedule we come in with:

n.generate_validation_report()
# Out:
# 2025-12-19 09:37:50,661 - Checking validity of the Network
# 2025-12-19 09:37:50,664 - Checking validity of the Network graph
# 2025-12-19 09:37:50,665 - Defaulting to checking graph connectivity for modes: ['car', 'walk', 'bike']. You can change this by passing a `modes_for_strong_connectivity` param
# 2025-12-19 09:37:50,665 - Checking network connectivity for mode: car
# 2025-12-19 09:38:12,132 - The graph for mode: car has: 1 connected components, 0 sinks/dead_ends and 0 sources/unreachable nodes.
# 2025-12-19 09:38:12,133 - Checking network connectivity for mode: walk
# 2025-12-19 09:38:29,868 - The graph for mode: walk has: 13 connected components, 3 sinks/dead_ends and 4 sources/unreachable nodes.
# 2025-12-19 09:38:29,869 - The graph has more than one connected component for mode walk! If this is not expected, consider using the `connect_components` method to connect the components, or `retain_n_connected_subgraphs` with `n=1` to extract the largest component
# 2025-12-19 09:38:29,870 - Checking network connectivity for mode: bike
# 2025-12-19 09:38:49,248 - The graph for mode: bike has: 13 connected components, 3 sinks/dead_ends and 4 sources/unreachable nodes.
# 2025-12-19 09:38:49,249 - The graph has more than one connected component for mode bike! If this is not expected, consider using the `connect_components` method to connect the components, or `retain_n_connected_subgraphs` with `n=1` to extract the largest component
# 2025-12-19 09:38:59,282 - Checking link values for `freespeed`
# 2025-12-19 09:39:11,097 - 1 of links have fractional values for `freespeed`
# 2025-12-19 09:39:13,899 - Checking link values for `capacity`
# 2025-12-19 09:39:28,708 - Checking link values for `permlanes`
# 2025-12-19 09:39:43,490 - Checking link values for `oneway`
# 2025-12-19 09:39:58,387 - Checking link values for `modes`
# 2025-12-19 09:40:21,518 - Checking link values for `{'attributes': 'osm:way:highway'}`
# 2025-12-19 09:40:38,311 - Checking link values for `{'attributes': 'osm:way:osmid'}`
# 2025-12-19 09:40:53,927 - Checking link values for `{'attributes': 'osm:way:lanes'}`
# 2025-12-19 09:41:08,375 - Checking link values for `{'attributes': 'osm:way:original_lanes'}`
# 2025-12-19 09:41:22,668 - Checking link values for `{'attributes': 'urban'}`
# 2025-12-19 09:41:38,428 - Checking link values for `{'attributes': 'osm:way:sidewalk'}`
# 2025-12-19 09:41:52,869 - Checking link values for `{'attributes': 'osm:way:cycleway'}`
# 2025-12-19 09:42:07,209 - Checking link values for `{'attributes': 'osm:way:railway'}`
# 2025-12-19 09:42:21,772 - Checking link values for `{'attributes': 'osm:way:toll'}`
# 2025-12-19 09:42:36,422 - Checking link values for `length`
# 2025-12-19 09:42:48,422 - 306 of links have fractional values for `length`
# 2025-12-19 09:42:51,434 - Checking validity of the Schedule
# 2025-12-19 09:42:51,434 - Computing headway stats
# 2025-12-19 09:45:29,701 - Checking validity of PT vehicles
# 2025-12-19 09:45:30,111 - All vehicles are being used.
# 2025-12-19 09:45:30,491 - No vehicles being used for multiple trips have been found.
# 2025-12-19 09:45:30,498 - Found 66 PT Routes 0 minimum headway between trips. The following Services are affected: {'number_of_affected': 44, 'ids': ['10969', '11556', '12044', '12951', '13232', '15874', '16104', '16167', '17542', '18261', '18867', '20592', '20640', '20752', '22009', '33968', '37131', '46146', '48189', '4931', '50897', '52773', '53738', '56525', '59212', '59356', '60815', '60821', '61742', '62690', '65918', '66098', '66195', '66515', '68555', '68925', '69401', '70376', '72879', '7952', '8629', '9077', '9619', '9840']}
# 2025-12-19 09:45:30,499 - Computing speeds
# 2025-12-19 09:45:44,563 - Checking speeds for prohibitive values 0 and infinity. You should verify speed values separately
# /home/siskiyoucedar/micromamba/envs/genet/lib/python3.12/site-packages/genet/core.py:2790: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'False' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[~df["link_in_network"], "mode_allowed_on_link"] = False
# /home/siskiyoucedar/micromamba/envs/genet/lib/python3.12/site-packages/genet/core.py:2790: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'False' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[~df["link_in_network"], "mode_allowed_on_link"] = False
# {'graph': {'graph_connectivity': {'car': {'problem_nodes': {'dead_ends': [],
#      'unreachable_node': []},
#     'number_of_connected_subgraphs': 1},
#    'walk': {'problem_nodes': {'dead_ends': ['5177059331397872457',
#       '5177059345067659337',
#       '5177059369965366499'],
#      'unreachable_node': ['5177059042600092821',
#       '5177059380871187983',
#       '5177376830341200159',
#       '5177376830392952463']},
#     'number_of_connected_subgraphs': 13},
#    'bike': {'problem_nodes': {'dead_ends': ['5177059331397872457',
#       '5177059345067659337',
#       '5177059369965366499'],
#      'unreachable_node': ['5177059042600092821',
#       '5177059380871187983',
#       '5177376830341200159',
#       '5177376830392952463']},
#     'number_of_connected_subgraphs': 13}},
#   'isolated_nodes': {'number_of_nodes': 0, 'nodes': []},
#   'link_attributes': {'zero_attributes': {},
#    'negative_attributes': {},
#    'infinite_attributes': {},
#    'fractional_attributes': {'freespeed': {'number_of': 1,
#      'percentage': 1.0148348559238956e-06,
#      'link_ids': ['306922']},
#     'length': {'number_of': 306,
#      'percentage': 0.00031053946591271203,
#      'link_ids': ['5176680794857103355_5176680794864000715',
#       '5176680794864000715_5176680794857103355',
#       '5176697628226318369_5176697628226338481',
#       '5176697628226338481_5176697628226318369',
#       '5176697655765274111_5176697655765295539',
#       '5176697655765295539_5176697655765274111',
#       '5176706202248301863_5176706202248375685',
#       '5176706202248375685_5176706202248301863',
#       '5176729159438171069_5176729159439192845',
#      '100650',
#      '100695',
#      '100703',
#      '100720',
#      '100722',
#      '100729',
#      '100761',
#      '10079',
#      '100794',
#      '100958',
#      '100961',
#      '100986',
#      '101013',
#      '10105',
#      '101110',
#      '101132',
#      '101149',
#      '101151',
#      '101152',
#      '101171',
#      '101206',
#      '10122',
#      '101239',
#      '10125',
#      '101310',
#      '101358',
#      '101409',
#      '101449',
#      '101478',
#      '101481',
#      '101502',
#      '101504',
#      '101541',
#      '101668',
#      '101674',
#      '101711',
#      '101763',
#      '101817',
#      '101844',
#      '101845',
#      '101879',
#      '101915',
#      '102071',
#      '102187',
#      '1022',
#      '102217',
#      '102226',
#      '102239',
#      '102248',
#      '102391',
#      '102426',
#      '10252',
#      '102531',
#      '102551',
#      '102631',
#      '102700',
#      '102724',
#      '102727',
#      '102732',
#      '102766',
#      '102776',
#      '102797',
#      '102834',
#      '102939',
#      '102955',
#      '102957',
#      '103073',
#      '10308',
#      '103143',
#      '103247',
#      '10325',
#      '103283',
#      '103289',
#      '103335',
#      '103441',
#      '103644',
#      '10366',
#      '103735',
#      '103746',
#      '103815',
#      '103837',
#      '103879',
#      '103906',
#      '103937',
#      '1040',
#      '104008',
#      '104045',
#      '104048',
#      '10410',
#      '104156',
#      '10419',
#      '104213',
#      '104288',
#      '104306',
#      '104323',
#      '104330',
#      '104383',
#      '104395',
#      '104414',
#      '104443',
#      '104448',
#      '104493',
#      '104522',
#      '104539',
#      '104575',
#      '104644',
#      '10469',
#      '104724',
#      '104728',
#      '104733',
#      '104746',
#      '104785',
#      '104819',
#      '104865',
#      '10487',
#      '10492',
#      '104920',
#      '104925',
#      '104928',
#      '104934',
#      '104968',
#      '104984',
#      '105100',
#      '105109',
#      '105158',
#      '105184',
#      '105206',
#      '105248',
#      '105260',
#      '105263',
#      '1053',
#      '105340',
#      '105345',
#      '10538',
#      '105394',
#      '105416',
#      '105456',
#      '105489',
#      '105521',
#      '105535',
#      '105549',
#      '105558',
#      '105614',
#      '105689',
#      '105743',
#      '105771',
#      '10580',
#      '105835',
#      '105842',
#      '105896',
#      '105931',
#      '10596',
#      '10601',
#      '10602',
#      '106037',
#      '106057',
#      '106069',
#      '106076',
#      '106133',
#      '106152',
#      '106159',
#      '106200',
#      '106231',
#      '106267',
#      '106271',
#      '106274',
#      '106299',
#      '106310',
#      '10634',
#      '106344',
#      '106413',
#      '106437',
#      '10646',
#      '106463',
#      '106546',
#      '106563',
#      '106586',
#      '106607',
#      '106681',
#      '106727',
#      '106800',
#      '106821',
#      '106841',
#      '106859',
#      '106861',
#      '106885',
#      '106930',
#      '106968',
#      '106980',
#      '107003',
#      '107067',
#      '107107',
#      '107153',
#      '107173',
#      '107199',
#      '107237',
#      '107276',
#      '107283',
#      '107320',
#      '107330',
#      '107346',
#      '107352',
#      '10751',
#      '107527',
#      '107562',
#      '107597',
#      '107635',
#      '107832',
#      '107897',
#      '107936',
#      '107958',
#      '107992',
#      '108005',
#      '108057',
#      '108058',
#      '108079',
#      '108080',
#      '108131',
#      '108207',
#      '108248',
#      '108318',
#      '10836',
#      '108377',
#      '108473',
#      '108487',
#      '108510',
#      '108512',
#      '108702',
#      '108711',
#      '108754',
#      '108772',
#      '108801',
#      '108824',
#      '108831',
#      '108861',
#      '108883',
#      '108889',
#      '108954',
#      '10898',
#      '108991',
#      '108994',
#      '108998',
#      '109048',
#      '109060',
#      '109150',
#      '109183',
#      '109203',
#      '109263',
#      '109309',
#      '109453',
#      '10947',
#      '109490',
#      '109519',
#      '109554',
#      '109603',
#      '109624',
#      '109643',
#      '109709',
#      '10976',
#      '109813',
#      '109823',
#      '109826',
#      '109857',
#      '110042',
#      '110085',
#      '110092',
#      '110104',
#      '110124',
#      '110126',
#      '110137',
#      '110193',
#      '110194',
#      '11022',
#      '110243',
#      '110256',
#      '110380',
#      '110382',
#      '110428',
#      '110432',
#      '110434',
#      '110439',
#      '110559',
#      '11063',
#      '11065',
#      '1108',
#      '110812',
#      '110822',
#      '110829',
#      '110891',
#      '110902',
#      '110990',
#      '111002',
#      '11110',
#      '111158',
#      '111270',
#      '111353',
#      '11136',
#      '111362',
#      '111368',
#      '111422',
#      '111428',
#      '111554',
#      '111575',
#      '111579',
#      '111611',
#      '111625',
#      '111651',
#      '111663',
#      '11167',
#      '111701',
#      '111702',
#      '11178',
#      '111781',
#      '111817',
#      '111828',
#      '11187',
#      '111881',
#      '111892',
#      '111899',
#      '111937',
#      '111977',
#      '111996',
#      '112002',
#      '112006',
#      '112108',
#      '112127',
#      '112232',
#      '112253',
#      '11230',
#      '112357',
#      '112370',
#      '11242',
#      '112465',
#      '112564',
#      '112654',
#      '112699',
#      '112753',
#      '112839',
#      '112888',
#      '112915',
#      '112929',
#      '112995',
#      '11300',
#      '113066',
#      '113100',
#      '113101',
#      '113152',
#      '11319',
#      '113222',
#      '113305',
#      '113310',
#      '113333',
#      '11340',
#      '113428',
#      '11347',
#      '113473',
#      '113507',
#      '11355',
#      '11358',
#      '113590',
#      '113609',
#      '11363',
#      '113681',
#      '113726',
#      '113727',
#      '113778',
#      '11378',
#      '11380',
#      '113870',
#      '113906',
#      '114041',
#      '114048',
#      '114090',
#      '114101',
#      '114205',
#      '11425',
#      '114382',
#      '11440',
#      '114427',
#      '114465',
#      '114480',
#      '114488',
#      '114494',
#      '11450',
#      '114531',
#      '114583',
#      '114613',
#      '114625',
#      '114664',
#      '114689',
#      '114692',
#      '114695',
#      '114796',
#      '114799',
#      '114942',
#      '114952',
#      '114953',
#      '115024',
#      '11513',
#      '115135',
#      '115175',
#      '115265',
#      '115280',
#      '115301',
#      '115317',
#      '115342',
#      '115365',
#      '115377',
#      '115421',
#      '115529',
#      '115547',
#      '115556',
#      '115572',
#      '115576',
#      '115614',
#      '115625',
#      '1157',
#      '115719',
#      '115746',
#      '11575',
#      '115759',
#      '11577',
#      '115789',
#      '115877',
#      '115890',
#      '115966',
#      '116001',
#      '116045',
#      '116066',
#      '116103',
#      '116107',
#      '116196',
#      '116226',
#      '11624',
#      '116240',
#      '116255',
#      '116261',
#      '116273',
#      '116336',
#      '11638',
#      '116389',
#      '116418',
#      '116428',
#      '116429',
#      '116454',
#      '116514',
#      '116523',
#      '116595',
#      '116610',
#      '11667',
#      '116706',
#      '116709',
#      '116725',
#      '116726',
#      '116734',
#      '116820',
#      '116839',
#      '116858',
#      '116909',
#      '116915',
#      '116931',
#      '116974',
#      '116977',
#      '117044',
#      '117054',
#      '117063',
#      '117143',
#      '117196',
#      '117233',
#      '117254',
#      '117325',
#      '117358',
#      '117383',
#      '117438',
#      '117546',
#      '117580',
#      '117581',
#      '117590',
#      '117649',
#      '117666',
#      '117684',
#      '117759',
#      '117764',
#      '117807',
#      '117809',
#      '117876',
#      '117899',
#      '11798',
#      '118001',
#      '118058',
#      '118061',
#      '118182',
#      '118261',
#      '118262',
#      '118338',
#      '118367',
#      '118414',
#      '118446',
#      '118450',
#      '118452',
#      '118456',
#      '118608',
#      '118653',
#      '118690',
#      '118711',
#      '118759',
#      '118777',
#      '11879',
#      '118791',
#      '118845',
#      '118850',
#      '118852',
#      '11887',
#      '118870',
#      '118885',
#      '118946',
#      '118951',
#      '118994',
#      '118996',
#      '1190',
#      '119013',
#      '119038',
#      '119045',
#      '119067',
#      '119094',
#      '119109',
#      '119134',
#      '119154',
#      '119165',
#      '119183',
#      '119208',
#      '119222',
#      '119245',
#      '119284',
#      '119290',
#      '119330',
#      '119368',
#      '119394',
#      '119397',
#      '119429',
#      '119467',
#      '11949',
#      '119505',
#      '119577',
#      '119693',
#      '119701',
#      '119806',
#      '119900',
#      '119903',
#      '119920',
#      '119961',
#      '119976',
#      '120008',
#      '120010',
#      '120031',
#      '12005',
#      '120073',
#      '120118',
#      '120133',
#      '120290',
#      '120302',
#      '120315',
#      '120392',
#      '120422',
#      '120445',
#      '120459',
#      '120469',
#      '120473',
#      '120484',
#      '120686',
#      '120707',
#      '120742',
#      '12076',
#      '120763',
#      '120776',
#      '120797',
#      '120799',
#      '120803',
#      '120821',
#      '12089',
#      '120920',
#      '120930',
#      '120934',
#      '121020',
#      '121103',
#      '12111',
#      '121133',
#      '121159',
#      '121251',
#      '121263',
#      '121316',
#      '121360',
#      '121374',
#      '121388',
#      '121436',
#      '121460',
#      '12148',
#      '121493',
#      '121519',
#      '121540',
#      '121566',
#      '121569',
#      '121626',
#      '121778',
#      '121868',
#      '121896',
#      '121959',
#      '12202',
#      '122110',
#      '122144',
#      '122172',
#      '122181',
#      '122229',
#      '122285',
#      '122324',
#      '122366',
#      '122411',
#      '122440',
#      '122483',
#      '122495',
#      '122559',
#      '122617',
#      '12262',
#      '122647',
#      '122654',
#      '122707',
#      '12271',
#      '122736',
#      '122746',
#      '122791',
#      '122803',
#      '122816',
#      '122844',
#      '122919',
#      '122945',
#      '122961',
#      '122966',
#      '122988',
#      '123013',
#      '123034',
#      '123049',
#      '123052',
#      '123096',
#      '123115',
#      '123133',
#      '123140',
#      '123226',
#      '123267',
#      '12327',
#      '123275',
#      '123322',
#      '123347',
#      '123390',
#      '123425',
#      '123432',
#      '123445',
#      '123478',
#      '123509',
#      '123552',
#      '123565',
#      '123569',
#      '123617',
#      '123647',
#      '123700',
#      '123746',
#      '123811',
#      '123821',
#      '123826',
#      '123839',
#      '123852',
#      '123856',
#      '123870',
#      '123896',
#      '123908',
#      '123910',
#      '124021',
#      '124032',
#      '12404',
#      '124045',
#      '124087',
#      '124184',
#      '124373',
#      '124374',
#      '124428',
#      '124473',
#      '124494',
#      '124507',
#      '124519',
#      '12461',
#      '124637',
#      '12464',
#      '124673',
#      '12468',
#      '124747',
#      '124762',
#      '124795',
#      '1248',
#      '124920',
#      '124921',
#      '124931',
#      '124993',
#      '125',
#      '125063',
#      '125142',
#      '125179',
#      '12532',
#      '125412',
#      '125422',
#      '125462',
#      '125480',
#      '125495',
#      '125528',
#      '12560',
#      '125641',
#      '125678',
#      '12580',
#      '125802',
#      '125839',
#      '125855',
#      '125865',
#      '125876',
#      '12589',
#      '125913',
#      '125921',
#      '125976',
#      '125984',
#      '125985',
#      '126095',
#      '126136',
#      '126174',
#      '126248',
#      '12625',
#      '126251',
#      '126319',
#      '126338',
#      '126340',
#      '126412',
#      '12647',
#      '126480',
#      '126519',
#      '126521',
#      '126539',
#      '126597',
#      '12660',
#      '126615',
#      '126638',
#      '12672',
#      '12677',
#      '126776',
#      '126873',
#      '126894',
#      '126941',
#      '126982',
#      '127038',
#      '127186',
#      '127200',
#      '127247',
#      '127286',
#      '127293',
#      '127298',
#      '127327',
#      '127405',
#      '127423',
#      '127468',
#      '127473',
#      '127500',
#      '127504',
#      '127557',
#      '127573',
#      '127648',
#      '127686',
#      '127698',
#      '127739',
#      '127792',
#      '127798',
#      '127832',
#      '127833',
#      '127845',
#      '127903',
#      '127996',
#      '12803',
#      '128057',
#      '128106',
#      '128131',
#      '12816',
#      '128220',
#      '12829',
#      '128320',
#      '128338',
#      '128364',
#      '128373',
#      '128554',
#      '128622',
#      '128666',
#      '12870',
#      '128704',
#      '128716',
#      '128746',
#      '128833',
#      '128872',
#      '12888',
#      '128913',
#      '128976',
#      '12898',
#      '128993',
#      '129033',
#      '129144',
#      '129240',
#      '12927',
#      '129277',
#      '129296',
#      '129306',
#      '129350',
#      '129356',
#      '129380',
#      '129536',
#      '129649',
#      '129694',
#      '129695',
#      '129702',
#      '129713',
#      '129730',
#      '129815',
#      '129867',
#      '129928',
#      '129943',
#      '129979',
#      '130039',
#      '130071',
#      '130079',
#      '130111',
#      '130135',
#      '130189',
#      '130217',
#      '130290',
#      '130340',
#      '130348',
#      '130359',
#      '130421',
#      '130503',
#      '130556',
#      '130591',
#      '130596',
#      '130622',
#      '130638',
#      '130641',
#      '130669',
#      '13069',
#      '130751',
#      '130822',
#      '130828',
#      '130894',
#      '130978',
#      '131012',
#      '131053',
#      '131079',
#      '131149',
#      '131194',
#      '131320',
#      '131383',
#      '131556',
#      '131585',
#      '131649',
#      '13172',
#      '131767',
#      '131784',
#      '131819',
#      '131889',
#      '131939',
#      '131991',
#      '132092',
#      '132187',
#      '132227',
#      '132271',
#      '132273',
#      '132277',
#      '132300',
#      '132373',
#      '132471',
#      '132474',
#      '132479',
#      '132540',
#      '132566',
#      '132583',
#      '132584',
#      '132637',
#      '132643',
#      '132671',
#      '132689',
#      '132703',
#      '13273',
#      '13276',
#      '132819',
#      '132908',
#      '132944',
#      '133008',
#      '133020',
#      '133031',
#      '133055',
#      '133060',
#      '133075',
#      '133083',
#      '133151',
#      '133172',
#      '133209',
#      '133286',
#      '133289',
#      '133317',
#      '133386',
#      '133461',
#      '133543',
#      '133558',
#      '133602',
#      '133608',
#      '133664',
#      '13367',
#      '133686',
#      '133751',
#      '133793',
#      '133821',
#      '133872',
#      '133874',
#      '13388',
#      '133899',
#      '13392',
#      '134035',
#      '134041',
#      '134078',
#      '13409',
#      '134106',
#      '134110',
#      '134364',
#      '134450',
#      '134502',
#      '134512',
#      '134516',
#      '134523',
#      '134531',
#      '134567',
#      '134569',
#      '134598',
#      '134605',
#      '134609',
#      '134626',
#      '13469',
#      '134699',
#      '134708',
#      '134717',
#      '134809',
#      '134833',
#      '134852',
#      '134905',
#      '134922',
#      '134927',
#      '13499',
#      '135038',
#      '135087',
#      '135091',
#      '135264',
#      '135281',
#      '135323',
#      '135439',
#      '135446',
#      '135544',
#      '135552',
#      '135557',
#      '135602',
#      '135613',
#      '135617',
#      '135643',
#      '135667',
#      '135700',
#      '135781',
#      '13589',
#      '135911',
#      '135936',
#      '135938',
#      '135950',
#      '136012',
#      '136017',
#      '136086',
#      '136129',
#      ...]}}},
#  'schedule': {'schedule_level': {'is_valid_schedule': True,
#    'invalid_stages': [],
#    'has_valid_services': True,
#    'invalid_services': [],
#    'headways': {'has_zero_min_headways': True,
#     'routes': {'number_of_affected': 66,
#      'ids': ['10969_0',
#       '10969_6',
#       '11556_1',
#       '12044_1',
#       '12951_0',
#       '12951_1',
#       '13232_1',
#       '15874_1',
#       '16104_0',
#       '16167_0',
#       '16167_1',
#       '17542_1',
#       '18261_1',
#       '18867_0',
#       '18867_1',
#       '20592_6',
#       '20640_0',
#       '20640_2',
#       '20752_1',
#       '22009_2',
#       '33968_0',
#       '33968_1',
#       '33968_2',
#       '33968_4',
#       '33968_5',
#       '37131_0',
#       '37131_1',
#       '46146_1',
#       '48189_2',
#       '4931_1',
#       '4931_3',
#       '50897_0',
#       '50897_1',
#       '52773_0',
#       '52773_1',
#       '53738_1',
#       '56525_0',
#       '56525_1',
#       '59212_7',
#       '59356_0',
#       '59356_1',
#       '60815_2',
#       '60821_0',
#       '60821_2',
#       '61742_0',
#       '61742_1',
#       '62690_0',
#       '62690_1',
#       '65918_0',
#       '66098_1',
#       '66195_1',
#       '66515_2',
#       '68555_0',
#       '68555_1',
#       '68925_1',
#       '68925_3',
#       '69401_0',
#       '69401_1',
#       '70376_0',
#       '72879_0',
#       '72879_1',
#       '7952_0',
#       '8629_1',
#       '9077_1',
#       '9619_0',
#       '9840_0']},
#     'services': {'number_of_affected': 44,
#      'ids': ['10969',
#       '11556',
#       '12044',
#       '12951',
#       '13232',
#    '63155': {'63155_0': 1.102972473332058, '63155_1': 1.138826653943012},
#    '63159': {'63159_0': 1.1766785662369754, '63159_1': 1.1199437094994709},
#    '63370': {'63370_0': 1.0719066077146389,
#     '63370_1': 1.080384096435202,
#     '63370_2': 1.0725049501339594,
#     '63370_3': 1.0808604992513169,
#     '63370_4': 1.1088183931808937,
#     '63370_5': 1.0655543883313678,
#     '63370_6': 1.0956328550042478,
#     '63370_7': 1.1070603499713012},
#    '63382': {'63382_0': 1.167854046996225,
#     '63382_1': 1.159967270365854,
#     '63382_2': 1.179740423482663,
#     '63382_3': 1.1556961067372353},
#    '63465': {'63465_0': 2.0832319024296795, '63465_1': 2.0994563039985006},
#    ...}},
#  'intermodal_access_egress': {'has_valid_intermodal_connections': True,
#   'invalid_intermodal_connections': {'car': {'stops_with_links_not_in_network': set(),
#     'stops_with_links_with_wrong_modes': set()}}},
#  'is_valid_network': False}

# %%
# actual list

market_towns = {
    'Aldeburgh',
    'Bury St Edmunds',
    'Capel St Mary',
    'Clare',
    'East Bergholt',
    'Eye',
    'Ipswich',
    'Lowestoft',
    'Red Lodge',
    'Beck Row',
    'Brandon',
    'Elmswell',
    'Haverhill',
    'Ixworth',
    'Long Melford',
    'Mildenhall',
    'Newmarket',
    'Stowmarket',
    'Sudbury',
    'Thurston',
    'Hadleigh',
    'Haverhill',
    'Felixstowe',
    'Framlingham',
    'Leiston',
    'Needham Market',
    'Rendlesham',
    'Saxmundham',
    'Shotley',
    'Beccles',
    'Bungay',
    'Halesworth',
    'Reydon',
    'Woodbridge',
    'Downham Market',  
    'Kings_Lynn', 
    'Swaffham', 
    'Wroxham', 
    'Stalham', 
    'Aylsham', 
    'Holt',
    'Fakenham', 
    'Hunstanton', 
    'Brandon',
    'Great_Yarmouth', 
    'Caister-on-Sea', 
    'Norwich',
    'Watton', 
    'Attleborough', 
    'Reepham', 
    'Cromer', 
    'Wells Next The Sea', 
    'Thetford',
    'Tiptree', 
    'Halstead', 
    'Great Dunmow', 
    'Brightlingsea',
    'West Mersea', 
    'Maldon', 
    'Saffron Walden', 
    'Braintree', 
    'Epping', 
    'Harlow',
    'Colchester',
    'Chelmsford',
    'Sudbury',
    'South Woodham Ferrers',
    'Bishops Stortford',
    'Braintree'
}
market_towns = sorted(list([t.replace(' ', '_') for t in market_towns]))
market_towns
# Out:
# ['Aldeburgh',
#  'Attleborough',
#  'Aylsham',
#  'Beccles',
#  'Beck_Row',
#  'Bishops_Stortford',
#  'Braintree',
#  'Brandon',
#  'Brightlingsea',
#  'Bungay',
#  'Bury_St_Edmunds',
#  'Caister-on-Sea',
#  'Capel_St_Mary',
#  'Chelmsford',
#  'Clare',
#  'Colchester',
#  'Cromer',
#  'Downham_Market',
#  'East_Bergholt',
#  'Elmswell',
#  'Epping',
#  'Eye',
#  'Fakenham',
#  'Felixstowe',
#  'Framlingham',
#  'Great_Dunmow',
#  'Great_Yarmouth',
#  'Hadleigh',
#  'Halesworth',
#  'Halstead',
#  'Harlow',
#  'Haverhill',
#  'Holt',
#  'Hunstanton',
#  'Ipswich',
#  'Ixworth',
#  'Kings_Lynn',
#  'Leiston',
#  'Long_Melford',
#  'Lowestoft',
#  'Maldon',
#  'Mildenhall',
#  'Needham_Market',
#  'Newmarket',
#  'Norwich',
#  'Red_Lodge',
#  'Reepham',
#  'Rendlesham',
#  'Reydon',
#  'Saffron_Walden',
#  'Saxmundham',
#  'Shotley',
#  'South_Woodham_Ferrers',
#  'Stalham',
#  'Stowmarket',
#  'Sudbury',
#  'Swaffham',
#  'Thetford',
#  'Thurston',
#  'Tiptree',
#  'Watton',
#  'Wells_Next_The_Sea',
#  'West_Mersea',
#  'Woodbridge',
#  'Wroxham']

# %%
# this throws an error - why?

# fixed it. was 5177495089997857897; dug out relevant stop id from schedule xml
# appears stop ids have changed in the newer versions of BERTIE

n.schedule.stop('390060143').print()
# Out:
# Stop ID: 390060143
# Projection: epsg:27700
# Lat, Lon: 52.150799, 1.60107101
# linkRefId: 5177495089997857897_5177495089997857897

# %%
# optional write to geojson - I will use this to get the right stop ids for market_town_stops below:

# n.write_spatial("C:/_BERTIE_data/market_buses_2040", filetype="geojson")

# %%
# relevant stops found using QGIS

# I changed all of these for the new ids; will need to pull back from the url noted above if needed

market_town_stops = {
    'Aldeburgh': '390060144',
    'Beccles': '390071010',
    'Beck_Row': '390020120',
    'Brandon': '390020066',
    'Bungay': '390070047',
    'Bury_St_Edmunds': '390050878',
    'Capel_St_Mary': '390010551',
    'Clare': '390050196',
    'East_Bergholt': '390010838',
    'Elmswell': '390040425',
    'Eye': '390040134',
    'Felixstowe': '390060767',
    'Framlingham': '390060370',
    'Hadleigh': '390010387',
    'Halesworth': '390070274',
    'Haverhill': '390050277',
    'Ipswich': '390030007',
    'Ixworth': '390050564',
    'Leiston': '390060208',
    'Long_Melford': '390010149',
    'Lowestoft': '390071022',
    'Mildenhall': '390020289',
    'Needham_Market': '390040505',
    'Newmarket': '390020187',
    'Red_Lodge': '390020148',
    'Rendlesham': '390061134',
    'Reydon': '390070335',
    'Saxmundham': '390060201',
    'Shotley': '390010018',
    'Stowmarket': '390040596',
    'Sudbury': '390010689',
    'Thurston': '390040539',
    'Woodbridge': '390060607',
    # norwich ones:
    'Downham_Market': '290G8',  # king's lynn
    'Kings_Lynn': '290G15', # hunstanton, swaffham
    'Swaffham': '2900S7122', # king's lynn, norwich
    'Wroxham': '2900W554', # norwich
    'Stalham': '2900S3919', # norwich 
    'Aylsham': '2900A219', # norwich, cromer
    'Holt': '2900H394', # cromer
    'Fakenham': '2900F0118', # wells
    'Hunstanton': '290G14', # king's lynn
    'Brandon': '390020066', # thetford 
    'Great_Yarmouth': '2900Y0386', # lowestoft
    'Caister-on-Sea': '2900C0117', # yarmouth
    'Norwich': '290G65', # beccles, bungay
    'Watton': '2900W1219', # dereham, thetford
    'Attleborough': '2900A181', # norwich
    'Reepham': '2900R053', # norwich
    'Cromer': '2900C3811', # aylsham, holt
    'Wells_Next_The_Sea': '2900W5712', # fakenham
    'Thetford': '290G29', # brandon
    # essex ones: 
    'Tiptree': '150014006006', # colchester
    'Halstead': '1500IM101', # braintree
    'Great_Dunmow': '150018016003', # braintree, bishops stortford
    'Brightlingsea': '150032004031', # colchester
    'West_Mersea': '150014013023', # colchester
    'Maldon': '1500IM597', # chelmsford, south woodham ferrers
    'Saffron_Walden': '1500IM154', # bishops stortford
    'Braintree': '150G00003242', # sudbury
    'Epping': '1500IM353', # harlow
    'Harlow': '150G00000876', # and chelmsford here because why not
    'Colchester': '1500IM77A',
    'Chelmsford': '150G00003237',
    'South_Woodham_Ferrers': '1500IM2261B',
    'Bishops_Stortford': '210G224'
}

# %%
# as yet unchanged - to add norfolk and essex ones

market_town_links = [
    ('Aldeburgh','Woodbridge'),
    ('Bury_St_Edmunds', 'Beck_Row'),
    ('Bury_St_Edmunds', 'Brandon'),
    ('Bury_St_Edmunds', 'Elmswell'),
    ('Bury_St_Edmunds', 'Haverhill'),
    ('Bury_St_Edmunds', 'Ixworth'),
    ('Bury_St_Edmunds', 'Long_Melford'),
    ('Bury_St_Edmunds', 'Mildenhall'),
    ('Bury_St_Edmunds', 'Newmarket'),
    ('Bury_St_Edmunds', 'Stowmarket'),
    ('Bury_St_Edmunds', 'Sudbury'),
    ('Bury_St_Edmunds', 'Thurston'),
    ('Capel_St_Mary', 'Hadleigh'),
    ('Clare', 'Haverhill'),
    ('East_Bergholt', 'Hadleigh'),
    ('Eye', 'Stowmarket'),
    ('Ipswich', 'Felixstowe'),
    ('Ipswich', 'Framlingham'),
    ('Ipswich', 'Hadleigh'),
    ('Ipswich', 'Leiston'),
    ('Ipswich', 'Needham_Market'),
    ('Ipswich', 'Rendlesham'),
    ('Ipswich', 'Saxmundham'),
    ('Ipswich', 'Shotley'),
    ('Ipswich', 'Stowmarket'),
    ('Ipswich', 'Woodbridge'),
    ('Lowestoft', 'Beccles'),
    ('Lowestoft', 'Bungay'),
    ('Lowestoft', 'Halesworth'),
    ('Lowestoft', 'Leiston'),
    ('Lowestoft', 'Saxmundham'),
    ('Red_Lodge', 'Mildenhall'),
    ('Reydon', 'Halesworth'),
    # norwich:
    ('Downham_Market', 'Kings_Lynn'),
    ('Swaffham', 'Kings_Lynn'),
    ('Swaffham', 'Norwich'),
    ('Wroxham', 'Norwich'),
    ('Stalham', 'Norwich'),
    ('Aylsham', 'Norwich'),
    ('Holt', 'Cromer'),
    ('Fakenham', 'Wells_Next_The_Sea'),
    ('Hunstanton', 'Kings_Lynn'),
    ('Brandon', 'Thetford'),
    ('Great_Yarmouth', 'Caister-on-Sea'),
    ('Great_Yarmouth', 'Lowestoft'),
    ('Norwich', 'Beccles'),
    ('Norwich', 'Bungay'),
    ('Watton', 'Thetford'),
    ('Attleborough', 'Norwich'),
    ('Reepham', 'Norwich'),
    ('Cromer', 'Aylsham'),
    # essex:
    ('Tiptree', 'Colchester'),
    ('Halstead', 'Braintree'),
    ('Great_Dunmow', 'Braintree'),
    ('Great_Dunmow', 'Bishops_Stortford'),
    ('Brightlingsea', 'Colchester'),
    ('West_Mersea', 'Colchester'),
    ('Maldon', 'Chelmsford'),
    ('Maldon', 'South_Woodham_Ferrers'),
    ('Saffron_Walden', 'Bishops_Stortford'),
    ('Braintree', 'Sudbury'),
    ('Epping', 'Harlow'),
    ('Harlow', 'Chelmsford'),
]

# %%
# function that gets all the bus routes
# I bet this will spring an error but let's see how we roll...

def get_trips(n):
    trips = n.schedule.route_trips_to_dataframe().sort_values(['route_id', 'trip_departure_time']).reset_index(drop=True)
    trips['mode'] = trips['route_id'].apply(lambda x: n.schedule.graph().graph['routes'][x]['mode'])
    trips = trips[trips['mode'] == 'bus']
    return trips

# %%
# a quick bit of code to check the market_town_stops list is valid:

print(market_town_stops["Cromer"])
# Out:
# 2900C3811

# %%
trips = get_trips(n)
trips.head()

# that looks right!
# Out:
# 2025-12-19 09:48:20,096 - `route_trips_to_dataframe` method is deprecated and will be replaced by `trips_to_dataframe`in later versions.
#   service_id route_id mode           trip_id trip_departure_time  \
# 0      10073  10073_0  bus  10073_0_06:00:00 1970-01-01 06:00:00
# 1      10073  10073_0  bus  10073_0_06:30:00 1970-01-01 06:30:00
# 2      10073  10073_0  bus  10073_0_07:00:00 1970-01-01 07:00:00
# 3      10073  10073_0  bus  10073_0_07:30:00 1970-01-01 07:30:00
# 4      10073  10073_0  bus  10073_0_08:00:00 1970-01-01 08:00:00
#
#                  vehicle_id
# 0  veh_bus_10073_0_06:00:00
# 1  veh_bus_10073_0_06:30:00
# 2  veh_bus_10073_0_07:00:00
# 3  veh_bus_10073_0_07:30:00
# 4  veh_bus_10073_0_08:00:00

# %%
trips_with_stops = n.schedule.route_trips_with_stops_to_dataframe()
trips_with_stops.head()
# Out:
# 2025-12-19 09:48:20,520 - `route_trips_with_stops_to_dataframe` method is deprecated and will be replaced by `trips_to_dataframe` in later versions.
#   service_name      departure_time mode  from_stop_name route_id  \
# 0           44 1970-01-01 06:00:00  bus        Lakeside  10073_0
# 1           44 1970-01-01 06:02:00  bus           Tesco  10073_0
# 2           44 1970-01-01 06:05:36  bus     Armour Road  10073_0
# 3           44 1970-01-01 06:07:00  bus  Watts Crescent  10073_0
# 4           44 1970-01-01 06:12:41  bus   Marlow Avenue  10073_0
#
#      to_stop_name route_name        arrival_time service_id    from_stop  \
# 0           Tesco         44 1970-01-01 06:02:00      10073  159G0060101
# 1     Armour Road         44 1970-01-01 06:05:36      10073   1590012401
# 2  Watts Crescent         44 1970-01-01 06:07:00      10073   1590703601
# 3   Marlow Avenue         44 1970-01-01 06:12:41      10073   1590048301
# 4   Saladin Drive         44 1970-01-01 06:14:00      10073   1590002001
#
#       to_stop           trip_id                vehicle_id
# 0  1590012401  10073_0_06:00:00  veh_bus_10073_0_06:00:00
# 1  1590703601  10073_0_06:00:00  veh_bus_10073_0_06:00:00
# 2  1590048301  10073_0_06:00:00  veh_bus_10073_0_06:00:00
# 3  1590002001  10073_0_06:00:00  veh_bus_10073_0_06:00:00
# 4  1590002101  10073_0_06:00:00  veh_bus_10073_0_06:00:00

# %% [markdown]
# We will compute typical bus speeds and use it to inform arrival and departure offsets for the new services
# $$
# speed = \frac{distance}{time}
# $$
# for all existing services and then
# $$
# time = \frac{distance}{speed}
# $$

# %%
from genet.utils import spatial

# %%
# ok so we're getting an error where the from_ or to_ stop is not an integer

# the best solution would be to get rid of any entry that doesn't qualify as an integer, and just use the remainder of the dataset

# the only way to tell that's the case is to pick up on the ones that contain *only numbers*:

# the below code fixes the problem, but cuts out a lot of data - I've killed it for now

# trips_with_stops = trips_with_stops[
#     trips_with_stops['from_stop'].apply(lambda x: str(x).isdigit()) &
#     trips_with_stops['to_stop'].apply(lambda x: str(x).isdigit())
# ]

# %%
# test that we can pull out lat and long

n.schedule.stop_attribute_data(keys=["lat","lon","id"]).head()
# Out:
#                    lat       lon           id
# 910GPBRO     52.574993 -0.249823     910GPBRO
# 910GTHETFD   52.419144  0.745098   910GTHETFD
# 910GATTLBON  52.514568  1.022371  910GATTLBON
# 910GWYMNDHM  52.565434  1.118048  910GWYMNDHM
# 910GNRCH     52.627178  1.306844     910GNRCH

# %%
# again, but bigger this time

lat_lon = n.schedule.stop_attribute_data(keys=["lat","lon","id"])

# %%
# then, merge that into the trips_with_stops df using id:

# first to_stop

lat_lon_to = lat_lon.rename(columns={'id':'to_stop', 'lat':'to_lat', 'lon':'to_lon'})

# then, merge that into the trips_with_stops df using id
trips_with_stops = trips_with_stops.merge(
    lat_lon_to[['to_stop', 'to_lat', 'to_lon']],
    on='to_stop',
    how='left'
)

# then, from_stop

lat_lon_from = lat_lon.rename(columns={'id':'from_stop', 'lat':'from_lat', 'lon':'from_lon'})

# then, merge that into the trips_with_stops df using id
trips_with_stops = trips_with_stops.merge(
    lat_lon_from[['from_stop', 'from_lat', 'from_lon']],
    on='from_stop',
    how='left'
)

# %%
# original code threw errors because some ids aren't just integers so can't be called

# trips_with_stops['distance'] = trips_with_stops.apply(
    # lambda x: spatial.distance_between_s2cellids(int(x['from_stop']), int(x['to_stop'])),
    # axis=1
# )

# new code uses a haversine function instead 

import numpy as np

APPROX_EARTH_RADIUS = 6371008.8

def haversine(lat1, lon1, lat2, lon2, R=APPROX_EARTH_RADIUS):
    # expects degrees
    lat1, lon1, lat2, lon2 = map(np.radians, (lat1, lon1, lat2, lon2))
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = np.sin(dlat / 2.0)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2.0)**2
    return 2 * R * np.arcsin(np.sqrt(a))

# ensure numeric and drop rows with missing coords
coords = ['from_lat','from_lon','to_lat','to_lon']
trips_with_stops[coords] = trips_with_stops[coords].apply(pd.to_numeric, errors='coerce')
trips_with_stops = trips_with_stops.dropna(subset=coords)

trips_with_stops['distance'] = trips_with_stops.apply(
    lambda x: haversine(x['from_lat'], x['from_lon'], x['to_lat'], x['to_lon']),
    axis=1
)

# %%
# horrible but necessary code to convert bng to lat, long:

# Converts eastings and northings (British national grid coordinates) to Lat/Long


from math import sqrt, pi, sin, cos, tan, atan2 as arctan2
import csv

def OSGB36toWGS84(E, N):
    # E, N are the British national grid coordinates - eastings and northings
    # The Airy 180 semi-major and semi-minor axes used for OSGB36 (m)
    a, b = 6377563.396, 6356256.909
    F0 = 0.9996012717  # scale factor on the central meridian
    lat0 = 49 * pi / 180  # Latitude of true origin (radians)
    # Longtitude of true origin and central meridian (radians)
    lon0 = -2 * pi / 180
    N0, E0 = -100000, 400000  # Northing & easting of true origin (m)
    e2 = 1 - (b * b) / (a * a)  # eccentricity squared
    n = (a - b) / (a + b)

    # Initialise the iterative variables
    lat, M = lat0, 0

    while N - N0 - M >= 0.00001:  # Accurate to 0.01mm
        lat = (N - N0 - M) / (a * F0) + lat
        M1 = (1 + n + (5. / 4) * n**2 + (5. / 4) * n**3) * (lat - lat0)
        M2 = (3 * n + 3 * n**2 + (21. / 8) * n**3) * \
            sin(lat - lat0) * cos(lat + lat0)
        M3 = ((15. / 8) * n**2 + (15. / 8) * n**3) * \
            sin(2 * (lat - lat0)) * cos(2 * (lat + lat0))
        M4 = (35. / 24) * n**3 * sin(3 * (lat - lat0)) * cos(3 * (lat + lat0))
        # meridional arc
        M = b * F0 * (M1 - M2 + M3 - M4)

    # transverse radius of curvature
    nu = a * F0 / sqrt(1 - e2 * sin(lat)**2)

    # meridional radius of curvature
    rho = a * F0 * (1 - e2) * (1 - e2 * sin(lat)**2)**(-1.5)
    eta2 = nu / rho - 1

    secLat = 1. / cos(lat)
    VII = tan(lat) / (2 * rho * nu)
    VIII = tan(lat) / (24 * rho * nu**3) * \
        (5 + 3 * tan(lat)**2 + eta2 - 9 * tan(lat)**2 * eta2)
    IX = tan(lat) / (720 * rho * nu**5) * \
        (61 + 90 * tan(lat)**2 + 45 * tan(lat)**4)
    X = secLat / nu
    XI = secLat / (6 * nu**3) * (nu / rho + 2 * tan(lat)**2)
    XII = secLat / (120 * nu**5) * (5 + 28 * tan(lat)**2 + 24 * tan(lat)**4)
    XIIA = secLat / (5040 * nu**7) * (61 + 662 * tan(lat) **
                                      2 + 1320 * tan(lat)**4 + 720 * tan(lat)**6)
    dE = E - E0

    # These are on the wrong ellipsoid currently: Airy1830. (Denoted by _1)
    lat_1 = lat - VII * dE**2 + VIII * dE**4 - IX * dE**6
    lon_1 = lon0 + X * dE - XI * dE**3 + XII * dE**5 - XIIA * dE**7

    # Want to convert to the GRS80 ellipsoid.
    # First convert to cartesian from spherical polar coordinates
    H = 0  # Third spherical coord.
    x_1 = (nu / F0 + H) * cos(lat_1) * cos(lon_1)
    y_1 = (nu / F0 + H) * cos(lat_1) * sin(lon_1)
    z_1 = ((1 - e2) * nu / F0 + H) * sin(lat_1)

    # Perform Helmut transform (to go between Airy 1830 (_1) and GRS80 (_2))
    s = -20.4894 * 10**-6  # The scale factor -1
    # The translations along x,y,z axes respectively
    tx, ty, tz = 446.448, -125.157, + 542.060
    # The rotations along x,y,z respectively, in seconds
    rxs, rys, rzs = 0.1502,  0.2470,  0.8421
    rx, ry, rz = rxs * pi / (180 * 3600.), rys * pi / \
        (180 * 3600.), rzs * pi / (180 * 3600.)  # In radians
    x_2 = tx + (1 + s) * x_1 + (-rz) * y_1 + (ry) * z_1
    y_2 = ty + (rz) * x_1 + (1 + s) * y_1 + (-rx) * z_1
    z_2 = tz + (-ry) * x_1 + (rx) * y_1 + (1 + s) * z_1

    # Back to spherical polar coordinates from cartesian
    # Need some of the characteristics of the new ellipsoid
    # The GSR80 semi-major and semi-minor axes used for WGS84(m)
    a_2, b_2 = 6378137.000, 6356752.3141
    # The eccentricity of the GRS80 ellipsoid
    e2_2 = 1 - (b_2 * b_2) / (a_2 * a_2)
    p = sqrt(x_2**2 + y_2**2)

    # Lat is obtained by an iterative proceedure:
    lat = arctan2(z_2, (p * (1 - e2_2)))  # Initial value
    latold = 2 * pi
    while abs(lat - latold) > 10**-16:
        lat, latold = latold, lat
        nu_2 = a_2 / sqrt(1 - e2_2 * sin(latold)**2)
        lat = arctan2(z_2 + e2_2 * nu_2 * sin(latold), p)

    # Lon and height are then pretty easy
    lon = arctan2(y_2, x_2)
    H = p / cos(lat) - nu_2

    # Uncomment this line if you want to print the results
    # print([(lat-lat_1)*180/pi, (lon - lon_1)*180/pi])

    # Convert to degrees
    lat = lat * 180 / pi
    lon = lon * 180 / pi

    # Job's a good'n.
    return lat, lon

# %%
trips_with_stops['time_delta'] = trips_with_stops['arrival_time'] - trips_with_stops['departure_time']
trips_with_stops['time_delta'] = trips_with_stops['time_delta'].dt.total_seconds()

# %%
trips_with_stops = trips_with_stops[trips_with_stops['time_delta'] != 0]

# %%
trips_with_stops['speed'] = trips_with_stops['distance'] / trips_with_stops['time_delta']

# %%
trips_with_stops.head()
# Out:
#   service_name      departure_time mode  from_stop_name route_id  \
# 0           44 1970-01-01 06:00:00  bus        Lakeside  10073_0
# 1           44 1970-01-01 06:02:00  bus           Tesco  10073_0
# 2           44 1970-01-01 06:05:36  bus     Armour Road  10073_0
# 3           44 1970-01-01 06:07:00  bus  Watts Crescent  10073_0
# 4           44 1970-01-01 06:12:41  bus   Marlow Avenue  10073_0
#
#      to_stop_name route_name        arrival_time service_id    from_stop  \
# 0           Tesco         44 1970-01-01 06:02:00      10073  159G0060101
# 1     Armour Road         44 1970-01-01 06:05:36      10073   1590012401
# 2  Watts Crescent         44 1970-01-01 06:07:00      10073   1590703601
# 3   Marlow Avenue         44 1970-01-01 06:12:41      10073   1590048301
# 4   Saladin Drive         44 1970-01-01 06:14:00      10073   1590002001
#
#       to_stop           trip_id                vehicle_id     to_lat  \
# 0  1590012401  10073_0_06:00:00  veh_bus_10073_0_06:00:00  51.488010
# 1  1590703601  10073_0_06:00:00  veh_bus_10073_0_06:00:00  51.486172
# 2  1590048301  10073_0_06:00:00  veh_bus_10073_0_06:00:00  51.485840
# 3  1590002001  10073_0_06:00:00  veh_bus_10073_0_06:00:00  51.488251
# 4  1590002101  10073_0_06:00:00  veh_bus_10073_0_06:00:00  51.486038
#
#      to_lon   from_lat  from_lon     distance  time_delta     speed
# 0  0.274086  51.490292  0.283074   672.047665       120.0  5.600397
# 1  0.256709  51.488010  0.274086  1220.420974       216.0  5.650097
# 2  0.249938  51.486172  0.256709   470.287536        84.0  5.598661
# 3  0.233635  51.485840  0.249938  1160.222268       341.0  3.402411
# 4  0.232072  51.488251  0.233635   268.821170        79.0  3.402800

# %%
trips_with_stops['speed'].describe()

# max speed is clearly an error, but I'm prepared to broadly credit this dataset.
# Out:
# count    1.368596e+06
# mean     6.460726e+00
# std      3.785154e+00
# min      5.612448e-03
# 25%      4.209896e+00
# 50%      5.667834e+00
# 75%      7.771441e+00
# max      2.496435e+02
# Name: speed, dtype: float64

# %%
import time
speed = 6.265
from_stop = market_town_links[0][0]
to_stop = market_town_links[0][1]

# new and exciting distance calculator:

for transitstops in sched_root.findall("transitStops"):
    # then drill to stopFacility
    for stopFacility in transitstops.findall("stopFacility"):
        # find the exact one we want
        if stopFacility.get("id") == market_town_stops[from_stop]:
            # then get x, y
            x_val = float(stopFacility.get("x"))
            y_val = float(stopFacility.get("y"))

latlon = OSGB36toWGS84(x_val, y_val)            

for transitstops in sched_root.findall("transitStops"):
    # then drill to stopFacility
    for stopFacility in transitstops.findall("stopFacility"):
        # find the exact one we want
        if stopFacility.get("id") == market_town_stops[to_stop]:
            # then get x, y
            x_val2 = float(stopFacility.get("x"))
            y_val2 = float(stopFacility.get("y"))
 
latlon2 = OSGB36toWGS84(x_val2, y_val2)

# get the number

distance = haversine(latlon[0], latlon[1], latlon2[0], latlon2[1])

# canned this one for obvious reasons:
# distance = spatial.distance_between_s2cellids(int(market_town_stops[from_stop]), int(market_town_stops[to_stop]))

time_s = distance/speed

from_stop, to_stop, time.strftime('%H:%M:%S', time.gmtime(time_s))
# Out:
# ('Aldeburgh', 'Woodbridge', '00:53:47')

# %%
# ok - that sounds better!

trip_departures = list(pd.date_range(start='00:00:00', end='23:59:59', freq='15min'))

# %%
from genet import Route, Service

import xml.etree.ElementTree as ET

# Get the config:

sched_raw = ET.parse("/mnt/c/_BERTIE_data/2_2040_do_minimum_40WFH/output_transitSchedule.xml")

sched_root = sched_raw.getroot()

def add_service(from_stop, to_stop, stop_dict):
    speed = 6.265
    
    # had to amend this line, because of the earlier issues with non-integer stop ids:

    # ok, so I've finally found a workaround after encountering a mass of non-integer stop ids. 

    # it involves manually using elementtree to extract the x and y of each stop and then haversine-ing the distance.

    # I'd just like Arup to know, whoever constructed distance_between_s2cellids is now my biggest enemy.

    for transitstops in sched_root.findall("transitStops"):
        # then drill to stopFacility
        for stopFacility in transitstops.findall("stopFacility"):
            # find the exact one we want
            if stopFacility.get("id") == stop_dict[from_stop]:
                # then get x, y
                x_val = float(stopFacility.get("x"))
                y_val = float(stopFacility.get("y"))

    latlon = OSGB36toWGS84(x_val, y_val)            

    for transitstops in sched_root.findall("transitStops"):
        # then drill to stopFacility
        for stopFacility in transitstops.findall("stopFacility"):
            # find the exact one we want
            if stopFacility.get("id") == stop_dict[to_stop]:
                # then get x, y
                x_val2 = float(stopFacility.get("x"))
                y_val2 = float(stopFacility.get("y"))
 
    latlon2 = OSGB36toWGS84(x_val2, y_val2)

    # get the number

    distance = haversine(latlon[0], latlon[1], latlon2[0], latlon2[1])

    # now it is working, so the old method is out:

    # distance = spatial.distance_between_s2cellids(int(stop_dict[from_stop]), int(stop_dict[to_stop]))

    # now back to pre-existing code:

    time_offset =  time.strftime('%H:%M:%S', time.gmtime(distance/speed))
    print(type(time_offset))
    trip_departures = list(pd.date_range(start='00:00:00', end='23:59:59', freq='15min'))
    
    service_id = f'service_{from_stop}_{to_stop}'
    
    route_id = f'route_{from_stop}_{to_stop}'
    route_from = Route(
        route_short_name=route_id,
        mode='bus',
        trips={
            'trip_id': [f'{route_id}_{t.hour:02}-{t.minute:02}-{t.second:02}' for t in trip_departures],
            'trip_departure_time': [t.strftime('%H:%M:%S') for t in trip_departures],
            'vehicle_id': [f'veh_scenario_bus_{route_id}_{i}' for i in range(len(trip_departures))]
        },
        arrival_offsets=['00:00:00', time_offset],
        departure_offsets=['00:00:00', time_offset],
        id=route_id,
        await_departure= [True, True],
        stops=[n.schedule.stop(stop_dict[from_stop]), n.schedule.stop(stop_dict[to_stop])]
    )

    route_id = f'route_{to_stop}_{from_stop}'
    route_to = Route(
        route_short_name=route_id,
        mode='bus',
        trips={
            'trip_id': [f'{route_id}_{t.hour:02}-{t.minute:02}-{t.second:02}' for t in trip_departures],
            'trip_departure_time': [t.strftime('%H:%M:%S') for t in trip_departures],
            # this bit should be adding the vehicle id!
            'vehicle_id': [f'veh_scenario_bus_{route_id}_{i}' for i in range(len(trip_departures))]
        },
        arrival_offsets=['00:00:00', time_offset],
        departure_offsets=['00:00:00', time_offset],
        id=route_id,
        await_departure= [True, True],
        stops=[n.schedule.stop(stop_dict[to_stop]), n.schedule.stop(stop_dict[from_stop])]
    )

    print(f'Adding {service_id}. Time offset: {time_offset}')
    n.schedule.add_service(Service(id=service_id, routes=[route_from, route_to]))
    print(f'Routing {service_id}.')
    n.reroute(service_id)
    n.schedule.generate_vehicles()
    return service_id

# %%
# new veh related code

len(n.schedule.vehicles)
# Out:
# 70354

# %%
# realise the new services!!!!

services = []
for market_town_connection in market_town_links:
    s = add_service(
        market_town_connection[0], 
        market_town_connection[1], 
        market_town_stops)
    services.append(s)
# Out:
# 2025-12-19 09:48:51,613 - Added Services with IDs `['service_Aldeburgh_Woodbridge']` and Routes: [['route_Aldeburgh_Woodbridge', 'route_Woodbridge_Aldeburgh']]
# <class 'str'>
# Adding service_Aldeburgh_Woodbridge. Time offset: 00:53:47
# 2025-12-19 09:48:55,063 - Rerouting Service `service_Aldeburgh_Woodbridge`
# 2025-12-19 09:48:55,073 - Checking `linkRefId`s of the Route: `route_Aldeburgh_Woodbridge` are present in the graph
# 2025-12-19 09:48:55,180 - Rerouting Route `route_Aldeburgh_Woodbridge`
# Routing service_Aldeburgh_Woodbridge.
# 2025-12-19 09:49:00,130 - Changed Route attributes for 1 routes
# 2025-12-19 09:49:00,286 - Checking `linkRefId`s of the Route: `route_Woodbridge_Aldeburgh` are present in the graph
# 2025-12-19 09:49:00,383 - Rerouting Route `route_Woodbridge_Aldeburgh`
# 2025-12-19 09:49:08,370 - Changed Route attributes for 1 routes
# 2025-12-19 09:49:12,086 - Added Services with IDs `['service_Bury_St_Edmunds_Beck_Row']` and Routes: [['route_Bury_St_Edmunds_Beck_Row', 'route_Beck_Row_Bury_St_Edmunds']]
# <class 'str'>
# Adding service_Bury_St_Edmunds_Beck_Row. Time offset: 00:55:00
# 2025-12-19 09:49:18,495 - Rerouting Service `service_Bury_St_Edmunds_Beck_Row`
# 2025-12-19 09:49:18,513 - Checking `linkRefId`s of the Route: `route_Bury_St_Edmunds_Beck_Row` are present in the graph
# 2025-12-19 09:49:18,610 - Rerouting Route `route_Bury_St_Edmunds_Beck_Row`
# Routing service_Bury_St_Edmunds_Beck_Row.
# 2025-12-19 09:49:23,551 - Changed Route attributes for 1 routes
# 2025-12-19 09:49:23,706 - Checking `linkRefId`s of the Route: `route_Beck_Row_Bury_St_Edmunds` are present in the graph
# 2025-12-19 09:49:23,798 - Rerouting Route `route_Beck_Row_Bury_St_Edmunds`
# 2025-12-19 09:49:28,776 - Changed Route attributes for 1 routes
# 2025-12-19 09:49:32,545 - Added Services with IDs `['service_Bury_St_Edmunds_Brandon']` and Routes: [['route_Bury_St_Edmunds_Brandon', 'route_Brandon_Bury_St_Edmunds']]
# <class 'str'>
# Adding service_Bury_St_Edmunds_Brandon. Time offset: 01:01:47
# 2025-12-19 09:49:38,860 - Rerouting Service `service_Bury_St_Edmunds_Brandon`
# 2025-12-19 09:49:38,870 - Checking `linkRefId`s of the Route: `route_Bury_St_Edmunds_Brandon` are present in the graph
# 2025-12-19 09:49:38,962 - Rerouting Route `route_Bury_St_Edmunds_Brandon`
# Routing service_Bury_St_Edmunds_Brandon.
# 2025-12-19 09:49:43,857 - Changed Route attributes for 1 routes
# 2025-12-19 09:49:44,019 - Checking `linkRefId`s of the Route: `route_Brandon_Bury_St_Edmunds` are present in the graph
# 2025-12-19 09:49:44,111 - Rerouting Route `route_Brandon_Bury_St_Edmunds`
# 2025-12-19 09:49:48,935 - Changed Route attributes for 1 routes
# 2025-12-19 09:49:55,399 - Added Services with IDs `['service_Bury_St_Edmunds_Elmswell']` and Routes: [['route_Bury_St_Edmunds_Elmswell', 'route_Elmswell_Bury_St_Edmunds']]
# <class 'str'>
# Adding service_Bury_St_Edmunds_Elmswell. Time offset: 00:35:38
# 2025-12-19 09:50:01,621 - Rerouting Service `service_Bury_St_Edmunds_Elmswell`
# 2025-12-19 09:50:01,636 - Checking `linkRefId`s of the Route: `route_Bury_St_Edmunds_Elmswell` are present in the graph
# 2025-12-19 09:50:01,729 - Rerouting Route `route_Bury_St_Edmunds_Elmswell`
# Routing service_Bury_St_Edmunds_Elmswell.
# 2025-12-19 09:50:06,729 - Changed Route attributes for 1 routes
# 2025-12-19 09:50:06,886 - Checking `linkRefId`s of the Route: `route_Elmswell_Bury_St_Edmunds` are present in the graph
# 2025-12-19 09:50:06,990 - Rerouting Route `route_Elmswell_Bury_St_Edmunds`
# 2025-12-19 09:50:11,860 - Changed Route attributes for 1 routes
# 2025-12-19 09:50:15,610 - Added Services with IDs `['service_Bury_St_Edmunds_Haverhill']` and Routes: [['route_Bury_St_Edmunds_Haverhill', 'route_Haverhill_Bury_St_Edmunds']]
# <class 'str'>
# Adding service_Bury_St_Edmunds_Haverhill. Time offset: 01:09:58
# 2025-12-19 09:50:21,934 - Rerouting Service `service_Bury_St_Edmunds_Haverhill`
# 2025-12-19 09:50:21,945 - Checking `linkRefId`s of the Route: `route_Bury_St_Edmunds_Haverhill` are present in the graph
# 2025-12-19 09:50:22,043 - Rerouting Route `route_Bury_St_Edmunds_Haverhill`
# Routing service_Bury_St_Edmunds_Haverhill.
# 2025-12-19 09:50:26,777 - Changed Route attributes for 1 routes
# 2025-12-19 09:50:26,922 - Checking `linkRefId`s of the Route: `route_Haverhill_Bury_St_Edmunds` are present in the graph
# 2025-12-19 09:50:27,017 - Rerouting Route `route_Haverhill_Bury_St_Edmunds`
# 2025-12-19 09:50:31,768 - Changed Route attributes for 1 routes
# 2025-12-19 09:50:38,391 - Added Services with IDs `['service_Bury_St_Edmunds_Ixworth']` and Routes: [['route_Bury_St_Edmunds_Ixworth', 'route_Ixworth_Bury_St_Edmunds']]
# <class 'str'>
# Adding service_Bury_St_Edmunds_Ixworth. Time offset: 00:26:36
# 2025-12-19 09:50:45,185 - Rerouting Service `service_Bury_St_Edmunds_Ixworth`
# 2025-12-19 09:50:45,197 - Checking `linkRefId`s of the Route: `route_Bury_St_Edmunds_Ixworth` are present in the graph
# 2025-12-19 09:50:45,292 - Rerouting Route `route_Bury_St_Edmunds_Ixworth`
# Routing service_Bury_St_Edmunds_Ixworth.
# 2025-12-19 09:50:50,138 - Changed Route attributes for 1 routes
# 2025-12-19 09:50:50,306 - Checking `linkRefId`s of the Route: `route_Ixworth_Bury_St_Edmunds` are present in the graph
# 2025-12-19 09:50:50,400 - Rerouting Route `route_Ixworth_Bury_St_Edmunds`
# 2025-12-19 09:50:55,327 - Changed Route attributes for 1 routes
# 2025-12-19 09:50:59,244 - Added Services with IDs `['service_Bury_St_Edmunds_Long_Melford']` and Routes: [['route_Bury_St_Edmunds_Long_Melford', 'route_Long_Melford_Bury_St_Edmunds']]
# <class 'str'>
# Adding service_Bury_St_Edmunds_Long_Melford. Time offset: 00:50:26
# 2025-12-19 09:51:05,772 - Rerouting Service `service_Bury_St_Edmunds_Long_Melford`
# 2025-12-19 09:51:05,783 - Checking `linkRefId`s of the Route: `route_Bury_St_Edmunds_Long_Melford` are present in the graph
# 2025-12-19 09:51:05,871 - Rerouting Route `route_Bury_St_Edmunds_Long_Melford`
# Routing service_Bury_St_Edmunds_Long_Melford.
# 2025-12-19 09:51:10,895 - Changed Route attributes for 1 routes
# 2025-12-19 09:51:11,039 - Checking `linkRefId`s of the Route: `route_Long_Melford_Bury_St_Edmunds` are present in the graph
# 2025-12-19 09:51:11,136 - Rerouting Route `route_Long_Melford_Bury_St_Edmunds`
# 2025-12-19 09:51:15,953 - Changed Route attributes for 1 routes
# 2025-12-19 09:51:22,551 - Added Services with IDs `['service_Bury_St_Edmunds_Mildenhall']` and Routes: [['route_Bury_St_Edmunds_Mildenhall', 'route_Mildenhall_Bury_St_Edmunds']]
# <class 'str'>
# Adding service_Bury_St_Edmunds_Mildenhall. Time offset: 00:47:00
# 2025-12-19 09:51:29,098 - Rerouting Service `service_Bury_St_Edmunds_Mildenhall`
# 2025-12-19 09:51:29,110 - Checking `linkRefId`s of the Route: `route_Bury_St_Edmunds_Mildenhall` are present in the graph
# 2025-12-19 09:51:29,199 - Rerouting Route `route_Bury_St_Edmunds_Mildenhall`
# Routing service_Bury_St_Edmunds_Mildenhall.
# 2025-12-19 09:51:34,089 - Changed Route attributes for 1 routes
# 2025-12-19 09:51:34,235 - Checking `linkRefId`s of the Route: `route_Mildenhall_Bury_St_Edmunds` are present in the graph
# 2025-12-19 09:51:34,334 - Rerouting Route `route_Mildenhall_Bury_St_Edmunds`
# 2025-12-19 09:51:39,306 - Changed Route attributes for 1 routes
# 2025-12-19 09:51:42,997 - Added Services with IDs `['service_Bury_St_Edmunds_Newmarket']` and Routes: [['route_Bury_St_Edmunds_Newmarket', 'route_Newmarket_Bury_St_Edmunds']]
# <class 'str'>
# Adding service_Bury_St_Edmunds_Newmarket. Time offset: 00:56:19
# 2025-12-19 09:51:49,075 - Rerouting Service `service_Bury_St_Edmunds_Newmarket`
# 2025-12-19 09:51:49,085 - Checking `linkRefId`s of the Route: `route_Bury_St_Edmunds_Newmarket` are present in the graph
# 2025-12-19 09:51:49,176 - Rerouting Route `route_Bury_St_Edmunds_Newmarket`
# Routing service_Bury_St_Edmunds_Newmarket.
# 2025-12-19 09:51:54,026 - Changed Route attributes for 1 routes
# 2025-12-19 09:51:54,160 - Checking `linkRefId`s of the Route: `route_Newmarket_Bury_St_Edmunds` are present in the graph
# 2025-12-19 09:51:54,250 - Rerouting Route `route_Newmarket_Bury_St_Edmunds`
# 2025-12-19 09:51:59,155 - Changed Route attributes for 1 routes
# 2025-12-19 09:52:05,809 - Added Services with IDs `['service_Bury_St_Edmunds_Stowmarket']` and Routes: [['route_Bury_St_Edmunds_Stowmarket', 'route_Stowmarket_Bury_St_Edmunds']]
# <class 'str'>
# Adding service_Bury_St_Edmunds_Stowmarket. Time offset: 00:53:35
# 2025-12-19 09:52:12,449 - Rerouting Service `service_Bury_St_Edmunds_Stowmarket`
# 2025-12-19 09:52:12,463 - Checking `linkRefId`s of the Route: `route_Bury_St_Edmunds_Stowmarket` are present in the graph
# 2025-12-19 09:52:12,557 - Rerouting Route `route_Bury_St_Edmunds_Stowmarket`
# Routing service_Bury_St_Edmunds_Stowmarket.
# 2025-12-19 09:52:17,488 - Changed Route attributes for 1 routes
# 2025-12-19 09:52:17,631 - Checking `linkRefId`s of the Route: `route_Stowmarket_Bury_St_Edmunds` are present in the graph
# 2025-12-19 09:52:17,728 - Rerouting Route `route_Stowmarket_Bury_St_Edmunds`
# 2025-12-19 09:52:22,707 - Changed Route attributes for 1 routes
# <class 'str'>
# Adding service_Bury_St_Edmunds_Sudbury. Time offset: 01:01:05
# 2025-12-19 09:52:29,298 - Added Services with IDs `['service_Bury_St_Edmunds_Sudbury']` and Routes: [['route_Bury_St_Edmunds_Sudbury', 'route_Sudbury_Bury_St_Edmunds']]
# 2025-12-19 09:52:32,785 - Rerouting Service `service_Bury_St_Edmunds_Sudbury`
# 2025-12-19 09:52:32,799 - Checking `linkRefId`s of the Route: `route_Bury_St_Edmunds_Sudbury` are present in the graph
# 2025-12-19 09:52:32,902 - Rerouting Route `route_Bury_St_Edmunds_Sudbury`
# Routing service_Bury_St_Edmunds_Sudbury.
# 2025-12-19 09:52:37,819 - Changed Route attributes for 1 routes
# 2025-12-19 09:52:37,970 - Checking `linkRefId`s of the Route: `route_Sudbury_Bury_St_Edmunds` are present in the graph
# 2025-12-19 09:52:38,060 - Rerouting Route `route_Sudbury_Bury_St_Edmunds`
# 2025-12-19 09:52:46,105 - Changed Route attributes for 1 routes
# 2025-12-19 09:52:49,793 - Added Services with IDs `['service_Bury_St_Edmunds_Thurston']` and Routes: [['route_Bury_St_Edmunds_Thurston', 'route_Thurston_Bury_St_Edmunds']]
# <class 'str'>
# Adding service_Bury_St_Edmunds_Thurston. Time offset: 00:16:38
# 2025-12-19 09:52:56,273 - Rerouting Service `service_Bury_St_Edmunds_Thurston`
# 2025-12-19 09:52:56,285 - Checking `linkRefId`s of the Route: `route_Bury_St_Edmunds_Thurston` are present in the graph
# 2025-12-19 09:52:56,381 - Rerouting Route `route_Bury_St_Edmunds_Thurston`
# Routing service_Bury_St_Edmunds_Thurston.
# 2025-12-19 09:53:01,347 - Changed Route attributes for 1 routes
# 2025-12-19 09:53:01,506 - Checking `linkRefId`s of the Route: `route_Thurston_Bury_St_Edmunds` are present in the graph
# 2025-12-19 09:53:01,600 - Rerouting Route `route_Thurston_Bury_St_Edmunds`
# 2025-12-19 09:53:06,425 - Changed Route attributes for 1 routes
# 2025-12-19 09:53:10,216 - Added Services with IDs `['service_Capel_St_Mary_Hadleigh']` and Routes: [['route_Capel_St_Mary_Hadleigh', 'route_Hadleigh_Capel_St_Mary']]
# <class 'str'>
# Adding service_Capel_St_Mary_Hadleigh. Time offset: 00:22:16
# 2025-12-19 09:53:16,675 - Rerouting Service `service_Capel_St_Mary_Hadleigh`
# 2025-12-19 09:53:16,690 - Checking `linkRefId`s of the Route: `route_Capel_St_Mary_Hadleigh` are present in the graph
# 2025-12-19 09:53:16,782 - Rerouting Route `route_Capel_St_Mary_Hadleigh`
# Routing service_Capel_St_Mary_Hadleigh.
# 2025-12-19 09:53:21,681 - Changed Route attributes for 1 routes
# 2025-12-19 09:53:21,846 - Checking `linkRefId`s of the Route: `route_Hadleigh_Capel_St_Mary` are present in the graph
# 2025-12-19 09:53:21,942 - Rerouting Route `route_Hadleigh_Capel_St_Mary`
# 2025-12-19 09:53:30,221 - Changed Route attributes for 1 routes
# 2025-12-19 09:53:33,908 - Added Services with IDs `['service_Clare_Haverhill']` and Routes: [['route_Clare_Haverhill', 'route_Haverhill_Clare']]
# <class 'str'>
# Adding service_Clare_Haverhill. Time offset: 00:25:33
# 2025-12-19 09:53:40,434 - Rerouting Service `service_Clare_Haverhill`
# 2025-12-19 09:53:40,446 - Checking `linkRefId`s of the Route: `route_Clare_Haverhill` are present in the graph
# 2025-12-19 09:53:40,537 - Rerouting Route `route_Clare_Haverhill`
# Routing service_Clare_Haverhill.
# 2025-12-19 09:53:45,410 - Changed Route attributes for 1 routes
# 2025-12-19 09:53:45,557 - Checking `linkRefId`s of the Route: `route_Haverhill_Clare` are present in the graph
# 2025-12-19 09:53:45,649 - Rerouting Route `route_Haverhill_Clare`
# 2025-12-19 09:53:50,534 - Changed Route attributes for 1 routes
# 2025-12-19 09:53:54,126 - Added Services with IDs `['service_East_Bergholt_Hadleigh']` and Routes: [['route_East_Bergholt_Hadleigh', 'route_Hadleigh_East_Bergholt']]
# <class 'str'>
# Adding service_East_Bergholt_Hadleigh. Time offset: 00:22:51
# 2025-12-19 09:54:00,578 - Rerouting Service `service_East_Bergholt_Hadleigh`
# 2025-12-19 09:54:00,591 - Checking `linkRefId`s of the Route: `route_East_Bergholt_Hadleigh` are present in the graph
# 2025-12-19 09:54:00,684 - Rerouting Route `route_East_Bergholt_Hadleigh`
# Routing service_East_Bergholt_Hadleigh.
# 2025-12-19 09:54:05,578 - Changed Route attributes for 1 routes
# 2025-12-19 09:54:05,742 - Checking `linkRefId`s of the Route: `route_Hadleigh_East_Bergholt` are present in the graph
# 2025-12-19 09:54:05,841 - Rerouting Route `route_Hadleigh_East_Bergholt`
# 2025-12-19 09:54:10,766 - Changed Route attributes for 1 routes
# 2025-12-19 09:54:17,302 - Added Services with IDs `['service_Eye_Stowmarket']` and Routes: [['route_Eye_Stowmarket', 'route_Stowmarket_Eye']]
# <class 'str'>
# Adding service_Eye_Stowmarket. Time offset: 00:48:11
# 2025-12-19 09:54:24,010 - Rerouting Service `service_Eye_Stowmarket`
# 2025-12-19 09:54:24,023 - Checking `linkRefId`s of the Route: `route_Eye_Stowmarket` are present in the graph
# 2025-12-19 09:54:24,114 - Rerouting Route `route_Eye_Stowmarket`
# Routing service_Eye_Stowmarket.
# 2025-12-19 09:54:29,027 - Changed Route attributes for 1 routes
# 2025-12-19 09:54:29,185 - Checking `linkRefId`s of the Route: `route_Stowmarket_Eye` are present in the graph
# 2025-12-19 09:54:29,279 - Rerouting Route `route_Stowmarket_Eye`
# 2025-12-19 09:54:34,077 - Changed Route attributes for 1 routes
# 2025-12-19 09:54:38,047 - Added Services with IDs `['service_Ipswich_Felixstowe']` and Routes: [['route_Ipswich_Felixstowe', 'route_Felixstowe_Ipswich']]
# <class 'str'>
# Adding service_Ipswich_Felixstowe. Time offset: 00:44:49
# 2025-12-19 09:54:44,436 - Rerouting Service `service_Ipswich_Felixstowe`
# 2025-12-19 09:54:44,448 - Checking `linkRefId`s of the Route: `route_Ipswich_Felixstowe` are present in the graph
# 2025-12-19 09:54:44,541 - Rerouting Route `route_Ipswich_Felixstowe`
# Routing service_Ipswich_Felixstowe.
# 2025-12-19 09:54:49,308 - Changed Route attributes for 1 routes
# 2025-12-19 09:54:49,464 - Checking `linkRefId`s of the Route: `route_Felixstowe_Ipswich` are present in the graph
# 2025-12-19 09:54:49,556 - Rerouting Route `route_Felixstowe_Ipswich`
# 2025-12-19 09:54:57,784 - Changed Route attributes for 1 routes
# 2025-12-19 09:55:01,440 - Added Services with IDs `['service_Ipswich_Framlingham']` and Routes: [['route_Ipswich_Framlingham', 'route_Framlingham_Ipswich']]
# <class 'str'>
# Adding service_Ipswich_Framlingham. Time offset: 00:59:16
# 2025-12-19 09:55:08,009 - Rerouting Service `service_Ipswich_Framlingham`
# 2025-12-19 09:55:08,021 - Checking `linkRefId`s of the Route: `route_Ipswich_Framlingham` are present in the graph
# 2025-12-19 09:55:08,113 - Rerouting Route `route_Ipswich_Framlingham`
# Routing service_Ipswich_Framlingham.
# 2025-12-19 09:55:13,012 - Changed Route attributes for 1 routes
# 2025-12-19 09:55:13,168 - Checking `linkRefId`s of the Route: `route_Framlingham_Ipswich` are present in the graph
# 2025-12-19 09:55:13,257 - Rerouting Route `route_Framlingham_Ipswich`
# 2025-12-19 09:55:18,215 - Changed Route attributes for 1 routes
# <class 'str'>
# Adding service_Ipswich_Hadleigh. Time offset: 00:37:03
# 2025-12-19 09:55:24,873 - Added Services with IDs `['service_Ipswich_Hadleigh']` and Routes: [['route_Ipswich_Hadleigh', 'route_Hadleigh_Ipswich']]
# 2025-12-19 09:55:28,514 - Rerouting Service `service_Ipswich_Hadleigh`
# 2025-12-19 09:55:28,528 - Checking `linkRefId`s of the Route: `route_Ipswich_Hadleigh` are present in the graph
# 2025-12-19 09:55:28,626 - Rerouting Route `route_Ipswich_Hadleigh`
# Routing service_Ipswich_Hadleigh.
# 2025-12-19 09:55:33,552 - Changed Route attributes for 1 routes
# 2025-12-19 09:55:33,708 - Checking `linkRefId`s of the Route: `route_Hadleigh_Ipswich` are present in the graph
# 2025-12-19 09:55:33,806 - Rerouting Route `route_Hadleigh_Ipswich`
# 2025-12-19 09:55:41,593 - Changed Route attributes for 1 routes
# 2025-12-19 09:55:45,337 - Added Services with IDs `['service_Ipswich_Leiston']` and Routes: [['route_Ipswich_Leiston', 'route_Leiston_Ipswich']]
# <class 'str'>
# Adding service_Ipswich_Leiston. Time offset: 01:28:18
# 2025-12-19 09:55:51,993 - Rerouting Service `service_Ipswich_Leiston`
# 2025-12-19 09:55:52,005 - Checking `linkRefId`s of the Route: `route_Ipswich_Leiston` are present in the graph
# 2025-12-19 09:55:52,103 - Rerouting Route `route_Ipswich_Leiston`
# Routing service_Ipswich_Leiston.
# 2025-12-19 09:55:57,023 - Changed Route attributes for 1 routes
# 2025-12-19 09:55:57,174 - Checking `linkRefId`s of the Route: `route_Leiston_Ipswich` are present in the graph
# 2025-12-19 09:55:57,269 - Rerouting Route `route_Leiston_Ipswich`
# 2025-12-19 09:56:02,109 - Changed Route attributes for 1 routes
# 2025-12-19 09:56:09,004 - Added Services with IDs `['service_Ipswich_Needham_Market']` and Routes: [['route_Ipswich_Needham_Market', 'route_Needham_Market_Ipswich']]
# <class 'str'>
# Adding service_Ipswich_Needham_Market. Time offset: 00:34:06
# 2025-12-19 09:56:12,526 - Rerouting Service `service_Ipswich_Needham_Market`
# 2025-12-19 09:56:12,539 - Checking `linkRefId`s of the Route: `route_Ipswich_Needham_Market` are present in the graph
# 2025-12-19 09:56:12,635 - Rerouting Route `route_Ipswich_Needham_Market`
# Routing service_Ipswich_Needham_Market.
# 2025-12-19 09:56:17,557 - Changed Route attributes for 1 routes
# 2025-12-19 09:56:17,702 - Checking `linkRefId`s of the Route: `route_Needham_Market_Ipswich` are present in the graph
# 2025-12-19 09:56:17,792 - Rerouting Route `route_Needham_Market_Ipswich`
# 2025-12-19 09:56:22,628 - Changed Route attributes for 1 routes
# 2025-12-19 09:56:29,412 - Added Services with IDs `['service_Ipswich_Rendlesham']` and Routes: [['route_Ipswich_Rendlesham', 'route_Rendlesham_Ipswich']]
# <class 'str'>
# Adding service_Ipswich_Rendlesham. Time offset: 00:51:11
# 2025-12-19 09:56:36,130 - Rerouting Service `service_Ipswich_Rendlesham`
# 2025-12-19 09:56:36,145 - Checking `linkRefId`s of the Route: `route_Ipswich_Rendlesham` are present in the graph
# 2025-12-19 09:56:36,238 - Rerouting Route `route_Ipswich_Rendlesham`
# Routing service_Ipswich_Rendlesham.
# 2025-12-19 09:56:41,089 - Changed Route attributes for 1 routes
# 2025-12-19 09:56:41,228 - Checking `linkRefId`s of the Route: `route_Rendlesham_Ipswich` are present in the graph
# 2025-12-19 09:56:41,314 - Rerouting Route `route_Rendlesham_Ipswich`
# 2025-12-19 09:56:46,248 - Changed Route attributes for 1 routes
# <class 'str'>
# Adding service_Ipswich_Saxmundham. Time offset: 01:16:33
# 2025-12-19 09:56:52,742 - Added Services with IDs `['service_Ipswich_Saxmundham']` and Routes: [['route_Ipswich_Saxmundham', 'route_Saxmundham_Ipswich']]
# 2025-12-19 09:56:56,276 - Rerouting Service `service_Ipswich_Saxmundham`
# 2025-12-19 09:56:56,288 - Checking `linkRefId`s of the Route: `route_Ipswich_Saxmundham` are present in the graph
# 2025-12-19 09:56:56,388 - Rerouting Route `route_Ipswich_Saxmundham`
# Routing service_Ipswich_Saxmundham.
# 2025-12-19 09:57:01,323 - Changed Route attributes for 1 routes
# 2025-12-19 09:57:01,476 - Checking `linkRefId`s of the Route: `route_Saxmundham_Ipswich` are present in the graph
# 2025-12-19 09:57:01,568 - Rerouting Route `route_Saxmundham_Ipswich`
# 2025-12-19 09:57:09,323 - Changed Route attributes for 1 routes
# 2025-12-19 09:57:13,208 - Added Services with IDs `['service_Ipswich_Shotley']` and Routes: [['route_Ipswich_Shotley', 'route_Shotley_Ipswich']]
# <class 'str'>
# Adding service_Ipswich_Shotley. Time offset: 00:30:50
# 2025-12-19 09:57:19,975 - Rerouting Service `service_Ipswich_Shotley`
# 2025-12-19 09:57:19,989 - Checking `linkRefId`s of the Route: `route_Ipswich_Shotley` are present in the graph
# 2025-12-19 09:57:20,090 - Rerouting Route `route_Ipswich_Shotley`
# Routing service_Ipswich_Shotley.
# 2025-12-19 09:57:25,028 - Changed Route attributes for 1 routes
# 2025-12-19 09:57:25,192 - Checking `linkRefId`s of the Route: `route_Shotley_Ipswich` are present in the graph
# 2025-12-19 09:57:25,285 - Rerouting Route `route_Shotley_Ipswich`
# 2025-12-19 09:57:30,301 - Changed Route attributes for 1 routes
# 2025-12-19 09:57:37,202 - Added Services with IDs `['service_Ipswich_Stowmarket']` and Routes: [['route_Ipswich_Stowmarket', 'route_Stowmarket_Ipswich']]
# <class 'str'>
# Adding service_Ipswich_Stowmarket. Time offset: 00:48:44
# 2025-12-19 09:57:40,728 - Rerouting Service `service_Ipswich_Stowmarket`
# 2025-12-19 09:57:40,743 - Checking `linkRefId`s of the Route: `route_Ipswich_Stowmarket` are present in the graph
# 2025-12-19 09:57:40,838 - Rerouting Route `route_Ipswich_Stowmarket`
# Routing service_Ipswich_Stowmarket.
# 2025-12-19 09:57:45,755 - Changed Route attributes for 1 routes
# 2025-12-19 09:57:45,921 - Checking `linkRefId`s of the Route: `route_Stowmarket_Ipswich` are present in the graph
# 2025-12-19 09:57:46,013 - Rerouting Route `route_Stowmarket_Ipswich`
# 2025-12-19 10:01:15,824 - Changed Route attributes for 1 routes
# <class 'str'>
# Adding service_Ipswich_Woodbridge. Time offset: 00:31:35
# 2025-12-19 10:01:30,653 - Added Services with IDs `['service_Ipswich_Woodbridge']` and Routes: [['route_Ipswich_Woodbridge', 'route_Woodbridge_Ipswich']]
# 2025-12-19 10:01:45,261 - Rerouting Service `service_Ipswich_Woodbridge`
# 2025-12-19 10:01:45,306 - Checking `linkRefId`s of the Route: `route_Ipswich_Woodbridge` are present in the graph
# Routing service_Ipswich_Woodbridge.
# 2025-12-19 10:01:45,555 - Rerouting Route `route_Ipswich_Woodbridge`
# 2025-12-19 10:01:55,203 - Changed Route attributes for 1 routes
# 2025-12-19 10:01:55,522 - Checking `linkRefId`s of the Route: `route_Woodbridge_Ipswich` are present in the graph
# 2025-12-19 10:01:55,723 - Rerouting Route `route_Woodbridge_Ipswich`
# 2025-12-19 10:02:05,458 - Changed Route attributes for 1 routes
# 2025-12-19 10:02:20,663 - Added Services with IDs `['service_Lowestoft_Beccles']` and Routes: [['route_Lowestoft_Beccles', 'route_Beccles_Lowestoft']]
# <class 'str'>
# Adding service_Lowestoft_Beccles. Time offset: 00:33:57
# 2025-12-19 10:02:30,276 - Rerouting Service `service_Lowestoft_Beccles`
# 2025-12-19 10:02:30,311 - Checking `linkRefId`s of the Route: `route_Lowestoft_Beccles` are present in the graph
# Routing service_Lowestoft_Beccles.
# 2025-12-19 10:02:30,504 - Rerouting Route `route_Lowestoft_Beccles`
# 2025-12-19 10:02:40,388 - Changed Route attributes for 1 routes
# 2025-12-19 10:02:40,701 - Checking `linkRefId`s of the Route: `route_Beccles_Lowestoft` are present in the graph
# 2025-12-19 10:02:40,904 - Rerouting Route `route_Beccles_Lowestoft`
# 2025-12-19 10:02:50,921 - Changed Route attributes for 1 routes
# 2025-12-19 10:03:05,681 - Added Services with IDs `['service_Lowestoft_Bungay']` and Routes: [['route_Lowestoft_Bungay', 'route_Bungay_Lowestoft']]
# <class 'str'>
# Adding service_Lowestoft_Bungay. Time offset: 00:56:40
# 2025-12-19 10:03:19,906 - Rerouting Service `service_Lowestoft_Bungay`
# 2025-12-19 10:03:19,932 - Checking `linkRefId`s of the Route: `route_Lowestoft_Bungay` are present in the graph
# Routing service_Lowestoft_Bungay.
# 2025-12-19 10:03:20,110 - Rerouting Route `route_Lowestoft_Bungay`
# 2025-12-19 10:03:29,876 - Changed Route attributes for 1 routes
# 2025-12-19 10:03:30,192 - Checking `linkRefId`s of the Route: `route_Bungay_Lowestoft` are present in the graph
# 2025-12-19 10:03:30,388 - Rerouting Route `route_Bungay_Lowestoft`
# 2025-12-19 10:03:40,001 - Changed Route attributes for 1 routes
# 2025-12-19 10:03:55,647 - Added Services with IDs `['service_Lowestoft_Halesworth']` and Routes: [['route_Lowestoft_Halesworth', 'route_Halesworth_Lowestoft']]
# <class 'str'>
# Adding service_Lowestoft_Halesworth. Time offset: 00:59:27
# 2025-12-19 10:04:04,395 - Rerouting Service `service_Lowestoft_Halesworth`
# 2025-12-19 10:04:04,431 - Checking `linkRefId`s of the Route: `route_Lowestoft_Halesworth` are present in the graph
# Routing service_Lowestoft_Halesworth.
# 2025-12-19 10:04:04,634 - Rerouting Route `route_Lowestoft_Halesworth`
# 2025-12-19 10:04:14,440 - Changed Route attributes for 1 routes
# 2025-12-19 10:04:14,728 - Checking `linkRefId`s of the Route: `route_Halesworth_Lowestoft` are present in the graph
# 2025-12-19 10:04:14,916 - Rerouting Route `route_Halesworth_Lowestoft`
# 2025-12-19 10:04:30,101 - Changed Route attributes for 1 routes
# 2025-12-19 10:04:39,530 - Added Services with IDs `['service_Lowestoft_Leiston']` and Routes: [['route_Lowestoft_Leiston', 'route_Leiston_Lowestoft']]
# <class 'str'>
# Adding service_Lowestoft_Leiston. Time offset: 01:24:57
# 2025-12-19 10:04:53,422 - Rerouting Service `service_Lowestoft_Leiston`
# 2025-12-19 10:04:53,445 - Checking `linkRefId`s of the Route: `route_Lowestoft_Leiston` are present in the graph
# Routing service_Lowestoft_Leiston.
# 2025-12-19 10:04:53,651 - Rerouting Route `route_Lowestoft_Leiston`
# 2025-12-19 10:05:03,240 - Changed Route attributes for 1 routes
# 2025-12-19 10:05:03,550 - Checking `linkRefId`s of the Route: `route_Leiston_Lowestoft` are present in the graph
# 2025-12-19 10:05:03,727 - Rerouting Route `route_Leiston_Lowestoft`
# 2025-12-19 10:05:13,650 - Changed Route attributes for 1 routes
# <class 'str'>
# Adding service_Lowestoft_Saxmundham. Time offset: 01:30:03
# 2025-12-19 10:05:28,353 - Added Services with IDs `['service_Lowestoft_Saxmundham']` and Routes: [['route_Lowestoft_Saxmundham', 'route_Saxmundham_Lowestoft']]
# 2025-12-19 10:05:36,843 - Rerouting Service `service_Lowestoft_Saxmundham`
# 2025-12-19 10:05:36,866 - Checking `linkRefId`s of the Route: `route_Lowestoft_Saxmundham` are present in the graph
# Routing service_Lowestoft_Saxmundham.
# 2025-12-19 10:05:37,057 - Rerouting Route `route_Lowestoft_Saxmundham`
# 2025-12-19 10:05:46,694 - Changed Route attributes for 1 routes
# 2025-12-19 10:05:47,049 - Checking `linkRefId`s of the Route: `route_Saxmundham_Lowestoft` are present in the graph
# 2025-12-19 10:05:47,232 - Rerouting Route `route_Saxmundham_Lowestoft`
# 2025-12-19 10:06:02,746 - Changed Route attributes for 1 routes
# 2025-12-19 10:06:11,755 - Added Services with IDs `['service_Red_Lodge_Mildenhall']` and Routes: [['route_Red_Lodge_Mildenhall', 'route_Mildenhall_Red_Lodge']]
# <class 'str'>
# Adding service_Red_Lodge_Mildenhall. Time offset: 00:11:41
# 2025-12-19 10:06:26,337 - Rerouting Service `service_Red_Lodge_Mildenhall`
# 2025-12-19 10:06:26,359 - Checking `linkRefId`s of the Route: `route_Red_Lodge_Mildenhall` are present in the graph
# Routing service_Red_Lodge_Mildenhall.
# 2025-12-19 10:06:26,564 - Rerouting Route `route_Red_Lodge_Mildenhall`
# 2025-12-19 10:06:36,355 - Changed Route attributes for 1 routes
# 2025-12-19 10:06:36,681 - Checking `linkRefId`s of the Route: `route_Mildenhall_Red_Lodge` are present in the graph
# 2025-12-19 10:06:36,878 - Rerouting Route `route_Mildenhall_Red_Lodge`
# 2025-12-19 10:06:46,991 - Changed Route attributes for 1 routes
# 2025-12-19 10:07:02,187 - Added Services with IDs `['service_Reydon_Halesworth']` and Routes: [['route_Reydon_Halesworth', 'route_Halesworth_Reydon']]
# <class 'str'>
# Adding service_Reydon_Halesworth. Time offset: 00:31:04
# 2025-12-19 10:07:10,964 - Rerouting Service `service_Reydon_Halesworth`
# 2025-12-19 10:07:10,994 - Checking `linkRefId`s of the Route: `route_Reydon_Halesworth` are present in the graph
# Routing service_Reydon_Halesworth.
# 2025-12-19 10:07:11,187 - Rerouting Route `route_Reydon_Halesworth`
# 2025-12-19 10:07:20,512 - Changed Route attributes for 1 routes
# 2025-12-19 10:07:20,802 - Checking `linkRefId`s of the Route: `route_Halesworth_Reydon` are present in the graph
# 2025-12-19 10:07:20,977 - Rerouting Route `route_Halesworth_Reydon`
# 2025-12-19 10:07:36,280 - Changed Route attributes for 1 routes
# 2025-12-19 10:07:45,847 - Added Services with IDs `['service_Downham_Market_Kings_Lynn']` and Routes: [['route_Downham_Market_Kings_Lynn', 'route_Kings_Lynn_Downham_Market']]
# <class 'str'>
# Adding service_Downham_Market_Kings_Lynn. Time offset: 00:44:45
# 2025-12-19 10:07:59,644 - Rerouting Service `service_Downham_Market_Kings_Lynn`
# 2025-12-19 10:07:59,671 - Checking `linkRefId`s of the Route: `route_Downham_Market_Kings_Lynn` are present in the graph
# Routing service_Downham_Market_Kings_Lynn.
# 2025-12-19 10:07:59,859 - Rerouting Route `route_Downham_Market_Kings_Lynn`
# 2025-12-19 10:08:09,558 - Changed Route attributes for 1 routes
# 2025-12-19 10:08:09,906 - Checking `linkRefId`s of the Route: `route_Kings_Lynn_Downham_Market` are present in the graph
# 2025-12-19 10:08:10,068 - Rerouting Route `route_Kings_Lynn_Downham_Market`
# 2025-12-19 10:08:19,718 - Changed Route attributes for 1 routes
# 2025-12-19 10:08:34,075 - Added Services with IDs `['service_Swaffham_Kings_Lynn']` and Routes: [['route_Swaffham_Kings_Lynn', 'route_Kings_Lynn_Swaffham']]
# <class 'str'>
# Adding service_Swaffham_Kings_Lynn. Time offset: 01:00:12
# 2025-12-19 10:08:42,770 - Rerouting Service `service_Swaffham_Kings_Lynn`
# 2025-12-19 10:08:42,803 - Checking `linkRefId`s of the Route: `route_Swaffham_Kings_Lynn` are present in the graph
# Routing service_Swaffham_Kings_Lynn.
# 2025-12-19 10:08:43,006 - Rerouting Route `route_Swaffham_Kings_Lynn`
# 2025-12-19 10:08:53,431 - Changed Route attributes for 1 routes
# 2025-12-19 10:08:53,721 - Checking `linkRefId`s of the Route: `route_Kings_Lynn_Swaffham` are present in the graph
# 2025-12-19 10:08:53,918 - Rerouting Route `route_Kings_Lynn_Swaffham`
# 2025-12-19 10:09:09,129 - Changed Route attributes for 1 routes
# 2025-12-19 10:09:18,832 - Added Services with IDs `['service_Swaffham_Norwich']` and Routes: [['route_Swaffham_Norwich', 'route_Norwich_Swaffham']]
# <class 'str'>
# Adding service_Swaffham_Norwich. Time offset: 01:49:05
# 2025-12-19 10:09:33,628 - Rerouting Service `service_Swaffham_Norwich`
# 2025-12-19 10:09:33,658 - Checking `linkRefId`s of the Route: `route_Swaffham_Norwich` are present in the graph
# Routing service_Swaffham_Norwich.
# 2025-12-19 10:09:33,927 - Rerouting Route `route_Swaffham_Norwich`
# 2025-12-19 10:09:43,675 - Changed Route attributes for 1 routes
# 2025-12-19 10:09:44,005 - Checking `linkRefId`s of the Route: `route_Norwich_Swaffham` are present in the graph
# 2025-12-19 10:09:44,181 - Rerouting Route `route_Norwich_Swaffham`
# 2025-12-19 10:09:53,887 - Changed Route attributes for 1 routes
# <class 'str'>
# Adding service_Wroxham_Norwich. Time offset: 00:31:07
# 2025-12-19 10:10:09,511 - Added Services with IDs `['service_Wroxham_Norwich']` and Routes: [['route_Wroxham_Norwich', 'route_Norwich_Wroxham']]
# 2025-12-19 10:10:18,721 - Rerouting Service `service_Wroxham_Norwich`
# 2025-12-19 10:10:18,745 - Checking `linkRefId`s of the Route: `route_Wroxham_Norwich` are present in the graph
# Routing service_Wroxham_Norwich.
# 2025-12-19 10:10:18,944 - Rerouting Route `route_Wroxham_Norwich`
# 2025-12-19 10:10:28,765 - Changed Route attributes for 1 routes
# 2025-12-19 10:10:29,065 - Checking `linkRefId`s of the Route: `route_Norwich_Wroxham` are present in the graph
# 2025-12-19 10:10:29,268 - Rerouting Route `route_Norwich_Wroxham`
# 2025-12-19 10:10:44,601 - Changed Route attributes for 1 routes
# <class 'str'>
# Adding service_Stalham_Norwich. Time offset: 00:59:15
# 2025-12-19 10:10:54,590 - Added Services with IDs `['service_Stalham_Norwich']` and Routes: [['route_Stalham_Norwich', 'route_Norwich_Stalham']]
# 2025-12-19 10:11:09,304 - Rerouting Service `service_Stalham_Norwich`
# 2025-12-19 10:11:09,320 - Checking `linkRefId`s of the Route: `route_Stalham_Norwich` are present in the graph
# 2025-12-19 10:11:09,472 - Rerouting Route `route_Stalham_Norwich`
# Routing service_Stalham_Norwich.
# 2025-12-19 10:11:19,003 - Changed Route attributes for 1 routes
# 2025-12-19 10:11:19,301 - Checking `linkRefId`s of the Route: `route_Norwich_Stalham` are present in the graph
# 2025-12-19 10:11:19,471 - Rerouting Route `route_Norwich_Stalham`
# 2025-12-19 10:11:29,283 - Changed Route attributes for 1 routes
# <class 'str'>
# Adding service_Aylsham_Norwich. Time offset: 00:49:59
# 2025-12-19 10:11:42,932 - Added Services with IDs `['service_Aylsham_Norwich']` and Routes: [['route_Aylsham_Norwich', 'route_Norwich_Aylsham']]
# 2025-12-19 10:11:52,190 - Rerouting Service `service_Aylsham_Norwich`
# 2025-12-19 10:11:52,217 - Checking `linkRefId`s of the Route: `route_Aylsham_Norwich` are present in the graph
# Routing service_Aylsham_Norwich.
# 2025-12-19 10:11:52,423 - Rerouting Route `route_Aylsham_Norwich`
# 2025-12-19 10:12:06,770 - Changed Route attributes for 1 routes
# 2025-12-19 10:12:07,059 - Checking `linkRefId`s of the Route: `route_Norwich_Aylsham` are present in the graph
# 2025-12-19 10:12:07,210 - Rerouting Route `route_Norwich_Aylsham`
# 2025-12-19 10:12:16,631 - Changed Route attributes for 1 routes
# 2025-12-19 10:12:26,427 - Added Services with IDs `['service_Holt_Cromer']` and Routes: [['route_Holt_Cromer', 'route_Cromer_Holt']]
# <class 'str'>
# Adding service_Holt_Cromer. Time offset: 00:37:52
# 2025-12-19 10:12:40,532 - Rerouting Service `service_Holt_Cromer`
# 2025-12-19 10:12:40,556 - Checking `linkRefId`s of the Route: `route_Holt_Cromer` are present in the graph
# Routing service_Holt_Cromer.
# 2025-12-19 10:12:40,747 - Rerouting Route `route_Holt_Cromer`
# 2025-12-19 10:12:50,592 - Changed Route attributes for 1 routes
# 2025-12-19 10:12:50,903 - Checking `linkRefId`s of the Route: `route_Cromer_Holt` are present in the graph
# 2025-12-19 10:12:51,085 - Rerouting Route `route_Cromer_Holt`
# 2025-12-19 10:13:06,585 - Changed Route attributes for 1 routes
# <class 'str'>
# Adding service_Fakenham_Wells_Next_The_Sea. Time offset: 00:36:38
# 2025-12-19 10:13:15,904 - Added Services with IDs `['service_Fakenham_Wells_Next_The_Sea']` and Routes: [['route_Fakenham_Wells_Next_The_Sea', 'route_Wells_Next_The_Sea_Fakenham']]
# 2025-12-19 10:13:30,666 - Rerouting Service `service_Fakenham_Wells_Next_The_Sea`
# 2025-12-19 10:13:30,695 - Checking `linkRefId`s of the Route: `route_Fakenham_Wells_Next_The_Sea` are present in the graph
# Routing service_Fakenham_Wells_Next_The_Sea.
# 2025-12-19 10:13:30,906 - Rerouting Route `route_Fakenham_Wells_Next_The_Sea`
# 2025-12-19 10:13:40,717 - Changed Route attributes for 1 routes
# 2025-12-19 10:13:41,059 - Checking `linkRefId`s of the Route: `route_Wells_Next_The_Sea_Fakenham` are present in the graph
# 2025-12-19 10:13:41,230 - Rerouting Route `route_Wells_Next_The_Sea_Fakenham`
# 2025-12-19 10:13:51,079 - Changed Route attributes for 1 routes
# <class 'str'>
# Adding service_Hunstanton_Kings_Lynn. Time offset: 00:56:53
# 2025-12-19 10:14:05,769 - Added Services with IDs `['service_Hunstanton_Kings_Lynn']` and Routes: [['route_Hunstanton_Kings_Lynn', 'route_Kings_Lynn_Hunstanton']]
# 2025-12-19 10:14:15,394 - Rerouting Service `service_Hunstanton_Kings_Lynn`
# 2025-12-19 10:14:15,422 - Checking `linkRefId`s of the Route: `route_Hunstanton_Kings_Lynn` are present in the graph
# Routing service_Hunstanton_Kings_Lynn.
# 2025-12-19 10:14:15,636 - Rerouting Route `route_Hunstanton_Kings_Lynn`
# 2025-12-19 10:14:25,523 - Changed Route attributes for 1 routes
# 2025-12-19 10:14:25,841 - Checking `linkRefId`s of the Route: `route_Kings_Lynn_Hunstanton` are present in the graph
# 2025-12-19 10:14:26,035 - Rerouting Route `route_Kings_Lynn_Hunstanton`
# 2025-12-19 10:14:41,817 - Changed Route attributes for 1 routes
# 2025-12-19 10:14:51,155 - Added Services with IDs `['service_Brandon_Thetford']` and Routes: [['route_Brandon_Thetford', 'route_Thetford_Brandon']]
# <class 'str'>
# Adding service_Brandon_Thetford. Time offset: 00:23:32
# 2025-12-19 10:15:04,972 - Rerouting Service `service_Brandon_Thetford`
# 2025-12-19 10:15:05,004 - Checking `linkRefId`s of the Route: `route_Brandon_Thetford` are present in the graph
# Routing service_Brandon_Thetford.
# 2025-12-19 10:15:05,204 - Rerouting Route `route_Brandon_Thetford`
# 2025-12-19 10:15:15,018 - Changed Route attributes for 1 routes
# 2025-12-19 10:15:15,324 - Checking `linkRefId`s of the Route: `route_Thetford_Brandon` are present in the graph
# 2025-12-19 10:15:15,508 - Rerouting Route `route_Thetford_Brandon`
# 2025-12-19 10:15:25,414 - Changed Route attributes for 1 routes
# 2025-12-19 10:15:39,817 - Added Services with IDs `['service_Great_Yarmouth_Caister-on-Sea']` and Routes: [['route_Great_Yarmouth_Caister-on-Sea', 'route_Caister-on-Sea_Great_Yarmouth']]
# <class 'str'>
# Adding service_Great_Yarmouth_Caister-on-Sea. Time offset: 00:12:07
# 2025-12-19 10:15:48,671 - Rerouting Service `service_Great_Yarmouth_Caister-on-Sea`
# 2025-12-19 10:15:48,700 - Checking `linkRefId`s of the Route: `route_Great_Yarmouth_Caister-on-Sea` are present in the graph
# Routing service_Great_Yarmouth_Caister-on-Sea.
# 2025-12-19 10:15:48,892 - Rerouting Route `route_Great_Yarmouth_Caister-on-Sea`
# 2025-12-19 10:15:58,677 - Changed Route attributes for 1 routes
# 2025-12-19 10:15:58,958 - Checking `linkRefId`s of the Route: `route_Caister-on-Sea_Great_Yarmouth` are present in the graph
# 2025-12-19 10:15:59,143 - Rerouting Route `route_Caister-on-Sea_Great_Yarmouth`
# 2025-12-19 10:16:14,002 - Changed Route attributes for 1 routes
# 2025-12-19 10:16:23,744 - Added Services with IDs `['service_Great_Yarmouth_Lowestoft']` and Routes: [['route_Great_Yarmouth_Lowestoft', 'route_Lowestoft_Great_Yarmouth']]
# <class 'str'>
# Adding service_Great_Yarmouth_Lowestoft. Time offset: 00:39:37
# 2025-12-19 10:16:38,028 - Rerouting Service `service_Great_Yarmouth_Lowestoft`
# 2025-12-19 10:16:38,059 - Checking `linkRefId`s of the Route: `route_Great_Yarmouth_Lowestoft` are present in the graph
# Routing service_Great_Yarmouth_Lowestoft.
# 2025-12-19 10:16:38,247 - Rerouting Route `route_Great_Yarmouth_Lowestoft`
# 2025-12-19 10:16:48,235 - Changed Route attributes for 1 routes
# 2025-12-19 10:16:48,515 - Checking `linkRefId`s of the Route: `route_Lowestoft_Great_Yarmouth` are present in the graph
# 2025-12-19 10:16:48,718 - Rerouting Route `route_Lowestoft_Great_Yarmouth`
# 2025-12-19 10:16:58,801 - Changed Route attributes for 1 routes
# 2025-12-19 10:17:13,626 - Added Services with IDs `['service_Norwich_Beccles']` and Routes: [['route_Norwich_Beccles', 'route_Beccles_Norwich']]
# <class 'str'>
# Adding service_Norwich_Beccles. Time offset: 01:09:26
# 2025-12-19 10:17:23,792 - Rerouting Service `service_Norwich_Beccles`
# 2025-12-19 10:17:23,821 - Checking `linkRefId`s of the Route: `route_Norwich_Beccles` are present in the graph
# Routing service_Norwich_Beccles.
# 2025-12-19 10:17:24,012 - Rerouting Route `route_Norwich_Beccles`
# 2025-12-19 10:17:39,343 - Changed Route attributes for 1 routes
# 2025-12-19 10:17:39,614 - Checking `linkRefId`s of the Route: `route_Beccles_Norwich` are present in the graph
# 2025-12-19 10:17:39,794 - Rerouting Route `route_Beccles_Norwich`
# 2025-12-19 10:17:50,251 - Changed Route attributes for 1 routes
# 2025-12-19 10:18:00,511 - Added Services with IDs `['service_Norwich_Bungay']` and Routes: [['route_Norwich_Bungay', 'route_Bungay_Norwich']]
# <class 'str'>
# Adding service_Norwich_Bungay. Time offset: 00:56:16
# 2025-12-19 10:18:14,659 - Rerouting Service `service_Norwich_Bungay`
# 2025-12-19 10:18:14,682 - Checking `linkRefId`s of the Route: `route_Norwich_Bungay` are present in the graph
# 2025-12-19 10:18:14,838 - Rerouting Route `route_Norwich_Bungay`
# Routing service_Norwich_Bungay.
# 2025-12-19 10:18:24,836 - Changed Route attributes for 1 routes
# 2025-12-19 10:18:25,157 - Checking `linkRefId`s of the Route: `route_Bungay_Norwich` are present in the graph
# 2025-12-19 10:18:25,363 - Rerouting Route `route_Bungay_Norwich`
# 2025-12-19 10:18:35,454 - Changed Route attributes for 1 routes
# 2025-12-19 10:18:49,564 - Added Services with IDs `['service_Watton_Thetford']` and Routes: [['route_Watton_Thetford', 'route_Thetford_Watton']]
# <class 'str'>
# Adding service_Watton_Thetford. Time offset: 00:48:12
# 2025-12-19 10:19:04,631 - Rerouting Service `service_Watton_Thetford`
# 2025-12-19 10:19:04,658 - Checking `linkRefId`s of the Route: `route_Watton_Thetford` are present in the graph
# Routing service_Watton_Thetford.
# 2025-12-19 10:19:04,856 - Rerouting Route `route_Watton_Thetford`
# 2025-12-19 10:19:14,525 - Changed Route attributes for 1 routes
# 2025-12-19 10:19:14,788 - Checking `linkRefId`s of the Route: `route_Thetford_Watton` are present in the graph
# 2025-12-19 10:19:14,956 - Rerouting Route `route_Thetford_Watton`
# 2025-12-19 10:19:24,822 - Changed Route attributes for 1 routes
# 2025-12-19 10:19:39,329 - Added Services with IDs `['service_Attleborough_Norwich']` and Routes: [['route_Attleborough_Norwich', 'route_Norwich_Attleborough']]
# <class 'str'>
# Adding service_Attleborough_Norwich. Time offset: 00:58:42
# 2025-12-19 10:19:48,675 - Rerouting Service `service_Attleborough_Norwich`
# 2025-12-19 10:19:48,700 - Checking `linkRefId`s of the Route: `route_Attleborough_Norwich` are present in the graph
# Routing service_Attleborough_Norwich.
# 2025-12-19 10:19:48,908 - Rerouting Route `route_Attleborough_Norwich`
# 2025-12-19 10:19:58,805 - Changed Route attributes for 1 routes
# 2025-12-19 10:19:59,064 - Checking `linkRefId`s of the Route: `route_Norwich_Attleborough` are present in the graph
# 2025-12-19 10:19:59,237 - Rerouting Route `route_Norwich_Attleborough`
# 2025-12-19 10:20:08,692 - Changed Route attributes for 1 routes
# 2025-12-19 10:20:23,362 - Added Services with IDs `['service_Reepham_Norwich']` and Routes: [['route_Reepham_Norwich', 'route_Norwich_Reepham']]
# <class 'str'>
# Adding service_Reepham_Norwich. Time offset: 00:52:17
# 2025-12-19 10:20:37,647 - Rerouting Service `service_Reepham_Norwich`
# 2025-12-19 10:20:37,671 - Checking `linkRefId`s of the Route: `route_Reepham_Norwich` are present in the graph
# Routing service_Reepham_Norwich.
# 2025-12-19 10:20:37,856 - Rerouting Route `route_Reepham_Norwich`
# 2025-12-19 10:20:47,773 - Changed Route attributes for 1 routes
# 2025-12-19 10:20:48,050 - Checking `linkRefId`s of the Route: `route_Norwich_Reepham` are present in the graph
# 2025-12-19 10:20:48,239 - Rerouting Route `route_Norwich_Reepham`
# 2025-12-19 10:20:57,942 - Changed Route attributes for 1 routes
# 2025-12-19 10:21:12,511 - Added Services with IDs `['service_Cromer_Aylsham']` and Routes: [['route_Cromer_Aylsham', 'route_Aylsham_Cromer']]
# <class 'str'>
# Adding service_Cromer_Aylsham. Time offset: 00:41:50
# 2025-12-19 10:21:22,112 - Rerouting Service `service_Cromer_Aylsham`
# 2025-12-19 10:21:22,135 - Checking `linkRefId`s of the Route: `route_Cromer_Aylsham` are present in the graph
# Routing service_Cromer_Aylsham.
# 2025-12-19 10:21:22,318 - Rerouting Route `route_Cromer_Aylsham`
# 2025-12-19 10:21:32,385 - Changed Route attributes for 1 routes
# 2025-12-19 10:21:32,668 - Checking `linkRefId`s of the Route: `route_Aylsham_Cromer` are present in the graph
# 2025-12-19 10:21:32,832 - Rerouting Route `route_Aylsham_Cromer`
# 2025-12-19 10:21:47,466 - Changed Route attributes for 1 routes
# 2025-12-19 10:21:57,833 - Added Services with IDs `['service_Tiptree_Colchester']` and Routes: [['route_Tiptree_Colchester', 'route_Colchester_Tiptree']]
# <class 'str'>
# Adding service_Tiptree_Colchester. Time offset: 00:35:31
# 2025-12-19 10:22:12,341 - Rerouting Service `service_Tiptree_Colchester`
# 2025-12-19 10:22:12,372 - Checking `linkRefId`s of the Route: `route_Tiptree_Colchester` are present in the graph
# Routing service_Tiptree_Colchester.
# 2025-12-19 10:22:12,562 - Rerouting Route `route_Tiptree_Colchester`
# 2025-12-19 10:22:22,057 - Changed Route attributes for 1 routes
# 2025-12-19 10:22:22,346 - Checking `linkRefId`s of the Route: `route_Colchester_Tiptree` are present in the graph
# 2025-12-19 10:22:22,523 - Rerouting Route `route_Colchester_Tiptree`
# 2025-12-19 10:22:32,466 - Changed Route attributes for 1 routes
# 2025-12-19 10:22:47,217 - Added Services with IDs `['service_Halstead_Braintree']` and Routes: [['route_Halstead_Braintree', 'route_Braintree_Halstead']]
# <class 'str'>
# Adding service_Halstead_Braintree. Time offset: 00:24:32
# 2025-12-19 10:22:57,118 - Rerouting Service `service_Halstead_Braintree`
# 2025-12-19 10:22:57,145 - Checking `linkRefId`s of the Route: `route_Halstead_Braintree` are present in the graph
# 2025-12-19 10:22:57,294 - Rerouting Route `route_Halstead_Braintree`
# Routing service_Halstead_Braintree.
# 2025-12-19 10:23:11,811 - Changed Route attributes for 1 routes
# 2025-12-19 10:23:12,080 - Checking `linkRefId`s of the Route: `route_Braintree_Halstead` are present in the graph
# 2025-12-19 10:23:12,259 - Rerouting Route `route_Braintree_Halstead`
# 2025-12-19 10:23:22,138 - Changed Route attributes for 1 routes
# 2025-12-19 10:23:32,466 - Added Services with IDs `['service_Great_Dunmow_Braintree']` and Routes: [['route_Great_Dunmow_Braintree', 'route_Braintree_Great_Dunmow']]
# <class 'str'>
# Adding service_Great_Dunmow_Braintree. Time offset: 00:35:41
# 2025-12-19 10:23:46,832 - Rerouting Service `service_Great_Dunmow_Braintree`
# 2025-12-19 10:23:46,854 - Checking `linkRefId`s of the Route: `route_Great_Dunmow_Braintree` are present in the graph
# Routing service_Great_Dunmow_Braintree.
# 2025-12-19 10:23:47,054 - Rerouting Route `route_Great_Dunmow_Braintree`
# 2025-12-19 10:23:56,936 - Changed Route attributes for 1 routes
# 2025-12-19 10:23:57,199 - Checking `linkRefId`s of the Route: `route_Braintree_Great_Dunmow` are present in the graph
# 2025-12-19 10:23:57,371 - Rerouting Route `route_Braintree_Great_Dunmow`
# 2025-12-19 10:24:07,473 - Changed Route attributes for 1 routes
# 2025-12-19 10:24:22,530 - Added Services with IDs `['service_Great_Dunmow_Bishops_Stortford']` and Routes: [['route_Great_Dunmow_Bishops_Stortford', 'route_Bishops_Stortford_Great_Dunmow']]
# <class 'str'>
# Adding service_Great_Dunmow_Bishops_Stortford. Time offset: 00:35:46
# 2025-12-19 10:24:37,347 - Rerouting Service `service_Great_Dunmow_Bishops_Stortford`
# 2025-12-19 10:24:37,375 - Checking `linkRefId`s of the Route: `route_Great_Dunmow_Bishops_Stortford` are present in the graph
# Routing service_Great_Dunmow_Bishops_Stortford.
# 2025-12-19 10:24:37,582 - Rerouting Route `route_Great_Dunmow_Bishops_Stortford`
# 2025-12-19 10:24:47,408 - Changed Route attributes for 1 routes
# 2025-12-19 10:24:47,688 - Checking `linkRefId`s of the Route: `route_Bishops_Stortford_Great_Dunmow` are present in the graph
# 2025-12-19 10:24:47,865 - Rerouting Route `route_Bishops_Stortford_Great_Dunmow`
# 2025-12-19 10:24:57,928 - Changed Route attributes for 1 routes
# 2025-12-19 10:25:13,523 - Added Services with IDs `['service_Brightlingsea_Colchester']` and Routes: [['route_Brightlingsea_Colchester', 'route_Colchester_Brightlingsea']]
# <class 'str'>
# Adding service_Brightlingsea_Colchester. Time offset: 00:31:44
# 2025-12-19 10:25:23,738 - Rerouting Service `service_Brightlingsea_Colchester`
# 2025-12-19 10:25:23,762 - Checking `linkRefId`s of the Route: `route_Brightlingsea_Colchester` are present in the graph
# Routing service_Brightlingsea_Colchester.
# 2025-12-19 10:25:23,987 - Rerouting Route `route_Brightlingsea_Colchester`
# 2025-12-19 10:25:34,167 - Changed Route attributes for 1 routes
# 2025-12-19 10:25:34,456 - Checking `linkRefId`s of the Route: `route_Colchester_Brightlingsea` are present in the graph
# 2025-12-19 10:25:34,646 - Rerouting Route `route_Colchester_Brightlingsea`
# 2025-12-19 10:25:49,248 - Changed Route attributes for 1 routes
# 2025-12-19 10:26:00,246 - Added Services with IDs `['service_West_Mersea_Colchester']` and Routes: [['route_West_Mersea_Colchester', 'route_Colchester_West_Mersea']]
# <class 'str'>
# Adding service_West_Mersea_Colchester. Time offset: 00:32:13
# 2025-12-19 10:26:15,277 - Rerouting Service `service_West_Mersea_Colchester`
# 2025-12-19 10:26:15,301 - Checking `linkRefId`s of the Route: `route_West_Mersea_Colchester` are present in the graph
# Routing service_West_Mersea_Colchester.
# 2025-12-19 10:26:15,513 - Rerouting Route `route_West_Mersea_Colchester`
# 2025-12-19 10:26:25,320 - Changed Route attributes for 1 routes
# 2025-12-19 10:26:25,610 - Checking `linkRefId`s of the Route: `route_Colchester_West_Mersea` are present in the graph
# 2025-12-19 10:26:25,803 - Rerouting Route `route_Colchester_West_Mersea`
# 2025-12-19 10:26:36,215 - Changed Route attributes for 1 routes
# 2025-12-19 10:26:51,639 - Added Services with IDs `['service_Maldon_Chelmsford']` and Routes: [['route_Maldon_Chelmsford', 'route_Chelmsford_Maldon']]
# <class 'str'>
# Adding service_Maldon_Chelmsford. Time offset: 00:38:28
# 2025-12-19 10:27:06,997 - Rerouting Service `service_Maldon_Chelmsford`
# 2025-12-19 10:27:07,021 - Checking `linkRefId`s of the Route: `route_Maldon_Chelmsford` are present in the graph
# Routing service_Maldon_Chelmsford.
# 2025-12-19 10:27:07,216 - Rerouting Route `route_Maldon_Chelmsford`
# 2025-12-19 10:27:17,172 - Changed Route attributes for 1 routes
# 2025-12-19 10:27:17,426 - Checking `linkRefId`s of the Route: `route_Chelmsford_Maldon` are present in the graph
# 2025-12-19 10:27:17,591 - Rerouting Route `route_Chelmsford_Maldon`
# 2025-12-19 10:27:27,075 - Changed Route attributes for 1 routes
# <class 'str'>
# Adding service_Maldon_South_Woodham_Ferrers. Time offset: 00:28:01
# 2025-12-19 10:27:42,644 - Added Services with IDs `['service_Maldon_South_Woodham_Ferrers']` and Routes: [['route_Maldon_South_Woodham_Ferrers', 'route_South_Woodham_Ferrers_Maldon']]
# 2025-12-19 10:27:53,084 - Rerouting Service `service_Maldon_South_Woodham_Ferrers`
# 2025-12-19 10:27:53,109 - Checking `linkRefId`s of the Route: `route_Maldon_South_Woodham_Ferrers` are present in the graph
# 2025-12-19 10:27:53,284 - Rerouting Route `route_Maldon_South_Woodham_Ferrers`
# Routing service_Maldon_South_Woodham_Ferrers.
# 2025-12-19 10:28:03,286 - Changed Route attributes for 1 routes
# 2025-12-19 10:28:03,546 - Checking `linkRefId`s of the Route: `route_South_Woodham_Ferrers_Maldon` are present in the graph
# 2025-12-19 10:28:03,729 - Rerouting Route `route_South_Woodham_Ferrers_Maldon`
# 2025-12-19 10:28:18,759 - Changed Route attributes for 1 routes
# 2025-12-19 10:28:29,553 - Added Services with IDs `['service_Saffron_Walden_Bishops_Stortford']` and Routes: [['route_Saffron_Walden_Bishops_Stortford', 'route_Bishops_Stortford_Saffron_Walden']]
# <class 'str'>
# Adding service_Saffron_Walden_Bishops_Stortford. Time offset: 00:47:41
# 2025-12-19 10:28:44,370 - Rerouting Service `service_Saffron_Walden_Bishops_Stortford`
# 2025-12-19 10:28:44,396 - Checking `linkRefId`s of the Route: `route_Saffron_Walden_Bishops_Stortford` are present in the graph
# 2025-12-19 10:28:44,588 - Rerouting Route `route_Saffron_Walden_Bishops_Stortford`
# Routing service_Saffron_Walden_Bishops_Stortford.
# 2025-12-19 10:28:54,546 - Changed Route attributes for 1 routes
# 2025-12-19 10:28:54,837 - Checking `linkRefId`s of the Route: `route_Bishops_Stortford_Saffron_Walden` are present in the graph
# 2025-12-19 10:28:55,025 - Rerouting Route `route_Bishops_Stortford_Saffron_Walden`
# 2025-12-19 10:29:04,949 - Changed Route attributes for 1 routes
# 2025-12-19 10:29:20,861 - Added Services with IDs `['service_Braintree_Sudbury']` and Routes: [['route_Braintree_Sudbury', 'route_Sudbury_Braintree']]
# <class 'str'>
# Adding service_Braintree_Sudbury. Time offset: 00:57:41
# 2025-12-19 10:29:31,378 - Rerouting Service `service_Braintree_Sudbury`
# 2025-12-19 10:29:31,402 - Checking `linkRefId`s of the Route: `route_Braintree_Sudbury` are present in the graph
# Routing service_Braintree_Sudbury.
# 2025-12-19 10:29:31,619 - Rerouting Route `route_Braintree_Sudbury`
# 2025-12-19 10:29:46,618 - Changed Route attributes for 1 routes
# 2025-12-19 10:29:46,917 - Checking `linkRefId`s of the Route: `route_Sudbury_Braintree` are present in the graph
# 2025-12-19 10:29:47,096 - Rerouting Route `route_Sudbury_Braintree`
# 2025-12-19 10:29:57,104 - Changed Route attributes for 1 routes
# 2025-12-19 10:30:07,927 - Added Services with IDs `['service_Epping_Harlow']` and Routes: [['route_Epping_Harlow', 'route_Harlow_Epping']]
# <class 'str'>
# Adding service_Epping_Harlow. Time offset: 00:21:26
# 2025-12-19 10:30:23,279 - Rerouting Service `service_Epping_Harlow`
# 2025-12-19 10:30:23,305 - Checking `linkRefId`s of the Route: `route_Epping_Harlow` are present in the graph
# Routing service_Epping_Harlow.
# 2025-12-19 10:30:23,519 - Rerouting Route `route_Epping_Harlow`
# 2025-12-19 10:30:33,599 - Changed Route attributes for 1 routes
# 2025-12-19 10:30:33,865 - Checking `linkRefId`s of the Route: `route_Harlow_Epping` are present in the graph
# 2025-12-19 10:30:34,042 - Rerouting Route `route_Harlow_Epping`
# 2025-12-19 10:30:44,350 - Changed Route attributes for 1 routes
# <class 'str'>
# Adding service_Harlow_Chelmsford. Time offset: 01:08:44
# 2025-12-19 10:30:59,282 - Added Services with IDs `['service_Harlow_Chelmsford']` and Routes: [['route_Harlow_Chelmsford', 'route_Chelmsford_Harlow']]
# 2025-12-19 10:31:14,621 - Rerouting Service `service_Harlow_Chelmsford`
# 2025-12-19 10:31:14,645 - Checking `linkRefId`s of the Route: `route_Harlow_Chelmsford` are present in the graph
# Routing service_Harlow_Chelmsford.
# 2025-12-19 10:31:14,850 - Rerouting Route `route_Harlow_Chelmsford`
# 2025-12-19 10:31:24,845 - Changed Route attributes for 1 routes
# 2025-12-19 10:31:25,102 - Checking `linkRefId`s of the Route: `route_Chelmsford_Harlow` are present in the graph
# 2025-12-19 10:31:25,289 - Rerouting Route `route_Chelmsford_Harlow`
# 2025-12-19 10:31:35,308 - Changed Route attributes for 1 routes

# %%
# from genet reference docs        

n.schedule.validate_vehicle_definitions()
# Out:
# True

# %%
len(n.schedule.vehicles)

# a higher number! it works!!!
# Out:
# 82450

# %%
vehs = n.schedule.vehicles

# %%
n.schedule.change_log().tail()

# ok, it's in the frame, just have to hope it runs properly in the model...
# Out:
#                timestamp change_event object_type                   old_id  \
# 184  2025-12-19 10:30:33       modify       route      route_Epping_Harlow
# 185  2025-12-19 10:30:44       modify       route      route_Harlow_Epping
# 186  2025-12-19 10:30:59          add     service                     None
# 187  2025-12-19 10:31:24       modify       route  route_Harlow_Chelmsford
# 188  2025-12-19 10:31:35       modify       route  route_Chelmsford_Harlow
#
#                         new_id  \
# 184        route_Epping_Harlow
# 185        route_Harlow_Epping
# 186  service_Harlow_Chelmsford
# 187    route_Harlow_Chelmsford
# 188    route_Chelmsford_Harlow
#
#                                         old_attributes  \
# 184  {'route_short_name': 'route_Epping_Harlow', 'm...
# 185  {'route_short_name': 'route_Harlow_Epping', 'm...
# 186                                               None
# 187  {'route_short_name': 'route_Harlow_Chelmsford'...
# 188  {'route_short_name': 'route_Chelmsford_Harlow'...
#
#                                         new_attributes  \
# 184  {'route_short_name': 'route_Epping_Harlow', 'm...
# 185  {'route_short_name': 'route_Harlow_Epping', 'm...
# 186  {'id': 'service_Harlow_Chelmsford', 'name': 'r...
# 187  {'route_short_name': 'route_Harlow_Chelmsford'...
# 188  {'route_short_name': 'route_Chelmsford_Harlow'...
#
#                                                   diff
# 184  [(add, network_links, [(0, '517705570447398359...
# 185  [(add, network_links, [(0, '517705929319297773...
# 186  [(add, , [('id', 'service_Harlow_Chelmsford'),...
# 187  [(add, network_links, [(0, '517705929319297773...
# 188  [(add, network_links, [(0, '517714709493297426...

# %%
# below doesn't work, I don't know why.

# n.schedule.vehicle_types = {k:v for k,v in n.schedule.vehicle_types.items() if k in {'Bus', 'Rail'}}
# n.schedule.vehicle_types['ScenarioBus'] = n.schedule.vehicle_types['Bus']

# %%
# not sure why this is here, it always yields an empty list
# ok, great, fixed it

n.schedule.vehicle_types
# Out:
# {'bus': {'capacity': {'seats': '7',
#    'standingRoom': '0',
#    'length': {'meter': '18.0'},
#    'width': {'meter': '2.5'},
#    'costInformation': {},
#    'passengerCarEquivalents': {'pce': '0.28'},
#    'networkMode': {'networkMode': 'car'},
#    'flowEfficiencyFactor': {'factor': '1.0'}},
#   'attribute': {'name': 'egressTimeInSecondsPerPerson',
#    'class': 'java.lang.Double'},
#   'attributes': {}},
#  'ferry': {'capacity': {'seats': '25',
#    'standingRoom': '0',
#    'length': {'meter': '50.0'},
#    'width': {'meter': '6.0'},
#    'costInformation': {},
#    'passengerCarEquivalents': {'pce': '0.71'},
#    'networkMode': {'networkMode': 'car'},
#    'flowEfficiencyFactor': {'factor': '1.0'}},
#   'attribute': {'name': 'egressTimeInSecondsPerPerson',
#    'class': 'java.lang.Double'},
#   'attributes': {}},
#  'rail': {'capacity': {'seats': '100',
#    'standingRoom': '0',
#    'length': {'meter': '200.0'},
#    'width': {'meter': '2.8'},
#    'costInformation': {},
#    'passengerCarEquivalents': {'pce': '2.71'},
#    'networkMode': {'networkMode': 'car'},
#    'flowEfficiencyFactor': {'factor': '1.0'}},
#   'attribute': {'name': 'egressTimeInSecondsPerPerson',
#    'class': 'java.lang.Double'},
#   'attributes': {}},
#  'subway': {'capacity': {'seats': '100',
#    'standingRoom': '0',
#    'length': {'meter': '30.0'},
#    'width': {'meter': '2.45'},
#    'costInformation': {},
#    'passengerCarEquivalents': {'pce': '0.44'},
#    'networkMode': {'networkMode': 'car'},
#    'flowEfficiencyFactor': {'factor': '1.0'}},
#   'attribute': {'name': 'egressTimeInSecondsPerPerson',
#    'class': 'java.lang.Double'},
#   'attributes': {}},
#  'tram': {'capacity': {'seats': '18',
#    'standingRoom': '0',
#    'length': {'meter': '36.0'},
#    'width': {'meter': '2.4'},
#    'costInformation': {},
#    'passengerCarEquivalents': {'pce': '0.52'},
#    'networkMode': {'networkMode': 'car'},
#    'flowEfficiencyFactor': {'factor': '1.0'}},
#   'attribute': {'name': 'egressTimeInSecondsPerPerson',
#    'class': 'java.lang.Double'},
#   'attributes': {}}}

# %%
n.schedule.validate_vehicle_definitions()
# Out:
# True

# %%
# ok, this is the important one:

# n.generate_validation_report()

rep = n.generate_validation_report()
# Out:
# 2025-12-19 10:31:50,638 - Checking validity of the Network
# 2025-12-19 10:31:50,640 - Checking validity of the Network graph
# 2025-12-19 10:31:50,641 - Defaulting to checking graph connectivity for modes: ['car', 'walk', 'bike']. You can change this by passing a `modes_for_strong_connectivity` param
# 2025-12-19 10:31:50,642 - Checking network connectivity for mode: car
# 2025-12-19 10:32:32,271 - The graph for mode: car has: 1 connected components, 0 sinks/dead_ends and 0 sources/unreachable nodes.
# 2025-12-19 10:32:32,272 - Checking network connectivity for mode: walk
# 2025-12-19 10:33:11,866 - The graph for mode: walk has: 13 connected components, 3 sinks/dead_ends and 4 sources/unreachable nodes.
# 2025-12-19 10:33:11,868 - The graph has more than one connected component for mode walk! If this is not expected, consider using the `connect_components` method to connect the components, or `retain_n_connected_subgraphs` with `n=1` to extract the largest component
# 2025-12-19 10:33:11,869 - Checking network connectivity for mode: bike
# 2025-12-19 10:33:53,430 - The graph for mode: bike has: 13 connected components, 3 sinks/dead_ends and 4 sources/unreachable nodes.
# 2025-12-19 10:33:53,431 - The graph has more than one connected component for mode bike! If this is not expected, consider using the `connect_components` method to connect the components, or `retain_n_connected_subgraphs` with `n=1` to extract the largest component
# 2025-12-19 10:34:16,622 - Checking link values for `freespeed`
# 2025-12-19 10:34:41,128 - 1 of links have fractional values for `freespeed`
# 2025-12-19 10:34:47,493 - Checking link values for `capacity`
# 2025-12-19 10:35:17,796 - Checking link values for `permlanes`
# 2025-12-19 10:35:46,124 - Checking link values for `oneway`
# 2025-12-19 10:36:15,380 - Checking link values for `modes`
# 2025-12-19 10:37:07,742 - Checking link values for `{'attributes': 'osm:way:highway'}`
# 2025-12-19 10:37:43,511 - Checking link values for `{'attributes': 'osm:way:osmid'}`
# 2025-12-19 10:38:18,096 - Checking link values for `{'attributes': 'osm:way:lanes'}`
# 2025-12-19 10:38:46,599 - Checking link values for `{'attributes': 'osm:way:original_lanes'}`
# 2025-12-19 10:39:13,845 - Checking link values for `{'attributes': 'urban'}`
# 2025-12-19 10:39:45,203 - Checking link values for `{'attributes': 'osm:way:sidewalk'}`
# 2025-12-19 10:40:12,118 - Checking link values for `{'attributes': 'osm:way:cycleway'}`
# 2025-12-19 10:40:39,156 - Checking link values for `{'attributes': 'osm:way:railway'}`
# 2025-12-19 10:41:06,681 - Checking link values for `{'attributes': 'osm:way:toll'}`
# 2025-12-19 10:41:34,334 - Checking link values for `length`
# 2025-12-19 10:41:58,353 - 306 of links have fractional values for `length`
# 2025-12-19 10:42:04,162 - Checking validity of the Schedule
# 2025-12-19 10:42:04,163 - Computing headway stats
# 2025-12-19 10:46:58,730 - Checking validity of PT vehicles
# 2025-12-19 10:46:59,212 - All vehicles are being used.
# 2025-12-19 10:46:59,668 - No vehicles being used for multiple trips have been found.
# 2025-12-19 10:46:59,675 - Found 66 PT Routes 0 minimum headway between trips. The following Services are affected: {'number_of_affected': 44, 'ids': ['10969', '11556', '12044', '12951', '13232', '15874', '16104', '16167', '17542', '18261', '18867', '20592', '20640', '20752', '22009', '33968', '37131', '46146', '48189', '4931', '50897', '52773', '53738', '56525', '59212', '59356', '60815', '60821', '61742', '62690', '65918', '66098', '66195', '66515', '68555', '68925', '69401', '70376', '72879', '7952', '8629', '9077', '9619', '9840']}
# 2025-12-19 10:46:59,676 - Computing speeds
# 2025-12-19 10:47:13,235 - Checking speeds for prohibitive values 0 and infinity. You should verify speed values separately
# /home/siskiyoucedar/micromamba/envs/genet/lib/python3.12/site-packages/genet/core.py:2790: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'False' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[~df["link_in_network"], "mode_allowed_on_link"] = False
# /home/siskiyoucedar/micromamba/envs/genet/lib/python3.12/site-packages/genet/core.py:2790: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'False' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc
#      '104920',
#      '104925',
#      '104928',
#      '104934',
#      '104968',
#      '104984',
#      '105100',
#      '105109',
#      '105158',
#      '105184',
#      '105206',
#      '105248',
#      '105260',
#      '105263',
#      '1053',
#      '105340',
#      '105345',
#      '10538',
#      '105394',
#      '105416',
#      '105456',
#      '105489',
#      '105521',
#      '105535',
#      '105549',
#      '105558',
#      '105614',
#      '105689',
#      '105743',
#      '105771',
#      '10580',
#      '105835',
#      '105842',
#      '105896',
#      '105931',
#      '10596',
#      '10601',
#      '10602',
#      '106037',
#      '106057',
#      '106069',
#      '106076',
#      '106133',
#      '106152',
#      '106159',
#      '106200',
#      '106231',
#      '106267',
#      '106271',
#      '106274',
#      '106299',
#      '106310',
#      '10634',
#      '106344',
#      '106413',
#      '106437',
#      '10646',
#      '106463',
#      '106546',
#      '106563',
#      '106586',
#      '106607',
#      '106681',
#      '106727',
#      '106800',
#      '106821',
#      '106841',
#      '106859',
#      '106861',
#      '106885',
#      '106930',
#      '106968',
#      '106980',
#      '107003',
#      '107067',
#      '107107',
#      '107153',
#      '107173',
#      '107199',
#      '107237',
#      '107276',
#      '107283',
#      '107320',
#      '107330',
#      '107346',
#      '107352',
#      '10751',
#      '107527',
#      '107562',
#      '107597',
#      '107635',
#      '107832',
#      '107897',
#      '107936',
#      '107958',
#      '107992',
#      '108005',
#      '108057',
#      '108058',
#      '108079',
#      '108080',
#      '108131',
#      '108207',
#      '108248',
#      '108318',
#      '10836',
#      '108377',
#      '108473',
#      '108487',
#      '108510',
#      '108512',
#      '108702',
#      '108711',
#      '108754',
#      '108772',
#      '108801',
#      '108824',
#      '108831',
#      '108861',
#      '108883',
#      '108889',
#      '108954',
#      '10898',
#      '108991',
#      '108994',
#      '108998',
#      '109048',
#      '109060',
#      '109150',
#      '109183',
#      '109203',
#      '109263',
#      '109309',
#      '109453',
#      '10947',
#      '109490',
#      '109519',
#      '109554',
#      '109603',
#      '109624',
#      '109643',
#      '109709',
#      '10976',
#      '109813',
#      '109823',
#      '109826',
#      '109857',
#      '110042',
#      '110085',
#      '110092',
#      '110104',
#      '110124',
#      '110126',
#      '110137',
#      '110193',
#      '110194',
#      '11022',
#      '110243',
#      '110256',
#      '110380',
#      '110382',
#      '110428',
#      '110432',
#      '110434',
#      '110439',
#      '110559',
#      '11063',
#      '11065',
#      '1108',
#      '110812',
#      '110822',
#      '110829',
#      '110891',
#      '110902',
#      '110990',
#      '111002',
#      '11110',
#      '111158',
#      '111270',
#      '111353',
#      '11136',
#      '111362',
#      '111368',
#      '111422',
#      '111428',
#      '111554',
#      '111575',
#      '111579',
#      '111611',
#      '111625',
#      '111651',
#      '111663',
#      '11167',
#      '111701',
#      '111702',
#      '11178',
#      '111781',
#      '111817',
#      '111828',
#      '11187',
#      '111881',
#      '111892',
#      '111899',
#      '111937',
#      '111977',
#      '111996',
#      '112002',
#      '112006',
#      '112108',
#      '112127',
#      '112232',
#      '112253',
#      '11230',
#      '112357',
#      '112370',
#      '11242',
#      '112465',
#      '112564',
#      '112654',
#      '112699',
#      '112753',
#      '112839',
#      '112888',
#      '112915',
#      '112929',
#      '112995',
#      '11300',
#      '113066',
#      '113100',
#      '113101',
#      '113152',
#      '11319',
#      '113222',
#      '113305',
#      '113310',
#      '113333',
#      '11340',
#      '113428',
#      '11347',
#      '113473',
#      '113507',
#      '11355',
#      '11358',
#      '113590',
#      '113609',
#      '11363',
#      '113681',
#      '113726',
#      '113727',
#      '113778',
#      '11378',
#      '11380',
#      '113870',
#      '113906',
#      '114041',
#      '114048',
#      '114090',
#      '114101',
#      '114205',
#      '11425',
#      '114382',
#      '11440',
#      '114427',
#      '114465',
#      '114480',
#      '114488',
#      '114494',
#      '11450',
#      '114531',
#      '114583',
#      '114613',
#      '114625',
#      '114664',
#      '114689',
#      '114692',
#      '114695',
#      '114796',
#      '114799',
#      '114942',
#      '114952',
#      '114953',
#      '115024',
#      '11513',
#      '115135',
#      '115175',
#      '115265',
#      '115280',
#      '115301',
#      '115317',
#      '115342',
#      '115365',
#      '115377',
#      '115421',
#      '115529',
#      '115547',
#      '115556',
#      '115572',
#      '115576',
#      '115614',
#      '115625',
#      '1157',
#      '115719',
#      '115746',
#      '11575',
#      '115759',
#      '11577',
#      '115789',
#      '115877',
#      '115890',
#      '115966',
#      '116001',
#      '116045',
#      '116066',
#      '116103',
#      '116107',
#      '116196',
#      '116226',
#      '11624',
#      '116240',
#      '116255',
#      '116261',
#      '116273',
#      '116336',
#      '11638',
#      '116389',
#      '116418',
#      '116428',
#      '116429',
#      '116454',
#      '116514',
#      '116523',
#      '116595',
#      '116610',
#      '11667',
#      '116706',
#      '116709',
#      '116725',
#      '116726',
#      '116734',
#      '116820',
#      '116839',
#      '116858',
#      '116909',
#      '116915',
#      '116931',
#      '116974',
#      '116977',
#      '117044',
#      '117054',
#      '117063',
#      '117143',
#      '117196',
#      '117233',
#      '117254',
#      '117325',
#      '117358',
#      '117383',
#      '117438',
#      '117546',
#      '117580',
#      '117581',
#      '117590',
#      '117649',
#      '117666',
#      '117684',
#      '117759',
#      '117764',
#      '117807',
#      '117809',
#      '117876',
#      '117899',
#      '11798',
#      '118001',
#      '118058',
#      '118061',
#      '118182',
#      '118261',
#      '118262',
#      '118338',
#      '118367',
#      '118414',
#      '118446',
#      '118450',
#      '118452',
#      '118456',
#      '118608',
#      '118653',
#      '118690',
#      '118711',
#      '118759',
#      '118777',
#      '11879',
#      '118791',
#      '118845',
#      '118850',
#      '118852',
#      '11887',
#      '118870',
#      '118885',
#      '118946',
#      '118951',
#      '118994',
#      '118996',
#      '1190',
#      '119013',
#      '119038',
#      '119045',
#      '119067',
#      '119094',
#      '119109',
#      '119134',
#      '119154',
#      '119165',
#      '119183',
#      '119208',
#      '119222',
#      '119245',
#      '119284',
#      '119290',
#      '119330',
#      '119368',
#      '119394',
#      '119397',
#      '119429',
#      '119467',
#      '11949',
#      '119505',
#      '119577',
#      '119693',
#      '119701',
#      '119806',
#      '119900',
#      '119903',
#      '119920',
#      '119961',
#      '119976',
#      '120008',
#      '120010',
#      '120031',
#      '12005',
#      '120073',
#      '120118',
#      '120133',
#      '120290',
#      '120302',
#      '120315',
#      '120392',
#      '120422',
#      '120445',
#      '120459',
#      '120469',
#      '120473',
#      '120484',
#      '120686',
#      '120707',
#      '120742',
#      '12076',
#      '120763',
#      '120776',
#      '120797',
#      '120799',
#      '120803',
#      '120821',
#      '12089',
#      '120920',
#      '120930',
#      '120934',
#      '121020',
#      '121103',
#      '12111',
#      '121133',
#      '121159',
#      '121251',
#      '121263',
#      '121316',
#      '121360',
#      '121374',
#      '121388',
#      '121436',
#      '121460',
#      '12148',
#      '121493',
#      '121519',
#      '121540',
#      '121566',
#      '121569',
#      '121626',
#      '121778',
#      '121868',
#      '121896',
#      '121959',
#      '12202',
#      '122110',
#      '122144',
#      '122172',
#      '122181',
#      '122229',
#      '122285',
#      '122324',
#      '122366',
#      '122411',
#      '122440',
#      '122483',
#      '122495',
#      '122559',
#      '122617',
#      '12262',
#      '122647',
#      '122654',
#      '122707',
#      '12271',
#      '122736',
#      '122746',
#      '122791',
#      '122803',
#      '122816',
#      '122844',
#      '122919',
#      '122945',
#      '122961',
#      '122966',
#      '122988',
#      '123013',
#      '123034',
#      '123049',
#      '123052',
#      '123096',
#      '123115',
#      '123133',
#      '123140',
#      '123226',
#      '123267',
#      '12327',
#      '123275',
#      '123322',
#      '123347',
#      '123390',
#      '123425',
#      '123432',
#      '123445',
#      '123478',
#      '123509',
#      '123552',
#      '123565',
#      '123569',
#      '123617',
#      '123647',
#      '123700',
#      '123746',
#      '123811',
#      '123821',
#      '123826',
#      '123839',
#      '123852',
#      '123856',
#      '123870',
#      '123896',
#      '123908',
#      '123910',
#      '124021',
#      '124032',
#      '12404',
#      '124045',
#      '124087',
#      '124184',
#      '124373',
#      '124374',
#      '124428',
#      '124473',
#      '124494',
#      '124507',
#      '124519',
#      '12461',
#      '124637',
#      '12464',
#      '124673',
#      '12468',
#      '124747',
#      '124762',
#      '124795',
#      '1248',
#      '124920',
#      '124921',
#      '124931',
#      '124993',
#      '125',
#      '125063',
#      '125142',
#      '125179',
#      '12532',
#      '125412',
#      '125422',
#      '125462',
#      '125480',
#      '125495',
#      '125528',
#      '12560',
#      '125641',
#      '125678',
#      '12580',
#      '125802',
#      '125839',
#      '125855',
#      '125865',
#      '125876',
#      '12589',
#      '125913',
#      '125921',
#      '125976',
#      '125984',
#      '125985',
#      '126095',
#      '126136',
#      '126174',
#      '126248',
#      '12625',
#      '126251',
#      '126319',
#      '126338',
#      '126340',
#      '126412',
#      '12647',
#      '126480',
#      '126519',
#      '126521',
#      '126539',
#      '126597',
#      '12660',
#      '126615',
#      '126638',
#      '12672',
#      '12677',
#      '126776',
#      '126873',
#      '126894',
#      '126941',
#      '126982',
#      '127038',
#      '127186',
#      '127200',
#      '127247',
#      '127286',
#      '127293',
#      '127298',
#      '127327',
#      '127405',
#      '127423',
#      '127468',
#      '127473',
#      '127500',
#      '127504',
#      '127557',
#      '127573',
#      '127648',
#      '127686',
#      '127698',
#      '127739',
#      '127792',
#      '127798',
#      '127832',
#      '127833',
#      '127845',
#      '127903',
#      '127996',
#      '12803',
#      '128057',
#      '128106',
#      '128131',
#      '12816',
#      '128220',
#      '12829',
#      '128320',
#      '128338',
#      '128364',
#      '128373',
#      '128554',
#      '128622',
#      '128666',
#      '12870',
#      '128704',
#      '128716',
#      '128746',
#      '128833',
#      '128872',
#      '12888',
#      '128913',
#      '128976',
#      '12898',
#      '128993',
#      '129033',
#      '129144',
#      '129240',
#      '12927',
#      '129277',
#      '129296',
#      '129306',
#      '129350',
#      '129356',
#      '129380',
#      '129536',
#      '129649',
#      '129694',
#      '129695',
#      '129702',
#      '129713',
#      '129730',
#      '129815',
#      '129867',
#      '129928',
#      '129943',
#      '129979',
#      '130039',
#      '130071',
#      '130079',
#      '130111',
#      '130135',
#      '130189',
#      '130217',
#      '130290',
#      '130340',
#      '130348',
#      '130359',
#      '130421',
#      '130503',
#      '130556',
#      '130591',
#      '130596',
#      '130622',
#      '130638',
#      '130641',
#      '130669',
#      '13069',
#      '130751',
#      '130822',
#      '130828',
#      '130894',
#      '130978',
#      '131012',
#      '131053',
#      '131079',
#      '131149',
#      '131194',
#      '131320',
#      '131383',
#      '131556',
#      '131585',
#      '131649',
#      '13172',
#      '131767',
#      '131784',
#      '131819',
#      '131889',
#      '131939',
#      '131991',
#      '132092',
#      '132187',
#      '132227',
#      '132271',
#      '132273',
#      '132277',
#      '132300',
#      '132373',
#      '132471',
#      '132474',
#      '132479',
#      '132540',
#      '132566',
#      '132583',
#      '132584',
#      '132637',
#      '132643',
#      '132671',
#      '132689',
#      '132703',
#      '13273',
#      '13276',
#      '132819',
#      '132908',
#      '132944',
#      '133008',
#      '133020',
#      '133031',
#      '133055',
#      '133060',
#      '133075',
#      '133083',
#      '133151',
#      '133172',
#      '133209',
#      '133286',
#      '133289',
#      '133317',
#      '133386',
#      '133461',
#      '133543',
#      '133558',
#      '133602',
#      '133608',
#      '133664',
#      '13367',
#      '133686',
#      '133751',
#      '133793',
#      '133821',
#      '133872',
#      '133874',
#      '13388',
#      '133899',
#      '13392',
#      '134035',
#      '134041',
#      '134078',
#      '13409',
#      '134106',
#      '134110',
#      '134364',
#      '134450',
#      '134502',
#      '134512',
#      '134516',
#      '134523',
#      '134531',
#      '134567',
#      '134569',
#      '134598',
#      '134605',
#      '134609',
#      '134626',
#      '13469',
#      '134699',
#      '134708',
#      '134717',
#      '134809',
#      '134833',
#      '134852',
#      '134905',
#      '134922',
#      '134927',
#      '13499',
#      '135038',
#      '135087',
#      '135091',
#      '135264',
#      '135281',
#      '135323',
#      '135439',
#      '135446',
#      '135544',
#      '135552',
#      '135557',
#      '135602',
#      '135613',
#      '135617',
#      '135643',
#      '135667',
#      '135700',
#      '135781',
#      '13589',
#      '135911',
#      '135936',
#      '135938',
#      '135950',
#      '136012',
#      '136017',
#      '136086',
#      '136129',
#      ...]}}},
#  'schedule': {'schedule_level': {'is_valid_schedule': True,
#    'invalid_stages': [],
#    'has_valid_services': True,
#    '62910': {'62910_0': 1.1536786759597668, '62910_1': 1.141745125475886},
#    '62911': {'62911_0': 1.1400313508044304, '62911_1': 1.1063086997434075},
#    '62912': {'62912_0': 1.1480490269121741, '62912_1': 1.1399870532437797},
#    '62915': {'62915_0': 1.103298957344203,
#     '62915_1': 1.0948223115315803,
#     '62915_2': 1.1025977041659607,
#     '62915_3': 1.0826421226403413,
#     '62915_4': 1.1105007423931539},
#    '62918': {'62918_0': 1.0143622516375452, '62918_1': 1.0093611700335972},
#    '62929': {'62929_0': 1.000017102208803, '62929_1': 1.000017102208803},
#    '62930': {'62930_0': 1.000017102208803, '62930_1': 1.000017102208803},
#    '62932': {'62932_0': 1.000017102208803, '62932_1': 1.000017102208803},
#    '62937': {'62937_0': 1.000017102208803, '62937_1': 1.000017102208803},
#    '62938': {'62938_0': 1.000017102208803},
#    '62939': {'62939_0': 1.000017102208803, '62939_1': 1.000017102208803},
#    '62940': {'62940_0': 1.000017102208803, '62940_1': 1.000017102208803},
#    '62945': {'62945_0': 1.000017102208803},
#    '62953': {'62953_0': 1.000017102208803},
#    '62955': {'62955_0': 1.000017102208803, '62955_1': 1.000017102208803},
#    '63028': {'63028_0': 1.2013996885357388,
#     '63028_1': 1.1803861485002902,
#     '63028_2': 1.194775439748169},
#    '63030': {'63030_0': 1.0127033951711844, '63030_1': 1.0348875241055369},
#    '63031': {'63031_0': 1.0859521127238725},
#    '63039': {'63039_0': 1.0972577911824273},
#    '63040': {'63040_0': 1.0976421399838512, '63040_1': 1.1307964927049925},
#    '63116': {'63116_0': 1.0540252983140042, '63116_1': 0.98632997561862},
#    '63136': {'63136_0': 1.079471509765419,
#     '63136_1': 1.0968064531165933,
#     '63136_2': 1.0825491474056743,
#     '63136_3': 1.1039776743202536,
#     '63136_4': 1.1253356638143683},
#    '63151': {'63151_0': 1.0823256369235708, '63151_1': 1.1219420705731604},
#    '63155': {'63155_0': 1.102972473332058, '63155_1': 1.138826653943012},
#    '63159': {'63159_0': 1.1766785662369754, '63159_1': 1.1199437094994709},
#    '63370': {'63370_0': 1.0719066077146389,
#     '63370_1': 1.080384096435202,
#     '63370_2': 1.0725049501339594,
#     '63370_3': 1.0808604992513169,
#     '63370_4': 1.1088183931808937,
#     '63370_5': 1.0655543883313678,
#     '63370_6': 1.0956328550042478,
#     '63370_7': 1.1070603499713012},
#    '63382': {'63382_0': 1.167854046996225,
#     '63382_1': 1.159967270365854,
#     '63382_2': 1.179740423482663,
#     '63382_3': 1.1556961067372353},
#    '63465': {'63465_0': 2.0832319024296795, '63465_1': 2.0994563039985006},
#    ...}},
#  'intermodal_access_egress': {'has_valid_intermodal_connections': True,
#   'invalid_intermodal_connections': {'car': {'stops_with_links_not_in_network': set(),
#     'stops_with_links_with_wrong_modes': set()}}},
#  'is_valid_network': False}

# %%
testy = n.schedule.generate_validation_report

# %%
print(testy)
# Out:
# <bound method Schedule.generate_validation_report of <Schedule instance at 133260872306176: with 1414 services>>

# %%
# n.write_to_matsim(output_path)
